# %% [markdown]
# # Joint Paradigm for Document-Level Event Extraction and Geoparsing for Indonesian News Text

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import pprint
import nltk

pp = pprint.PrettyPrinter(indent=2)

# %% [markdown]
# ## Data Pre-Processing

# %%
# Specify the path to the text file
file_path = "event-geoparsing-corpus.txt"

# Open the file
file = open(file_path, "r")

# Read the contents of the file
file_contents = file.read()

# Close the file
file.close()

# Print the contents of the file
pp.pprint(file_contents)
# Out:
# ('Kerabat/NNP/O/O\n'
#  'Layat/NNP/O/O\n'
#  'Jasad/NNP/O/O\n'
#  'Jerry/NNP/O/O\n'
#  'Wong/NNP/O/O\n'
#  'Pengemudi/NNP/O/O\n'
#  'Mini/NNP/B-ARG/Vehicle-Arg\n'
#  'Cooper/NNP/I-ARG/Vehicle-Arg\n'
#  'di/IN/O/O\n'
#  'RSCM/NN/B-ORG/Hospital-Arg\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Jenazah/NNP/O/O\n'
#  'Jerry/NNP/O/O\n'
#  'Wong/NNP/O/O\n'
#  ',/,/O/O\n'
#  'pengemudi/NN/O/O\n'
#  'Mini/NNP/B-ARG/Vehicle-Arg\n'
#  'Cooper/NNP/I-ARG/Vehicle-Arg\n'
#  'yang/SC/O/O\n'
#  'menabrak/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'bagian/O/O\n'
#  'belakang/NN/O/O\n'
#  'truk/NN/B-ARG/Vehicle-Arg\n'
#  ',/,/O/O\n'
#  'kini/RB/O/O\n'
#  'berada/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'RSCM/NNP/B-ORG/Hospital-Arg\n'
#  '\n'
#  'Sekitar/CDI/O/O\n'
#  '15/CDP/O/O\n'
#  'kerabat/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'teman/NN/O/O\n'
#  'datang/VBI/O/O\n'
#  'melayat/VBT/O/O\n'
#  '\n'
#  'Pantauan/IN/O/O\n'
#  'detikcom/NN/B-ORG/Reporter-Arg\n'
#  'di/IN/O/O\n'
#  'kamar/NN/O/O\n'
#  'jenazah/NN/O/O\n'
#  'RSCM/NNP/B-ORG/Hospital-Arg\n'
#  ',/,/O/O\n'
#  'Jalan/NN/B-ARG/Street-Arg\n'
#  'Salemba/NNP/I-ARG/Street-Arg\n'
#  ',/,/O/O\n'
#  'Jakarta/NNP/B-PLOC/Place-Arg/(-6.1780125136691195, 106.83773321392438)/2\n'
#  'Pusat/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Jumat/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '16/5/2014/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  ',/,/O/O\n'
#  'jasad/NN/O/O\n'
#  'Jerry/NNP/O/O\n'
#  'ditutup/VB/O/O\n'
#  'kain/NN/O/O\n'
#  'jarik/NN/O/O\n'
#  'cokelat/JJ/O/O\n'
#  ',/,/O/O\n'
#  'dikelilingi/VBT/O/O\n'
#  'kerabatnya/NN/O/O\n'
#  '\n'
#  'Ada/VB/O/O\n'
#  'seorang/NN/O/O\n'
#  'kerabat/NN/O/O\n'
#  'Jerry/NNP/O/O\n'
#  ',/,/O/O\n'
#  'Dodi/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'mengenang/VBT/O/O\n'
#  'Jerry/NN/O/O\n'
#  'sebagai/IN/O/O\n'
#  'orang/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'baik/JJ/O/O\n'
#  'dan/CC/O/O\n'
#  'banyak/CD/O/O\n'
#  'teman/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Jerry/NN/O/O\n'
#  'tadi/NN/O/O\n'
#  'perjalanan/NN/O/O\n'
#  'dari/IN/O/O\n'
#  'rumah/NN/O/O\n'
#  'temannya/NNG/O/O\n'
#  ',/,/O/O\n'
#  'mau/MD/O/O\n'
#  'pulang/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'rumahnya/NN/O/O\n'
#  'di/IN/O/O\n'
#  'daerah/NN/O/O\n'
#  'Pluit/NNP/B-PLOC/To-Arg/(-6.113297962451269, 106.78672611344551)/4\n'
#  '\n'
#  'Jerry/NN/O/O\n'
#  'ini/DT/O/O\n'
#  'orangnya/NN/O/O\n'
#  'baik/JJ/O/O\n'
#  ',/,/O/O\n'
#  'temannya/NNG/O/O\n'
#  'banyak/JJ/O/O\n'
#  ',/,/O/O\n'
#  'kebetulan/NN/O/O\n'
#  'saya/PRP/O/O\n'
#  'teman/NN/O/O\n'
#  'main/NN/O/O\n'
#  'futsal/JJ/O/O\n'
#  'di/IN/O/O\n'
#  'Kuningan/NN/B-PLOC/Place-Arg/(-6.235976199075322, 106.82213128724581)/4\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'dia/PRP/O/O\n'
#  '\n'
#  'Sedang/NN/O/O\n'
#  'kerabatnya/NN/O/O\n'
#  'lainnya/NNG/O/O\n'
#  'enggan/RB/O/O\n'
#  'memberikan/VB/O/O\n'
#  'keterangan/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Saya/PRP/O/O\n'
#  'nggak/NN/O/O\n'
#  'tahu/VBI/O/O\n'
#  'apa/WP/O/O\n'
#  '-/-/O/O\n'
#  'apa/WP/O/O\n'
#  ',/,/O/O\n'
#  'kami/PRP/O/O\n'
#  'sedang/RB/O/O\n'
#  'berduka/VB/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'begitu/RB/O/O\n'
#  'pinta/NN/O/O\n'
#  'seorang/NN/O/O\n'
#  'kerabat/NN/O/O\n'
#  '\n'
#  'Mini/NN/B-ARG/Vehicle-Arg\n'
#  'Cooper/NNP/I-ARG/Vehicle-Arg\n'
#  'bernopol/VB/O/O\n'
#  'B/SYM/B-ARG/Plate-Arg\n'
#  '226/CD/I-ARG/Plate-Arg\n'
#  'NUK/NN/I-ARG/Plate-Arg\n'
#  'yang/SC/O/O\n'
#  'dikemudikan/VBT/O/O\n'
#  'Jerry/NNP/O/O\n'
#  'Wong/NNP/O/O\n'
#  'menghantam/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'keras/JJ/O/O\n'
#  'bagian/O/O\n'
#  'belakang/NN/O/O\n'
#  'truk/NN/B-ARG/Vehicle-Arg\n'
#  'wing/FW/O/O\n'
#  'box/MD/O/O\n'
#  'bernopol/VB/O/O\n'
#  'B/SYM/B-ARG/Plate-Arg\n'
#  '9667/CDP/I-ARG/Plate-Arg\n'
#  'ZX/NN/I-ARG/Plate-Arg\n'
#  'di/IN/O/O\n'
#  'Km/NN/B-ARG/Point-Arg\n'
#  '24+800/NN/I-ARG/Point-Arg\n'
#  'dari/IN/O/O\n'
#  'Pluit/NN/B-LOC/From-Arg/(-6.113297962451269, 106.78672611344551)/4\n'
#  'arah/NN/O/O\n'
#  'Bandara/NNP/B-ORG/To-Arg\n'
#  'Soekarno/NNP/I-ORG/To-Arg\n'
#  '-/NNP/I-ORG/To-Arg\n'
#  'Hatta/NNP/I-ORG/To-Arg\n'
#  '\n'
#  'Saking/NN/O/O\n'
#  'kerasnya/NN/O/O\n'
#  'hantaman/NN/B-EVE/ACCIDENT-EVENT\n'
#  'itu/PR/O/O\n'
#  ',/,/O/O\n'
#  'bagian/O/O\n'
#  'depan/NN/O/O\n'
#  'Mini/NNP/B-ARG/Vehicle-Arg\n'
#  'Cooper/NNP/I-ARG/Vehicle-Arg\n'
#  'tersangkut/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'bemper/NN/O/O\n'
#  'truk/NN/B-ARG/Vehicle-Arg\n'
#  'itu/PR/O/O\n'
#  '\n'
#  '===\n'
#  '1/CDP/B-ARG/DeathVictim-Arg\n'
#  'Orang/NN/I-ARG/DeathVictim-Arg\n'
#  'Tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  ',/,/O/O\n'
#  '125/CD/B-ARG/Evacuee-Arg\n'
#  'Ribu/CD/I-ARG/Evacuee-Arg\n'
#  'Warga/NN/I-ARG/Evacuee-Arg\n'
#  'California/NNP/B-PLOC/Place-Arg/(37.84576308242729, -120.72746695681695)/1\n'
#  'Mengungsi/VBI/B-EVE/EVACUATE-EVENT\n'
#  'akibat/IN/O/O\n'
#  'Kebakaran/NN/B-EVE/FIRE-EVENT\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'California/NNP/B-PLOC/Published-Arg/(37.84576308242729, '
#  '-120.72746695681695)/1\n'
#  '-/-/O/O\n'
#  'Kebakaran/NN/B-EVE/FIRE-EVENT\n'
#  'hutan/NN/I-EVE/FIRE-EVENT\n'
#  'yang/SC/O/O\n'
#  'menerjang/VBT/O/O\n'
#  'wilayah/NN/O/O\n'
#  'California/NNP/B-PLOC/Place-Arg/(37.84576308242729, -120.72746695681695)/1\n'
#  ',/,/O/O\n'
#  'Amerika/NNP/B-PLOC/Place-Arg/(38.4572641110912, -92.2110028043666)/0\n'
#  'Serikat/NNP/I-PLOC/Place-Arg\n'
#  'memaksa/VBT/O/O\n'
#  '125/CDP/B-ARG/Evacuee-Arg\n'
#  'ribu/CDP/I-ARG/Evacuee-Arg\n'
#  'warga/NN/O/O\n'
#  'untuk/SC/O/O\n'
#  'mengungsi/VBI/B-EVE/EVACUATE-EVENT\n'
#  '\n'
#  'Dilaporkan/VBT/O/O\n'
#  'sedikitnya/NNG/O/O\n'
#  'satu/CDP/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'akibat/IN/O/O\n'
#  'kebakaran/NN/B-EVE/FIRE-EVENT\n'
#  'ini/PR/O/O\n'
#  '\n'
#  'Ada/NN/O/O\n'
#  'sembilan/CDP/B-ARG/Point-Arg\n'
#  'titik/NN/I-ARG/Point-Arg\n'
#  'api/NN/B-EVE/FIRE-EVENT\n'
#  'yang/SC/O/O\n'
#  'terus/RB/O/O\n'
#  'bergerak/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'wilayah/NN/O/O\n'
#  'Southern/NNP/B-PLOC/Place-Arg/(37.84576308242729, -120.72746695681695)/5\n'
#  'California/NNP/I-PLOC/Place-Arg\n'
#  'dan/CC/O/O\n'
#  'mengancam/VBT/O/O\n'
#  'pemukiman/NN/B-ARG/Facility-Arg\n'
#  'warga/NN/I-ARG/Facility-Arg\n'
#  'yang/SC/O/O\n'
#  'ada/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'San/NNP/B-LOC/Place-Arg/(33.135, -117.1743)/5\n'
#  'Marcos/NNP/I-LOC/Place-Arg\n'
#  'dan/CC/O/O\n'
#  'Escondido/NNP/B-LOC/Place-Arg/(33.1347, -117.0723)/5\n'
#  ',/,/O/O\n'
#  'distrik/NN/O/O\n'
#  'San/NNP/B-PLOC/Place-Arg/(32.8312, -117.1225)/5\n'
#  'Diego/NNP/I-PLOC/Place-Arg\n'
#  '\n'
#  'Sebuah/NN/O/O\n'
#  'rumah/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'cukup/RB/O/O\n'
#  'besar/JJ/O/O\n'
#  'milik/NN/O/O\n'
#  'warga/NN/O/O\n'
#  'setempat/NN/O/O\n'
#  'di/IN/O/O\n'
#  'pinggiran/NN/O/O\n'
#  'San/NNP/B-LOC/Place-Arg/(33.135, -117.1743)/5\n'
#  'Marcos/NNP/I-LOC/Place-Arg\n'
#  'habis/RB/O/O\n'
#  'dilalap/VBT/B-EVE/FIRE-EVENT\n'
#  'api/NN/I-EVE/FIRE-EVENT\n'
#  '\n'
#  'Tayangan/NN/O/O\n'
#  'televisi/NN/O/O\n'
#  'setempat/NN/O/O\n'
#  'menunjukkan/VB/O/O\n'
#  'bagaiman/IN/O/O\n'
#  'kobaran/NN/B-EVE/FIRE-EVENT\n'
#  'api/NN/I-EVE/FIRE-EVENT\n'
#  'bergerak/VBI/O/O\n'
#  'cepat/JJ/O/O\n'
#  'mendekati/VB/O/O\n'
#  'rumah/NN/O/O\n'
#  'warga/NN/O/O\n'
#  ',/,/O/O\n'
#  'sementara/CC/O/O\n'
#  'warga/NN/O/O\n'
#  'bergegas/VBI/O/O\n'
#  'mengevakuasi/VBT/B-EVE/EVACUATE-EVENT\n'
#  'barang/NN/O/O\n'
#  '-/-/O/O\n'
#  'barangnya/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'mengungsi/VBI/B-EVE/EVACUATE-EVENT\n'
#  'dari/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  '\n'
#  'Demikian/PR/O/O\n'
#  'seperti/IN/O/O\n'
#  'dilansir/VBT/O/O\n'
#  'Reuters/NN/B-ORG/Reporter-Arg\n'
#  ',/,/O/O\n'
#  'Jumat/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '16/5/2014/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  '===\n'
#  'Analisis/NNP/O/O\n'
#  'BMKG/NNP/B-ORG/Reporter-Arg\n'
#  'soal/IN/O/O\n'
#  'Gempa/NNP/B-EVE/QUAKE-EVENT\n'
#  'Lebak/NNP/B-LOC/Place-Arg/(-6.585671253448132, 106.20907658148096)/2\n'
#  '5,1/CD/B-ARG/Strength-Arg\n'
#  'SR/NN/B-ARG/Strength-Arg\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'berkekuatan/VBI/B-ARG/Strength-Arg\n'
#  '5,1/CD/I-ARG/Strength-Arg\n'
#  'Skala/NN/I-ARG/Strength-Arg\n'
#  'Richter/NNP/I-ARG/Strength-Arg\n'
#  '(/OP/O/O\n'
#  'SR/NNP/O/O\n'
#  ')/CP/O/O\n'
#  'mengguncang/VBT/B-EVE/QUAKE-EVENT\n'
#  'kawasan/NN/O/O\n'
#  'Lebak/NNP/B-LOC/Place-Arg/(-6.585671253448132, 106.20907658148096)/2\n'
#  ',/,/O/O\n'
#  'Banten/NNP/B-LOC/Place-Arg/(-6.321098712338462, 106.23469405402261)/1\n'
#  '\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  'dirasakan/VB/O/O\n'
#  'hingga/IN/O/O\n'
#  'Bandung/NNP/B-LOC/Place-Arg/(-7.043296715749431, 107.65469419110545)/2\n'
#  'Dampak/NN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'digambarkan/VB/O/O\n'
#  'oleh/IN/O/O\n'
#  'peta/NN/O/O\n'
#  'tingkat/NN/O/O\n'
#  'guncangan/NN/B-EVE/QUAKE-EVENT\n'
#  '(/OP/O/O\n'
#  'shakemap/NN/O/O\n'
#  ')/CP/O/O\n'
#  'BMKG/NNP/B-ORG/Reporter-Arg\n'
#  'dan/CC/O/O\n'
#  'laporan/NN/O/O\n'
#  'masyarakat/NN/O/O\n'
#  'menunjukkan/VB/O/O\n'
#  'bahwa/SC/O/O\n'
#  'dampak/NN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'berupa/VBT/O/O\n'
#  'guncangan/NN/B-EVE/QUAKE-EVENT\n'
#  'dirasakan/VB/O/O\n'
#  'di/IN/O/O\n'
#  'daerah/NN/O/O\n'
#  'Bayah/NN/B-LOC/Place-Arg/(-6.908602082571137, 106.28554321427342)/3\n'
#  'dan/CC/O/O\n'
#  'Cikotok/NNP/B-LOC/Place-Arg/(-6.853926442579436, 106.29481931990914)/4\n'
#  'dalam/IN/O/O\n'
#  'skala/NN/O/O\n'
#  'intensitas/NN/O/O\n'
#  'II/OD/B-ARG/Strength-Arg\n'
#  'SIG/NNP/I-ARG/Strength-Arg\n'
#  '-/-/O/O\n'
#  'BMKG/NNP/B-ORG/OfficerOfficial-Arg\n'
#  '(/OP/O/O\n'
#  'III/OD/B-ARG/Strength-Arg\n'
#  '-/-/O/O\n'
#  'IV/OD/B-ARG/Strength-Arg\n'
#  'MMI/NNP/I-ARG/Strength-Arg\n'
#  ')/CP/O/O\n'
#  ',/,/O/O\n'
#  'Sukabumi/NNP/B-LOC/Place-Arg/(-6.936256164208697, 106.92618260828208)/2\n'
#  'dan/CC/O/O\n'
#  'Bandung/NNP/B-LOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2\n'
#  'dengan/IN/O/O\n'
#  'intensitas/NN/O/O\n'
#  'II/OD/B-ARG/Strength-Arg\n'
#  'SIG/NNP/I-ARG/Strength-Arg\n'
#  '-/-/O/O\n'
#  'BMKG/NNP/B-ORG/OfficerOfficial-Arg\n'
#  '(/OP/O/O\n'
#  'II/NNP/B-ARG/Strength-Arg\n'
#  '-/-/O/O\n'
#  'III/OD/B-ARG/Strength-Arg\n'
#  'MMI/NNP/I-ARG/Strength-Arg\n'
#  ')/CP/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'Kepala/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Pusat/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Gempa/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Bumi/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'dan/CC/O/O\n'
#  'Tsunami/NN/O/O\n'
#  'BMKG/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Mochammad/NNP/O/O\n'
#  'Riyad/NNP/O/O\n'
#  'dalam/IN/O/O\n'
#  'keterangan/NN/O/O\n'
#  'tertulis/VBI/O/O\n'
#  ',/,/O/O\n'
#  'Jumat/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '16/2/2018/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  'Baca/VBI/O/O\n'
#  'juga/RB/O/O\n'
#  ':/:/O/O\n'
#  'Gempa/NNP/B-EVE/QUAKE-EVENT\n'
#  '5,1/CD/B-ARG/Strength-Arg\n'
#  'SR/NN/I-ARG/Strength-Arg\n'
#  'Guncang/NNP/B-EVE/QUAKE-EVENT\n'
#  'Lebak/NNP/B-LOC/Place-Arg/(-6.585671253448132, 106.20907658148096)/2\n'
#  'Banten/NNP/B-LOC/Place-Arg/(-6.321098712338462, 106.23469405402261)/1\n'
#  'Berdasarkan/NNP/O/O\n'
#  'hasil/NN/O/O\n'
#  'analisis/NN/O/O\n'
#  'BMKG/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'itu/PR/O/O\n'
#  'merupakan/VB/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'tektonik/NN/O/O\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'itu/PR/O/O\n'
#  'terjadi/VB/O/O\n'
#  'akibat/IN/O/O\n'
#  'aktivitas/NN/O/O\n'
#  'subduksi/NN/O/O\n'
#  'lempeng/JJ/O/O\n'
#  'Indo/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Australia/NNP/B-PLOC/Place-Arg/(-31.667307305686077, 138.4606196920466)/0\n'
#  'ke/IN/O/O\n'
#  'bawah/NN/O/O\n'
#  'Lempeng/NN/O/O\n'
#  'Eurasia/NNP/O/O\n'
#  '\n'
#  '===\n'
#  '3/CDP/B-ARG/DeathVictim-Arg\n'
#  'Tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'Akibat/IN/O/O\n'
#  'Gempa/NNP/B-EVE/QUAKE-EVENT\n'
#  'di/IN/O/O\n'
#  'Meksiko/NNP/B-PLOC/Place-Arg/(20.893694415571684, -99.32179436716993)/0\n'
#  'dan/CC/O/O\n'
#  'Guatemala/NNP/B-PLOC/Place-Arg/(14.898340481702862, -90.81834384088687)/0\n'
#  ',/,/O/O\n'
#  'Termasuk/VBT/O/O\n'
#  'Bayi/NN/O/O\n'
#  'Baru/NNP/O/O\n'
#  'Lahir/VBI/O/O\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Mexico/NNP/B-PLOC/Published-Arg/(19.302903257396633, -99.10508326400131)/1\n'
#  'City/NNP/I-PLOC/Published-Arg\n'
#  '-/-/O/O\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'berkekuatan/VBI/B-ARG/Strength-Arg\n'
#  '6,9/CD/I-ARG/Strength-Arg\n'
#  'Skala/NN/I-ARG/Strength-Arg\n'
#  'Richter/NNP/I-ARG/Strength-Arg\n'
#  'mengguncang/VB/B-EVE/QUAKE-EVENT/QUAKE-EVENT\n'
#  'wilayah/NN/O/O\n'
#  'Meksiko/NNP/B-LOC/Place-Arg/(20.893694415571684, -99.32179436716993)/0\n'
#  'dan/CC/O/O\n'
#  'Guatemala/NN/B-LOC/Place-Arg/(14.898340481702862, -90.81834384088687)/0\n'
#  '\n'
#  'Nahas/NNP/O/O\n'
#  ',/,/O/O\n'
#  'sedikitnya/NNG/O/O\n'
#  '3/CDP/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'dalam/IN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  'termasuk/VB/O/O\n'
#  'salah/JJ/O/O\n'
#  'satunya/PRN/O/O\n'
#  'seorang/NN/O/O\n'
#  'bayi/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'baru/JJ/O/O\n'
#  'lahir/VB/O/O\n'
#  '\n'
#  'Survei/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Geologi/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'AS/NNP/B-PLOC/Place-Arg/(38.4572641110912, -92.2110028043666)/0\n'
#  '(/OP/O/O\n'
#  'USGS/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ')/CP/O/O\n'
#  ',/,/O/O\n'
#  'seperti/IN/O/O\n'
#  'dilansir/VBT/O/O\n'
#  'AFP/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'Selasa/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '8/7/2014/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  ',/,/O/O\n'
#  'mencatat/VB/O/O\n'
#  'bahwa/SC/O/O\n'
#  'pusat/NN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'ini/DT/O/O\n'
#  'berada/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'hanya/RB/O/O\n'
#  'berjarak/VBI/O/O\n'
#  '2/CDP/B-ARG/Central-Arg\n'
#  'kilometer/NN/I-ARG/Central-Arg\n'
#  'dari/IN/O/O\n'
#  'kota/NN/O/O\n'
#  'Puerto/NNP/B-LOC/Place-Arg/(-34.6135871,-58.3697784)/2\n'
#  'Madero/NNP/I-LOC/Place-Arg\n'
#  'dan/CC/O/O\n'
#  'berjarak/VBI/O/O\n'
#  '200/CDP/B-ARG/Central-Arg\n'
#  'kilometer/NN/I-ARG/Central-Arg\n'
#  'dari/IN/O/O\n'
#  'Guatemala/NNP/B-LOC/Place-Arg/(14.629566162184377, -90.50339335214694)/2\n'
#  'City/NNP/I-LOC/Place-Arg\n'
#  '\n'
#  'Menurut/NNP/O/O\n'
#  'USGS/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'pusat/NN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'ini/DT/O/O\n'
#  'berada/VBI/O/O\n'
#  'pada/IN/O/O\n'
#  'kedalaman/NN/B-ARG/Depth-Arg\n'
#  '60/CD/I-ARG/Depth-Arg\n'
#  'kilometer/NND/I-ARG/Depth-Arg\n'
#  'di/IN/O/O\n'
#  'bawah/NN/O/O\n'
#  'permukaan/NN/O/O\n'
#  'laut/NN/O/O\n'
#  '\n'
#  'Sekitar/CDI/O/O\n'
#  '10/CDP/B-ARG/Repeat-Arg\n'
#  'kali/NN/I-ARG/Repeat-Arg\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'susulan/NN/I-EVE/QUAKE-EVENT\n'
#  'dilaporkan/VB/O/O\n'
#  'terjadi/VB/O/O\n'
#  'pasca/SC/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  '6,9/CD/B-ARG/Strength-Arg\n'
#  'SR/NN/I-ARG/Strength-Arg\n'
#  'tersebut/PR/O/O\n'
#  'melanda/VB/O/O\n'
#  '\n'
#  'Hal/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'sempat/MD/O/O\n'
#  'memicu/VBT/O/O\n'
#  'kepanikan/NN/O/O\n'
#  'warga/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'sayangnya/PRP/O/O\n'
#  'menyebabkan/VBT/O/O\n'
#  'tanah/NN/B-EVE/LANDSLIDE-EVENT\n'
#  'longsor/JJ/I-EVE/LANDSLIDE-EVENT\n'
#  'di/IN/O/O\n'
#  'beberapa/CDI/O/O\n'
#  'wilayah/NN/O/O\n'
#  '\n'
#  '===\n'
#  'Tabrak/NN/B-EVE/ACCIDENT-EVENT\n'
#  'Pembatas/NN/O/O\n'
#  'Jalan/NN/O/O\n'
#  'Km/NN/B-ARG/Point-Arg\n'
#  '27/CD/I-ARG/Point-Arg\n'
#  'Tol/NNP/B-ARG/Street-Arg\n'
#  'Bandara/NNP/I-ARG/Street-Arg\n'
#  ',/,/O/O\n'
#  'BMW/NN/B-ARG/Vehicle-Arg\n'
#  'Ringsek/NN/O/O\n'
#  'Berat/NN/O/O\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Sebuah/NND/O/O\n'
#  'mobil/NN/O/O\n'
#  'BMW/NNP/B-ARG/Vehicle-Arg\n'
#  'dengan/IN/O/O\n'
#  'nopol/NN/O/O\n'
#  'B/SYM/B-ARG/Plate-Arg\n'
#  '54/CD/I-ARG/Plate-Arg\n'
#  'LN/NN/I-ARG/Plate-Arg\n'
#  'menabrak/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'pembatas/NN/O/O\n'
#  'jalan/NN/O/O\n'
#  'Tol/NNP/B-ARG/Street-Arg\n'
#  'Bandara/NNP/I-ARG/Street-Arg\n'
#  'arah/NN/O/O\n'
#  'Jakarta/NNP/B-PLOC/To-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  'tengah/O/O\n'
#  'malam/NN/O/O\n'
#  'ini/PR/O/O\n'
#  '\n'
#  'Kondisi/NN/O/O\n'
#  'mobil/NN/O/O\n'
#  'itu/PR/O/O\n'
#  'ringsek/JJ/O/O\n'
#  'berat/JJ/O/O\n'
#  'di/IN/O/O\n'
#  'bagian/NN/O/O\n'
#  'depan/JJ/O/O\n'
#  '\n'
#  'Informasi/NN/O/O\n'
#  'itu/PR/O/O\n'
#  'disampaikan/VB/O/O\n'
#  'TMC/NNP/O/O\n'
#  'Polda/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Metro/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Jaya/NNP/I-ORG/OfficerOfficial-Arg\n'
#  '\n'
#  'BMW/NNP/B-ARG/Vehicle-Arg\n'
#  'bernomor/VBT/O/O\n'
#  'pelat/NN/O/O\n'
#  'B/SYM/B-ARG/Plate-Arg\n'
#  '54/CD/I-ARG/Plate-Arg\n'
#  'LN/NN/I-ARG/Plate-Arg\n'
#  'itu/DT/O/O\n'
#  'menabrak/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'pembatas/NN/O/O\n'
#  'jalan/NN/O/O\n'
#  'Tol/NNP/B-ARG/Street-Arg\n'
#  'Bandara/NNP/I-ARG/Street-Arg\n'
#  'di/IN/O/O\n'
#  'Km/NN/B-ARG/Point-Arg\n'
#  '27/CD/I-ARG/Point-Arg\n'
#  ',/,/O/O\n'
#  'tepatnya/RB/O/O\n'
#  'di/IN/O/O\n'
#  'Kamal/NNP/B-LOC/Place-Arg/(-6.101459525319878, 106.69969913010671)/4\n'
#  'mengarah/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'Pluit/NN/B-PLOC/To-Arg/(-6.113297962451269, 106.78672611344551)/4\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '23.30/JJ/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Dari/IN/O/O\n'
#  'foto/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'diunggah/VB/O/O\n'
#  'TMC/NNP/O/O\n'
#  'Polda/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Metro/NN/I-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'mobil/NN/O/O\n'
#  'itu/DT/O/O\n'
#  'diduga/VBT/O/O\n'
#  'berkecepatan/VBT/O/O\n'
#  'tinggi/JJ/O/O\n'
#  'saat/SC/O/O\n'
#  'menabrak/VBT/O/O\n'
#  'hingga/IN/O/O\n'
#  'mobil/NN/B-ARG/Vehicle-Arg\n'
#  'berbalik/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'arah/NN/O/O\n'
#  'berlawanan/VBI/O/O\n'
#  '\n'
#  'Bagian/NN/O/O\n'
#  'depannya/NN/O/O\n'
#  'tampak/VB/O/O\n'
#  'ringsek/JJ/O/O\n'
#  'berat/JJ/O/O\n'
#  '\n'
#  'Ban/NN/O/O\n'
#  'mobil/NN/B-ARG/Vehicle-Arg\n'
#  'depan/NN/O/O\n'
#  'sebelah/NN/O/O\n'
#  'kiri/NN/O/O\n'
#  'juga/RB/O/O\n'
#  'terlihat/VB/O/O\n'
#  'lepas/JJ/O/O\n'
#  '\n'
#  '===\n'
#  'Kebakaran/NN/B-EVE/FIRE-EVENT\n'
#  'Hanguskan/NNP/O/O\n'
#  'Kantor/NNP/B-ORG/Facility-Arg\n'
#  'Redaksi/NNP/I-ORG/Facility-Arg\n'
#  'Pikiran/NNP/I-ORG/Facility-Arg\n'
#  'Rakyat/NNP/I-ORG/Facility-Arg\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Bandung/NNP/B-PLOC/Published-Arg/(-6.920669331867579, 107.62893793140472)/2\n'
#  ',/,/O/O\n'
#  '-/-/O/O\n'
#  'Kebakaran/NN/B-EVE/FIRE-EVENT\n'
#  'melanda/VB/O/O\n'
#  'kantor/NN/B-ORG/Facility-Arg\n'
#  'redaksi/NN/I-ORG/Facility-Arg\n'
#  'koran/NN/I-ORG/Facility-Arg\n'
#  'Pikiran/NNP/I-ORG/Facility-Arg\n'
#  'Rakyat/NNP/I-ORG/Facility-Arg\n'
#  'di/IN/O/O\n'
#  'Jalan/NN/B-ARG/Street-Arg\n'
#  'Soekarno/NNP/I-ARG/Street-Arg\n'
#  'Hatta/NNP/I-ARG/Street-Arg\n'
#  ',/,/O/O\n'
#  'Bandung/NNP/B-LOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2\n'
#  '\n'
#  'Belum/NEG/O/O\n'
#  'diketahui/VBT/O/O\n'
#  'penyebab/NN/O/O\n'
#  'insiden/NN/O/O\n'
#  'tersebut/PR/O/O\n'
#  '\n'
#  'Petugas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'pemadam/NN/I-ORG/OfficerOfficial-Arg\n'
#  'sudah/MD/O/O\n'
#  'berada/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  'kejadian/NN/O/O\n'
#  '\n'
#  'Kapolrestabes/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Bandung/NNP/B-PLOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2\n'
#  'Kombes/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Pol/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Mashudi/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'mengatakan/VB/O/O\n'
#  'peristiwa/NN/O/O\n'
#  'kebakaran/NN/B-EVE/FIRE-EVENT\n'
#  'berlangsung/VBI/O/O\n'
#  'sekitar/CDI/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '06.00/JJ/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  ',/,/O/O\n'
#  'Sabtu/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '4/10/2014/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Api/NN/B-EVE/FIRE-EVENT\n'
#  'diduga/VBT/O/O\n'
#  'mulai/MD/O/O\n'
#  'muncul/VB/O/O\n'
#  'di/IN/O/O\n'
#  'lantai/NN/O/O\n'
#  'dua/CDP/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'ucap/VB/O/O\n'
#  'Mashudi/NN/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  'kejadian/NN/O/O\n'
#  '\n'
#  'Pantauan/NN/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  'pada/IN/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '08.25/CD/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  ',/,/O/O\n'
#  'kondisi/NN/O/O\n'
#  'api/NN/B-EVE/FIRE-EVENT\n'
#  'sudah/MD/O/O\n'
#  'padam/IN/O/O\n'
#  '\n'
#  'Petugas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Dinas/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Pencegahan/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Kebakaran/NN/I-ORG/OfficerOfficial-Arg\n'
#  '(/OP/O/O\n'
#  'Diskar/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ')/CP/O/O\n'
#  'Kota/NNP/B-PLOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2\n'
#  'Bandung/NNP/I-PLOC/Place-Arg\n'
#  'melakukan/VB/O/O\n'
#  'pendinginan/NN/O/O\n'
#  'di/IN/O/O\n'
#  'area/NN/O/O\n'
#  'bangunan/NN/B-ORG/Facility-Arg\n'
#  'redaksi/NN/B-ORG/Facility-Arg\n'
#  'Pikiran/NNP/B-ORG/Facility-Arg\n'
#  'Rakyat/NNP/B-ORG/Facility-Arg\n'
#  '\n'
#  '===\n'
#  'Truk/NN/B-ARG/Vehicle-Arg\n'
#  'Gandeng/NNP/O/O\n'
#  'Nyemplung/NNP/O/O\n'
#  'ke/IN/O/O\n'
#  'Sungai/NN/O/O\n'
#  'di/IN/O\n'
#  'Demak/NNP/B-PLOC/Place-Arg/(-6.914199432985346, 110.6401210778076)/2\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Sebuah/NND/O/O\n'
#  'truk/NN/B-ARG/Vehicle-Arg\n'
#  'gandeng/NN/O/O\n'
#  'mengalami/VB/O/O\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'Jalan/NN/B-ARG/Street-Arg\n'
#  'Raya/NNP/I-ARG/Street-Arg\n'
#  'Demak/NN/B-LOC/Place-Arg/(-6.914199432985346, 110.6401210778076)/2\n'
#  'arah/NN/O/O\n'
#  'Kudus/NN/B-PLOC/To-Arg/(-6.800818096681704, 110.85433802259463)/2\n'
#  'tepatnya/RB/O/O\n'
#  'di/IN/O/O\n'
#  'depan/NN/O/O\n'
#  'Pasar/NNP/B-ORG/Place-Arg\n'
#  'Gajah/NNP/I-ORG/Place-Arg\n'
#  ',/,/O/O\n'
#  'Jawa/NNP/B-PLOC/Place-Arg/(-7.272336146806256, 110.1979583965181)\n'
#  'Tengah/NN/I-PLOC/Place-Arg\n'
#  '\n'
#  'Truk/NN/B-ARG/Vehicle-Arg\n'
#  'tersebut/DT/O/O\n'
#  'terguling/VBI/B-EVE/ACCIDENT-EVENT\n'
#  'hingga/IN/O/O\n'
#  'masuk/VBT/O/O\n'
#  'ke/IN/O/O\n'
#  'dalam/IN/O/O\n'
#  'sungai/NN/O/O\n'
#  '\n'
#  'Menurut/IN/O/O\n'
#  'saksi/NN/O/O\n'
#  'mata/NN/O/O\n'
#  ',/,/O/O\n'
#  'Ali/NNP/O/O\n'
#  'Musyadad/NNP/O/O\n'
#  'kejadia/NN/O/O\n'
#  'terjadi/VB/O/O\n'
#  ',/,/O/O\n'
#  'Minggu/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '18/1/2015/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '06.00/CDP/I-ARG/Time-Arg\n'
#  'WIB/NN/I-ARG/Time-Arg\n'
#  'tadi/NN/O/O\n'
#  '\n'
#  'Kondisi/NN/O/O\n'
#  'truk/NN/B-ARG/Vehicle-Arg\n'
#  'yang/SC/O/O\n'
#  'bernopol/VBT/O/O\n'
#  'berawalan/VBT/O/O\n'
#  'B/NNP/O/O\n'
#  'itu/PR/O/O\n'
#  'terlihat/VB/O/O\n'
#  'hancur/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'terbalik/VBI/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'dalam/IN/O/O\n'
#  'sungai/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'tidak/NEG/O/O\n'
#  'terlalu/RB/O/O\n'
#  'dalam/JJ/O/O\n'
#  '\n'
#  'Ali/NN/O/O\n'
#  'juga/RB/O/O\n'
#  'mengatakan/VBI/O/O\n'
#  ',/,/O/O\n'
#  'ada/VBI/O/O\n'
#  'tiga/CDP/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  'menjadi/VB/I-ARG/DeathVictim-Arg\n'
#  'korban/NN/I-ARG/DeathVictim-Arg\n'
#  'dalam/IN/O/O\n'
#  'kejadian/NN/O/O\n'
#  'ini/PR/O/O\n'
#  '\n'
#  'Ketiganya/NN/O/O\n'
#  'diketahui/VBT/O/O\n'
#  'sudah/MD/O/O\n'
#  'tidak/NEG/O/O\n'
#  'bernyawa/VBI/O/O\n'
#  '\n'
#  '===\n'
#  'Field/NNP/B-ORG/Facility-Arg\n'
#  'Hospital/NNP/I-ORG/Facility-Arg\n'
#  'Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0\n'
#  'di/IN/O/O\n'
#  'Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  'Tangani/NNP/O/O\n'
#  '9/CD/B-ARG/DeathVictim-Arg\n'
#  'Korban/NN/I-ARG/DeathVictim-Arg\n'
#  'dan/CC/O/O\n'
#  'Tampung/NNP/O/O\n'
#  '346/CDP/B-ARG/Evacuee-Arg\n'
#  'Pengungsi/NN/I-ARG/Evacuee-Arg\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Kathmandu/NNP/B-PLOC/Published-Arg/(27.72347337087862, 85.3308207184338)/3\n'
#  '-/-/O/O\n'
#  'Tim/NN/O/O\n'
#  'Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0\n'
#  'Peduli/JJ/O/O\n'
#  'Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  'tengah/MD/O/O\n'
#  'membongkar/VBT/O/O\n'
#  'ruangan/NN/O/O\n'
#  'operasi/NN/O/O\n'
#  'ortopedi/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'anestesi/NN/O/O\n'
#  'sebelum/SC/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  '7,4/CD/B-ARG/Strength-Arg\n'
#  'SR/NNP/B-ARG/Strength-Arg\n'
#  'mengguncang/VB/B-EVE/QUAKE-EVENT\n'
#  'wilayah/NN/O/O\n'
#  'utara/NN/O/O\n'
#  'Nepal/NN/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  'tadi/NN/O/O\n'
#  'siang/NN/O/O\n'
#  '\n'
#  'Setelah/SC/O/O\n'
#  'ruang/NN/O/O\n'
#  'operasi/NN/O/O\n'
#  'dalam/IN/O/O\n'
#  'bentuk/NN/O/O\n'
#  'infleatable/NN/O/O\n'
#  'tent/NN/O/O\n'
#  'itu/PR/O/O\n'
#  'dibongkar/VB/O/O\n'
#  ',/,/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'terjadi/VB/O/O\n'
#  'sehingga/SC/O/O\n'
#  'tim/NN/O/O\n'
#  'membangun/VB/O/O\n'
#  'tenda/NN/O/O\n'
#  'tambahan/NN/O/O\n'
#  'Ada/NN/O/O\n'
#  '9/CD/O/O\n'
#  'warga/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'dirawat/VBT/O/O\n'
#  ',/,/O/O\n'
#  'luka/NN/O/O\n'
#  '-/-/O/O\n'
#  'luka/NN/O/O\n'
#  'dan/NNP/O/O\n'
#  'kepanikan/IN/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'Direktur/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Tanggap/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Darurat/JJ/I-ORG/OfficerOfficial-Arg\n'
#  'BNPB/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Junjungan/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Tambunan/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'di/IN/O/O\n'
#  'Kathmandu/NNP/B-PLOC/Place-Arg/(27.72347337087862, 85.3308207184338)/3\n'
#  ',/,/O/O\n'
#  'Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  ',/,/O/O\n'
#  'Selasa/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '12/5/2015/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'malam/NN/O/O\n'
#  '\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'berkekuatan/VBI/B-ARG/Strength-Arg\n'
#  '7,4/CD/I-ARG/Strength-Arg\n'
#  'SR/NN/I-ARG/Strength-Arg\n'
#  'kembali/RB/O/O\n'
#  'mengguncang/VB/B-EVE/QUAKE-EVENT/QUAKE-EVENT\n'
#  'Nepal/NN/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  'hari/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'pada/IN/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '12.49/CD/I-ARG/Time-Arg\n'
#  'waktu/NN/O/O\n'
#  'setempat/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'berlangsung/VB/O/O\n'
#  'kurang/RB/O/O\n'
#  'lebih/RB/O/O\n'
#  'selama/IN/O/O\n'
#  '2/CDP/B-ARG/Duration-Arg\n'
#  'menit/NN/I-ARG/Duration-Arg\n'
#  '\n'
#  'Guncangan/NN/B-EVE/QUAKE-EVENT\n'
#  'terasa/VBI/O/O\n'
#  'kuat/JJ/O/O\n'
#  'di/IN/O/O\n'
#  'distrik/NN/O/O\n'
#  'field/NN/O/O\n'
#  'hospital/NNP/O/O\n'
#  'Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0\n'
#  'berdiri/VB/O/O\n'
#  ',/,/O/O\n'
#  'yakni/SC/O/O\n'
#  'Satungal/NNP/B-LOC/Place-Arg/(27.68195348230143, 85.25200908474135)\n'
#  '\n'
#  '===\n'
#  'Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  'Kembali/RB/O/O\n'
#  'Diguncang/VBT/B-EVE/QUAKE-EVENT\n'
#  'Gempa/NN/I-EVE/QUAKE-EVENT\n'
#  '7,1/CD/B-ARG/Strength-Arg\n'
#  'SR/NNP/I-ARG/Strength-Arg\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Kathmandu/NNP/B-PLOC/Published-Arg/(27.72347337087862, 85.3308207184338)/3\n'
#  ',/,/O/O\n'
#  '-/-/O/O\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'bumi/NN/I-EVE/QUAKE-EVENT\n'
#  'kembali/RB/O/O\n'
#  'melanda/VB/O/O\n'
#  'Nepal/NN/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0\n'
#  'hari/NN/O/O\n'
#  'ini/PR/O/O\n'
#  '\n'
#  'Gempa/NNP/B-EVE/QUAKE-EVENT\n'
#  'berkekuatan/VBI/B-ARG/Strength-Arg\n'
#  '7,1/CD/I-ARG/Strength-Arg\n'
#  'Skala/NN/I-ARG/Strength-Arg\n'
#  'Richter/NNP/I-ARG/Strength-Arg\n'
#  '(/OP/O/O\n'
#  'SR/NNP/O/O\n'
#  ')/CP/O/O\n'
#  'ini/DT/O/O\n'
#  'menyebabkan/VBT/O/O\n'
#  'ribuan/CDC/O/O\n'
#  'orang/NN/O/O\n'
#  'di/IN/O/O\n'
#  'ibukota/NN/O/O\n'
#  'Kathmandu/NN/B-LOC/Place-Arg/(27.72347337087862, 85.3308207184338)/3\n'
#  'berlarian/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'jalan/NN/O/O\n'
#  '-/-/O/O\n'
#  'jalan/NN/O/O\n'
#  '\n'
#  'Badan/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Survei/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Geologi/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Amerika/NNP/B-PLOC/Place-Arg/(38.4572641110912, -92.2110028043666)/0\n'
#  'Serikat/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'USGS/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'menyatakan/VB/O/O\n'
#  'seperti/IN/O/O\n'
#  'dilansir/VBT/O/O\n'
#  'kantor/NN/O/O\n'
#  'berita/NN/O/O\n'
#  'Reuters/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'Selasa/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '12/5/2015/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  ',/,/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  'terjadi/VB/O/O\n'
#  'di/IN/O/O\n'
#  'wilayah/NN/O/O\n'
#  'sekitar/RB/O/O\n'
#  '68/CD/B-ARG/Central-Arg\n'
#  'kilometer/NND/I-ARG/Central-Arg\n'
#  'sebelah/NN/I-ARG/Central-Arg\n'
#  'barat/NN/I-ARG/Central-Arg\n'
#  'kota/NN/B-LOC/Place-Arg/(27.928189880910356, 86.61208289377247)/4\n'
#  'Namche/NNP/I-LOC/Place-Arg\n'
#  'Bazar/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'dekat/JJ/O/O\n'
#  'dengan/IN/O/O\n'
#  'gunung/NN/O/O\n'
#  'Mount/NNP/B-ARG/Place-Arg\n'
#  'Everest/NN/I-ARG/Place-Arg\n'
#  '\n'
#  'Guncangan/NNP/B-EVE/QUAKE-EVENT\n'
#  'gempa/NN/I-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  'dilaporkan/VB/O/O\n'
#  'dirasakan/VB/O/O\n'
#  'hingga/IN/O/O\n'
#  'ke/IN/O/O\n'
#  'New/NNP/B-LOC/Place-Arg/(28.646518974169425, 77.1089795345416)/2\n'
#  'Delhi/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'India/NNP/B-PLOC/Place-Arg/(21.57293880816482, 78.53025185596609)/0\n'
#  '\n'
#  'Sejauh/NN/O/O\n'
#  'ini/PR/O/O\n'
#  ',/,/O/O\n'
#  'belum/NEG/O/O\n'
#  'ada/VBI/O/O\n'
#  'laporan/NN/O/O\n'
#  'korban/NN/O/O\n'
#  'maupun/CC/O/O\n'
#  'kerusakan/NN/O/O\n'
#  'akibat/IN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  '\n'
#  '===\n'
#  '41/CD/B-ARG/DeathVictim-Arg\n'
#  'Orang/NN/I-ARG/DeathVictim-Arg\n'
#  'Tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'Akibat/IN/O/O\n'
#  'Banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'di/IN/O/O\n'
#  'India/NNP/B-PLOC/Place-Arg/(21.57293880816482, 78.53025185596609)/0\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'New/NNP/B-PLOC/Published-Arg/(28.646518974169425, 77.1089795345416)/2\n'
#  'Delhi/NNP/I-PLOC/Published-Arg\n'
#  '-/-/O/O\n'
#  'Wilayah/NN/O/O\n'
#  'Gujarat/NNP/B-LOC/Place-Arg/(22.292066083838034, 71.90914465940999)/1\n'
#  ',/,/O/O\n'
#  'India/NNP/B-PLOC/Place-Arg/(21.57293880816482, 78.53025185596609)/0\n'
#  'tengah/MD/O/O\n'
#  'dilanda/VBT/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'bandang/JJ/I-EVE/FLOOD-EVENT\n'
#  'yang/SC/O/O\n'
#  'dipicu/VB/O/O\n'
#  'oleh/IN/O/O\n'
#  'hujan/NN/B-EVE/RAIN-EVENT\n'
#  'deras/NN/I-EVE/RAIN-EVENT\n'
#  'tiada/NN/O/O\n'
#  'henti/NN/O/O\n'
#  'selama/IN/O/O\n'
#  '24/CDP/B-ARG/Duration-Arg\n'
#  'jam/NN/I-ARG/Duration-Arg\n'
#  '\n'
#  'Sedikitnya/NNG/O/O\n'
#  '41/CD/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'akibat/IN/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'ini/PR/O/O\n'
#  '\n'
#  'Otoritas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'setempat/NN/O/O\n'
#  'telah/MD/O/O\n'
#  'mengevakuasi/VBT/B-EVE/EVACUATE-EVENT\n'
#  'lebih/RB/O/O\n'
#  'dari/IN/O/O\n'
#  '10/CDP/B-ARG/Evacuee-Arg\n'
#  'ribu/CDP/I-ARG/Evacuee-Arg\n'
#  'warga/NN/I-ARG/Evacuee-Arg\n'
#  ',/,/O/O\n'
#  'terutama/JJ/O/O\n'
#  'dari/IN/O/O\n'
#  'wilayah/NN/O/O\n'
#  'Gujarat/NN/B-LOC/Place-Arg/(22.292066083838034, 71.90914465940999)/1\n'
#  'yang/SC/O/O\n'
#  'terletak/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'dekat/JJ/O/O\n'
#  'pantai/NN/O/O\n'
#  '\n'
#  'Distrik/NNP/B-LOC/Place-Arg/(21.326558941241277, 71.29974959140496)/2\n'
#  'Amreli/NNP/I-LOC/Place-Arg\n'
#  'merupakan/VB/O/O\n'
#  'area/NN/O/O\n'
#  'terdampak/IN/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'paling/RB/O/O\n'
#  'parah/JJ/O/O\n'
#  ',/,/O/O\n'
#  'dengan/IN/O/O\n'
#  'mayoritas/NN/O/O\n'
#  'korban/NN/O/O\n'
#  'tewas/JJ/O/O\n'
#  'berasal/VBI/O/O\n'
#  'dari/IN/O/O\n'
#  'distrik/NN/O/O\n'
#  'ini/PR/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Terdapat/NN/O/O\n'
#  '41/CD/B-ARG/DeathVictim-Arg\n'
#  'korban/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'di/IN/O/O\n'
#  'sejumlah/CDI/O/O\n'
#  'wilayah/NN/O/O\n'
#  ',/,/O/O\n'
#  'dengan/IN/O/O\n'
#  '36/CDP/B-ARG/DeathVictim-Arg\n'
#  'korban/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'berasal/VBI/O/O\n'
#  'dari/IN/O/O\n'
#  'Amreli/NNP/B-LOC/Place-Arg/(21.326558941241277, 71.29974959140496)/2\n'
#  ',/,/O/O\n'
#  'kemudian/CC/O/O\n'
#  'tiga/CDP/B-ARG/DeathVictim-Arg\n'
#  'korban/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'berasal/VBI/O/O\n'
#  'dari/IN/O/O\n'
#  'Bhavnagar/NNP/B-LOC/Place-Arg/(21.746013932118366, 72.04927349639709)/2\n'
#  'dan/CC/O/O\n'
#  'dua/CDP/B-ARG/DeathVictim-Arg\n'
#  'korban/NN/I-ARG/DeathVictim-Arg\n'
#  'tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'lainnya/NNG/O/O\n'
#  'dari/IN/O/O\n'
#  'disrik/VBT/O/O\n'
#  'Rajkot/NNP/B-LOC/Place-Arg/(22.011645000050645, 70.72023172903025)/2\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'terang/JJ/O/O\n'
#  'seorang/NN/O/O\n'
#  'pejabat/NN/O/O\n'
#  'pada/IN/O/O\n'
#  'ruang/NN/O/O\n'
#  'kontrol/NN/O/O\n'
#  'badan/NN/O/O\n'
#  'penanggulangan/NN/O/O\n'
#  'bencana/NN/O/O\n'
#  'setempat/NN/O/O\n'
#  ',/,/O/O\n'
#  'seperti/IN/O/O\n'
#  'dilansir/VBT/O/O\n'
#  'AFP/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'Kamis/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '25/6/2015/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  '===\n'
#  'Pikap/NNP/B-ARG/Vehicle-Arg\n'
#  'Terguling/NNP/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'Tol/NNP/B-ARG/Street-Arg\n'
#  'JORR/NNP/I-ARG/Street-Arg\n'
#  ',/,/O/O\n'
#  'Pondok/NNP/B-PLOC/Place-Arg/(-6.2649756,106.7818375)/3\n'
#  'Indah/NNP/I-PLOC\n'
#  'ke/IN/O/O\n'
#  'Cilincing/NNP/B-PLOC/Place-Arg/(-6.123697810179591, 106.93802723918002)/3\n'
#  'Macet/NNP/B-EVE/ACCIDENT-EVENT\n'
#  '2/CDP/I-ARG/Length-Arg\n'
#  'Kilometer/NND/I-ARG/Length-Arg\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Mobil/NN/O/O\n'
#  'pikap/NN/B-ARG/Vehicle-Arg\n'
#  'terguling/VBI/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'KM/NN/B-ARG/Point-Arg\n'
#  '52/CDP/I-ARG/Point-Arg\n'
#  'Tol/NNP/B-ARG/Place-Arg\n'
#  'JORR/NNP/I-ARG/Place-Arg\n'
#  'Pondok/NNP/B-LOC/Place-Arg/(-6.2649756,106.7818375)/3\n'
#  'Indah/NNP/I-LOC/Place-Arg\n'
#  'arah/NN/O/O\n'
#  'Cilincing/NNP/B-PLOC/To-Arg/(-6.123697810179591, 106.93802723918002)/3\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '07.32/CD/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'mengakibatkan/VBT/O/O\n'
#  'kepadatan/NN/O/O\n'
#  'kendaraan/NN/O/O\n'
#  'hingga/IN/O/O\n'
#  '2/CDP/B-ARG/Length-Arg\n'
#  'kilometer/NND/I-ARG/Length-Arg\n'
#  '\n'
#  'Petugas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Jasa/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Marga/NN/I-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'Ani/NN/O/O\n'
#  'saat/SC/O/O\n'
#  'dikonfirmasi/VB/O/O\n'
#  'mengatakan/VB/O/O\n'
#  ',/,/O/O\n'
#  'petugas/NN/O/O\n'
#  'sudah/MD/O/O\n'
#  'berada/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  'kejadian/NN/O/O\n'
#  '\n'
#  'Belum/NEG/O/O\n'
#  'diketahui/VBT/O/O\n'
#  'ada/VBI/O/O\n'
#  'tidaknya/NEG/O/O\n'
#  'korban/NN/O/O\n'
#  'akibat/IN/O/O\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  '\n'
#  '"/"/O/O\n'
#  'Kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'tepatnya/RB/O/O\n'
#  'di/IN/O/O\n'
#  'KM/NN/B-ARG/Point-Arg\n'
#  '52+800/NN/I-ARG/Point-Arg\n'
#  'yaitu/SC/O/O\n'
#  'mobil/NN/B-ARG/Vehicle-Arg\n'
#  'muatan/NN/O/O\n'
#  'cat/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'tiner/NN/O/O\n'
#  '\n'
#  'Akibatnya/NN/O/O\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'macet/NN/B-EVE/JAM-EVENT\n'
#  '2/CDP/B-ARG/Length-Arg\n'
#  'KM/NN/I-ARG/Length-Arg\n'
#  'dari/IN/O/O\n'
#  'Pondok/NNP/B-LOC/From-Arg/(-6.2649756,106.7818375)/3\n'
#  'Indah/NNP/I-LOC/From-Arg\n'
#  'ke/IN/O/O\n'
#  'Cilincing/NNP/B-LOC/To-Arg/(-6.123697810179591, 106.93802723918002)/3\n'
#  '"/"/O/O\n'
#  'ujar/VB/O/O\n'
#  'Ani/NN/O/O\n'
#  'pada/IN/O/O\n'
#  'detikcom/NNP/B-ORG/Reporter-Arg\n'
#  ',/,/O/O\n'
#  'Rabu/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '30/9/2015/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  '===\n'
#  'Korban/NN/B-ARG/DeathVictim-Arg\n'
#  'Tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'di/IN/O/O\n'
#  'Plaza/NNP/B-ARG/Facility-Arg\n'
#  'UOB/NNP/I-ARG/Facility-Arg\n'
#  'Ditemukan/VBT/O/O\n'
#  'di/IN/O/O\n'
#  'Bawah/NN/O/O\n'
#  'Mobil/NN/O/O\n'
#  'di/IN/O/O\n'
#  'Basement/NNP/O/O\n'
#  '1/CD/O/O\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Petugas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'tim/NN/O/O\n'
#  'evakuasi/NN/O/O\n'
#  'kembali/RB/O/O\n'
#  'menemukan/VBT/O/O\n'
#  'korban/NN/B-ARG/Facility-Arg\n'
#  'tewas/JJ/I-ARG/Facility-Arg\n'
#  'di/IN/O/O\n'
#  'Plaza/NNP/B-ARG/Facility-Arg\n'
#  'UOB/NNP/I-ARG/Facility-Arg\n'
#  ',/,/O/O\n'
#  'Thamrin/NNP/B-ARG/Place-Arg\n'
#  '\n'
#  'Korban/NN/O/O\n'
#  'diketahui/VBT/O/O\n'
#  'bernama/VB/O/O\n'
#  'Herdian/NNP/O/O\n'
#  'Eko/NNP/O/O\n'
#  '(/OP/O/O\n'
#  '27/CD/O/O\n'
#  ')/CP/O/O\n'
#  '\n'
#  'Korban/NN/O/O\n'
#  'merupakan/VB/O/O\n'
#  'cleaning/FW/O/O\n'
#  'service/NN/O/O\n'
#  'di/IN/O/O\n'
#  'gedung/NN/O/O\n'
#  'itu/PR/O/O\n'
#  '\n'
#  '"Korban/DT/O/O\n'
#  'meninggal/VBI/O/O\n'
#  'ditemukan/VBT/O/O\n'
#  'di/IN/O/O\n'
#  'bawah/NN/O/O\n'
#  'mobil/NN/O/O\n'
#  '\n'
#  'Kondisi/NN/O/O\n'
#  'tubuh/NN/O/O\n'
#  'korban/NN/O/O\n'
#  'sudah/RB/O/O\n'
#  'bengkak/JJ/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'Kadis/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Damkar/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  'Paimin/NNP/O/O\n'
#  'Napitupulu/NNP/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  ',/,/O/O\n'
#  'Sabtu/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '19/1/2013/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'Korban/NNP/O/O\n'
#  'ditemukan/VBT/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '15.05/CD/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Jasad/NN/O/O\n'
#  'korban/NN/O/O\n'
#  'langsung/RB/O/O\n'
#  'dimasukkan/VB/O/O\n'
#  'ke/IN/O/O\n'
#  'kantung/NN/O/O\n'
#  'mayat/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'dibawa/VB/O/O\n'
#  'ke/IN/O/O\n'
#  'RSCM/NNP/B-ORG/Hospital-Arg\n'
#  '\n'
#  '"/"/O/O\n'
#  'Korban/NN/O/O\n'
#  'ditemukan/VBT/O/O\n'
#  'di/IN/O/O\n'
#  'basement/NN/O/O\n'
#  '1,/CDP/O/O\n'
#  '"/"/O/O\n'
#  'jelasnya/NN/O/O\n'
#  '\n'
#  'Kondisi/JJ/O/O\n'
#  'di/IN/O/O\n'
#  'lokasi/NN/O/O\n'
#  ',/,/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'di/IN/O/O\n'
#  'basement/NN/O/O\n'
#  '1/CD/O/O\n'
#  'sudah/MD/O/O\n'
#  'surut/JJ/O/O\n'
#  ',/,/O/O\n'
#  'tetapi/CC/O/O\n'
#  'di/IN/O/O\n'
#  'basement/NN/O/O\n'
#  '2/CD/O/O\n'
#  'masih/MD/O/O\n'
#  'tergenang/VBI/O/O\n'
#  '\n'
#  'Evakuasi/NNP/B-EVE/\n'
#  'terus/RB/O/O\n'
#  'dilakukan/VB/O/O\n'
#  '\n'
#  '===\n'
#  'Wali/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Kota/NNP/I-ORG/OfficerOfficial-Arg\n'
#  ':/:/O/O\n'
#  'Korban/NN/B-ARG/DeathVictim-Arg\n'
#  'Jiwa/NN/I-ARG/DeathVictim-Arg\n'
#  'Bisa/MD/O/O\n'
#  'Lebih/RB/O/O\n'
#  'dari/IN/O/O\n'
#  '100/CDP/B-ARG/DeathVictim-Arg\n'
#  'Orang/NN/I-ARG/DeathVictim-Arg\n'
#  '-/-/O/O\n'
#  '-/-/O/O\n'
#  'Foto/NN/O/O\n'
#  ':/NNP/O/O\n'
#  'PoolTaipei/NNP/O/O\n'
#  ',/,/O/O\n'
#  '-/-/O/O\n'
#  'Korban/NN/B-ARG/DeathVictim-Arg\n'
#  'jiwa/NN/I-ARG/DeathVictim-Arg\n'
#  'akibat/IN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  '6,4/CD/B-ARG/Strength-Arg\n'
#  'Skala/NN/I-ARG/Strength-Arg\n'
#  'Richter/NNP/I-ARG/Strength-Arg\n'
#  '(/OP/O/O\n'
#  'SR/NNP/O/O\n'
#  ')/CP/O/O\n'
#  'di/IN/O/O\n'
#  'kota/NN/B-LOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2\n'
#  'Tainan/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Taiwan/NNP/B-PLOC/Place-Arg/(24.119811469350566, 120.75584580341844)/0\n'
#  'selatan/NNP/O/O\n'
#  'terus/RB/O/O\n'
#  'bertambah/VBI/O/O\n'
#  '\n'
#  'Sejauh/NN/O/O\n'
#  'ini/PR/O/O\n'
#  ',/,/O/O\n'
#  'sudah/MD/O/O\n'
#  '38/CDP/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  'yang/SC/I-ARG/DeathVictim-Arg\n'
#  'ditemukan/VBT/O/O\n'
#  'tewas/JJ/B-ARG/DeathVictim-Arg\n'
#  'usai/IN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'yang/SC/O/O\n'
#  'terjadi/VBI/O/O\n'
#  'dua/CDP/O/O\n'
#  'hari/NN/O/O\n'
#  'lalu/JJ/O/O\n'
#  '\n'
#  'Namun/CC/O/O\n'
#  'wali/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'kota/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Tainan/NNP/B-PLOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2\n'
#  'mengingatkan/VB/O/O\n'
#  ',/,/O/O\n'
#  'jumlah/NN/O/O\n'
#  'korban/NN/B-ARG/DeathVictim-Arg\n'
#  'jiwa/NN/I-ARG/DeathVictim-Arg\n'
#  'bisa/MD/O/O\n'
#  'mencapai/VB/O/O\n'
#  'lebih/RB/O/O\n'
#  'dari/IN/O/O\n'
#  '100/CDP/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  '\n'
#  'Upaya/NN/O/O\n'
#  'pencarian/NN/O/O\n'
#  'korban/NN/O/O\n'
#  'terus/RB/O/O\n'
#  'dilakukan/VB/O/O\n'
#  'dan/CC/O/O\n'
#  'difokuskan/VBT/O/O\n'
#  'di/IN/O/O\n'
#  'area/NN/O/O\n'
#  'reruntuhan/NN/O/O\n'
#  'gedung/NN/B-ARG/Facility-Arg\n'
#  'Wei/NNP/I-ARG/Facility-Arg\n'
#  '-/-/O/O\n'
#  'guan/NN/O/O\n'
#  'Golden/NNP/B-ARG/Facility-Arg\n'
#  'Dragon/NNP/I-ARG/Facility-Arg\n'
#  'Building/NNP/I-ARG/Facility-Arg\n'
#  'di/IN/O/O\n'
#  'kota/NN/B-LOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2\n'
#  'Tainan/NNP/I-LOC/Place-Arg\n'
#  '\n'
#  'Gedung/NNP/O/O\n'
#  'berlantai/VBT/O/O\n'
#  '17/CDP/O/O\n'
#  'tersebut/DT/O/O\n'
#  'ambruk/NN/O/O\n'
#  'akibat/IN/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'yang/SC/O/O\n'
#  'terjadi/VB/O/O\n'
#  'pada/IN/O/O\n'
#  'Sabtu/NNP/B-ARG/Time-Arg\n'
#  ',/,/O/O\n'
#  '6/CD/O/O\n'
#  'Februari/NNP/O/O\n'
#  'lalu/VB/O/O\n'
#  '\n'
#  'Di/IN/O/O\n'
#  'gedung/NN/O/O\n'
#  'tersebut/PR/O/O\n'
#  ',/,/O/O\n'
#  '117/CD/B-ARG/MissingPerson-Arg\n'
#  'orang/NN/I-ARG/MissingPerson-Arg\n'
#  'tercatat/VB/I-ARG/MissingPerson-Arg\n'
#  'masih/MD/I-ARG/MissingPerson-Arg\n'
#  'hilang/VBI/I-ARG/MissingPerson-Arg\n'
#  'dan/CC/O/O\n'
#  'diperkirakan/VBT/O/O\n'
#  'tertimpa/VBI/O/O\n'
#  'puing/NN/O/O\n'
#  '-/-/O/O\n'
#  'puing/NN/O/O\n'
#  '\n'
#  'Wali/NN/B-ORG/OfficerOfficial-Arg\n'
#  'kota/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Tainan/NNP/B-LOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2\n'
#  ',/,/O/O\n'
#  'William/NNP/O/O\n'
#  'Lai/NNP/O/O\n'
#  'mengatakan/VB/O/O\n'
#  ',/,/O/O\n'
#  'upaya/NN/O/O\n'
#  'penyelamatan/NN/O/O\n'
#  'kini/RB/O/O\n'
#  'telah/MD/O/O\n'
#  'memasuki/VBT/O/O\n'
#  'apa/WP/O/O\n'
#  'yang/SC/O/O\n'
#  'disebutnya/VB/O/O\n'
#  'sebagai/IN/O/O\n'
#  '"/"/O/O\n'
#  'tahap/NN/O/O\n'
#  'ketiga/CDO/O/O\n'
#  '"/"/O/O\n'
#  '\n'
#  '===\n'
#  '4/CD/B-ARG/Affectedvehicle-Arg\n'
#  'Kendaraan/NN/I-ARG/Affectedvehicle-Arg\n'
#  'Kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'Beruntun/NN/I-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'KM/NN/B-ARG/Point-Arg\n'
#  '33/NNP/I-ARG/Point-Arg\n'
#  'Tol/NNP/B-ARG/Street-Arg\n'
#  'Jagorawi/NNP/I-ARG/Street-Arg\n'
#  'Arah/NN/O/O\n'
#  'Jakarta/NNP/B-PLOC/To-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Foto/NN/O/O\n'
#  ':/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Empat/CDP/B-ARG/Affectedvehicle-Arg\n'
#  'kendaraan/NN/I-ARG/Affectedvehicle-Arg\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'beruntun/VBI/I-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'KM/NN/B-ARG/Point-Arg\n'
#  '33+800/NN/I-ARG/Point-Arg\n'
#  'Tol/NNP/B-ARG/Street-Arg\n'
#  'Jagorawi/NNP/I-ARG/Street-Arg\n'
#  'yang/SC/O/O\n'
#  'mengarah/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'Jakarta/NNP/B-PLOC/To-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '\n'
#  'Petugas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'masih/MD/O/O\n'
#  'melakukan/VB/O/O\n'
#  'evakuasi/NN/O/O\n'
#  'kendaraan/NN/O/O\n'
#  'tersebut/PR/O/O\n'
#  '"/"/O/O\n'
#  'Kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'terjadi/VB/O/O\n'
#  'di/IN/O/O\n'
#  'lajur/NN/O/O\n'
#  '2/CD/O/O\n'
#  'dan/CC/O/O\n'
#  '3/CDP/O/O\n'
#  '\n'
#  'Untuk/IN/O/O\n'
#  'data/NN/O/O\n'
#  '-/-/O/O\n'
#  'data/NN/O/O\n'
#  'kendaraannya/NN/O/O\n'
#  'kami/PRP/O/O\n'
#  'belum/NEG/O/O\n'
#  'menerima/VBT/O/O\n'
#  'informasi/NN/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'petugas/NN/B-ORG/OfficerOfficial-Arg\n'
#  'operator/NN/I-ORG/OfficerOfficial-Arg\n'
#  'PT/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Jasamarga/NNP/I-ORG/OfficerOfficial-Arg\n'
#  ',/,/O/O\n'
#  'Rafli/NN/O/O\n'
#  'saat/SC/O/O\n'
#  'dikonfirmasi/VB/O/O\n'
#  ',/,/O/O\n'
#  'Kamis/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '28/4/2016/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'Peristiwa/NN/O/O\n'
#  'itu/PR/O/O\n'
#  'terjadi/VB/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '23.34/CD/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Lalu/VB/O/O\n'
#  'lintas/NN/O/O\n'
#  'pun/RP/O/O\n'
#  'padat/IN/O/O\n'
#  'menjelang/VBT/O/O\n'
#  'lokasi/NN/O/O\n'
#  '\n'
#  '===\n'
#  'Kasus/NN/O/O\n'
#  'Vellfire/NN/O/O\n'
#  'Anak/NN/O/O\n'
#  'Eks/NNP/O/O\n'
#  'Menteri/NNP/O/O\n'
#  'Sugiharto/NNP/O/O\n'
#  'Tabrak/NNP/B-EVE/ACCIDENT-EVENT\n'
#  '4/CD/B-ARG/Affectedvehicle-Arg\n'
#  'Mobil/NN/I-ARG/Affectedvehicle-Arg\n'
#  'Masih/MD/O/O\n'
#  'Lanjut/VB/O/O\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  '-/-/O/O\n'
#  'Kasus/NN/O/O\n'
#  'Vellfire/NNP/O/O\n'
#  'menabrak/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'empat/CDP/B-ARG/Affectedvehicle-Arg\n'
#  'mobil/NN/I-ARG/Affectedvehicle-Arg\n'
#  'yang/SC/O/O\n'
#  'dikemudikan/VBT/O/O\n'
#  'Hadi/NNP/O/O\n'
#  'Prasetyo/NNP/O/O\n'
#  '(/OP/O/O\n'
#  '16/CD/O/O\n'
#  ')/CP/O/O\n'
#  'anak/NN/O/O\n'
#  'eks/NN/O/O\n'
#  'Menteri/NN/O/O\n'
#  'BUMN/NN/O/O\n'
#  'Sugiharto/NNP/O/O\n'
#  'terus/RB/O/O\n'
#  'diseldiki/VBT/O/O\n'
#  'polisi/NN/O/O\n'
#  '\n'
#  'Saksi/NNP/O/O\n'
#  '-/-/O/O\n'
#  'saksi/NN/O/O\n'
#  'dalam/IN/O/O\n'
#  'kasus/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'akan/MD/O/O\n'
#  'dipanggil/VB/O/O\n'
#  '\n'
#  'Polisi/NN/B-ORG/OfficerOfficial-Arg\n'
#  'juga/RB/O/O\n'
#  'memeriksa/VBT/O/O\n'
#  'kepemilikan/NN/O/O\n'
#  'SIM/NN/O/O\n'
#  'milik/NN/O/O\n'
#  'Hadi/NNP/O/O\n'
#  'yang/SC/O/O\n'
#  'baru/MD/O/O\n'
#  'berusia/VB/O/O\n'
#  '16/CD/O/O\n'
#  'tahun/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Memang/NN/O/O\n'
#  'tetap/JJ/O/O\n'
#  'kita/PRP/O/O\n'
#  'lanjutkan/VB/O/O\n'
#  ',/,/O/O\n'
#  'kita/PRP/O/O\n'
#  'proses/NN/O/O\n'
#  'hukum/NN/O/O\n'
#  'kita/PRP/O/O\n'
#  'lanjutkan/VB/O/O\n'
#  'pendalaman/NN/O/O\n'
#  '\n'
#  'Kesulitan/VB/O/O\n'
#  'kita/PRP/O/O\n'
#  'kan/RP/O/O\n'
#  'pihak/NN/O/O\n'
#  'korban/NN/O/O\n'
#  'tidak/NEG/O/O\n'
#  'buat/NN/O/O\n'
#  'laporan/NN/O/O\n'
#  ',/,/O/O\n'
#  'sudah/RB/O/O\n'
#  'diundang/VBT/O/O\n'
#  'tidak/NEG/O/O\n'
#  'datang/VBI/O/O\n'
#  'memang/RB/O/O\n'
#  'mereka/PRP/O/O\n'
#  'sudah/MD/O/O\n'
#  'ada/VB/O/O\n'
#  'penyelesaian/NN/O/O\n'
#  'kekeluargaan/NN/O/O\n'
#  ',/,/O/O\n'
#  'tetapi/CC/O/O\n'
#  'proses/NN/O/O\n'
#  'hukum/NN/O/O\n'
#  'tetap/RB/O/O\n'
#  'berjalan/VB/O/O\n'
#  '\n'
#  'Karena/SC/O/O\n'
#  'ini/PR/O/O\n'
#  'kan/RP/O/O\n'
#  'bukan/NEG/O/O\n'
#  'delik/NN/O/O\n'
#  'aduan/FW/O/O\n'
#  ',/,/O/O\n'
#  'ada/VB/O/O\n'
#  'prosedur/NN/O/O\n'
#  'penanganannya/NN/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'jelas/VB/O/O\n'
#  'Kasatlantas/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Polres/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Jaksel/NNP/B-PLOC/Place-Arg/(-6.256679776683385, 106.81568629190677)/2\n'
#  'Kompol/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Dody/NNP/O/O\n'
#  ',/,/O/O\n'
#  'Rabu/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '27/4/2016/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  'Peristiwa/NN/O/O\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'ini/PR/O/O\n'
#  'terjadi/VB/O/O\n'
#  'pada/IN/O/O\n'
#  'Kamis/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '21/4/4/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'sore/NN/O/O\n'
#  '\n'
#  'Selain/IN/O/O\n'
#  'empat/CDP/B-ARG/Affectedvehicle-Arg\n'
#  'mobil/NN/I-ARG/Affectedvehicle-Arg\n'
#  'ada/VBI/O/O\n'
#  'satu/CDP/B-ARG/Affectedvehicle-Arg\n'
#  'motor/NN/I-ARG/Affectedvehicle-Arg\n'
#  'yang/SC/O/O\n'
#  'ditabrak/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'Jl/NNP/B-ARG/Street-Arg\n'
#  'Ciniru/NNP/I-ARG/Street-Arg\n'
#  ',/,/O/O\n'
#  'Kebayoran/NNP/B-LOC/Place-Arg/(-6.24397614020749, 106.80236966063316)/3\n'
#  'Baru/NNP/I-LOC/Place-Arg\n'
#  '\n'
#  'Hadi/NN/O/O\n'
#  'saat/NN/O/O\n'
#  'ini/DT/O/O\n'
#  'mengejar/VBT/O/O\n'
#  'kakak/NN/O/O\n'
#  'tirinya/NNP/O/O\n'
#  'Stephen/NNP/O/O\n'
#  '\n'
#  'Kasus/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'memang/RB/O/O\n'
#  'dilandasi/VBT/O/O\n'
#  'pertengkaran/NN/O/O\n'
#  'kakak/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'adik/NNP/O/O\n'
#  '\n'
#  '===\n'
#  'BMKG/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ':/:/O/O\n'
#  'Gempa/NNP/B-EVE/QUAKE-EVENT\n'
#  '6,5/CD/B-ARG/Strength-Arg\n'
#  'SR/NN/I-ARG/Strength-Arg\n'
#  'di/IN/O/O\n'
#  'Sumbar/NNP/B-LOC/Place-Arg/(-0.7011133317649648, 100.54048425582306)/1\n'
#  'Cukup/RB/O/O\n'
#  'Kuat/JJ/O/O\n'
#  'Tapi/CC/O/O\n'
#  'Tak/NEG/O/O\n'
#  'Timbulkan/NN/O/O\n'
#  'Kerusakan/NN/O/O\n'
#  '-/-/O/O\n'
#  '-/-/O/O\n'
#  'Foto/NN/O/O\n'
#  ':/:/O/O\n'
#  'Zainal/NNP/O/O\n'
#  'AbidinJakarta/NNP/O/O\n'
#  '-/NNP/O/O\n'
#  'Gempa/NNP/B-EVE/QUAKE-EVENT\n'
#  'berkekuatan/VBI/B-ARG/Strength-Arg\n'
#  '6,5/CD/I-ARG/Strength-Arg\n'
#  'SR/NNP/I-ARG/Strength-Arg\n'
#  'mengguncang/NNP/B-EVE/QUAKE-EVENT\n'
#  'Sumatera/NNP/B-LOC/Place-Arg/(-0.7011133317649648, 100.54048425582306)/1\n'
#  'Barat/NNP/I-LOC/Place-Arg\n'
#  '\n'
#  'Gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  'cukup/RB/O/O\n'
#  'kuat/JJ/O/O\n'
#  'namun/CC/O/O\n'
#  'tidak/NEG/O/O\n'
#  'mengakibatkan/VBT/O/O\n'
#  'kerusakan/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Mengacu/VB/O/O\n'
#  'parameter/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'tampak/VB/O/O\n'
#  'bahwa/SC/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'tersebut/PR/O/O\n'
#  'merupakan/VB/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'menengah/JJ/O/O\n'
#  'terjadi/VBI/O/O\n'
#  'akibat/IN/O/O\n'
#  'aktivitas/NN/O/O\n'
#  'subduksi/NN/O/O\n'
#  'lempeng/JJ/O/O\n'
#  'di/IN/O/O\n'
#  'zona/NN/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'ujar/VB/O/O\n'
#  'Kepala/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Bidang/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Mitigasi/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Gempa/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'bumi/NN/I-ORG/OfficerOfficial-Arg\n'
#  'dan/CC/I-ORG/OfficerOfficial-Arg\n'
#  'Tsunami/NN/I-ORG/OfficerOfficial-Arg\n'
#  'BMKG/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Daryono/NNP/O/O\n'
#  'saat/SC/O/O\n'
#  'dihubungi/VBT/O/O\n'
#  'detikcom/NN/B-ORG/Reporter-Arg\n'
#  ',/,/O/O\n'
#  'Kamis/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '2/6/2016/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  '\n'
#  'Menurut/IN/O/O\n'
#  'Daryono/NNP/O/O\n'
#  ',/,/O/O\n'
#  'gempa/NN/B-EVE/QUAKE-EVENT\n'
#  'ini/PR/O/O\n'
#  'memiliki/VB/O/O\n'
#  'efek/NN/O/O\n'
#  'permukaan/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'cukup/RB/O/O\n'
# ...
#  'satu/CDP/O/O\n'
#  'jam/NN/O/O\n'
#  'derasnya/NN/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'penjual/NN/O/O\n'
#  'buah/NN/O/O\n'
#  '-/-/O/O\n'
#  'buahan/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'saat/SC/O/O\n'
#  'berbincang/VBI/O/O\n'
#  'dengan/IN/O/O\n'
#  'detikcom/NN/B-ORG/Reporter-Arg\n'
#  'di/IN/O/O\n'
#  'pintu/NN/O/O\n'
#  'masuk/VB/O/O\n'
#  'Pasar/NNP/B-ORG\n'
#  'Gedebage/NNP/B-LOC/Place-Arg/(-6.9544782784345855, 107.70035145514332)/3\n'
#  '\n'
#  '===\n'
#  'Banjir/NN/B-EVE/FLOOD-EVENT\n'
#  '3/CDP/B-ARG/Height-Arg\n'
#  'Meter/NN/I-ARG/Height-Arg\n'
#  ',/,/O/O\n'
#  'Warga/NN/O/O\n'
#  'Cililitan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4\n'
#  'Mengungsi/VBI/O/O\n'
#  'ke/IN/O/O\n'
#  'Pinggir/NN/O/O\n'
#  'Jalan/NN/O/O\n'
#  '-/-/O/O\n'
#  '-/NNP/O/O\n'
#  'Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  ',/,/O/O\n'
#  'CNN/NNP/B-ORG/Reporter-Arg\n'
#  'Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0\n'
#  '-/NNP/O/O\n'
#  '-/-/O/O\n'
#  'Warga/NN/O/O\n'
#  'RT/SYM/O/O\n'
#  '01/CD/O/O\n'
#  ',/,/O/O\n'
#  'RW/NNP/B-ARG/Place-Arg\n'
#  '06/CD/I-ARG/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kelurahan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4\n'
#  'Cililitan/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Jakarta/NNP/B-PLOC/Place-Arg/(-6.253493193386638, 106.88971076153182)/2\n'
#  'Timur/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'mengungsi/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'sepanjang/NN/O/O\n'
#  'Jalan/NN/B-ARG/Place-Arg\n'
#  'Cililitan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4\n'
#  '-/NNP/O/O\n'
#  'Condet/NNP/B-PLOC/Place-Arg/(-6.2823949,106.8530383)/4\n'
#  'akibat/IN/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'setinggi/VBT/B-ARG/Height-Arg\n'
#  '2,5/CD/I-ARG/Height-Arg\n'
#  'hingga/IN/I-ARG/Height-Arg\n'
#  '3/CDP/B-ARG/Height-Arg\n'
#  'meter/NN/I-ARG/Height-Arg\n'
#  'merendam/VBT/O/O\n'
#  'permukiman/NN/B-ARG/Facility-Arg\n'
#  'mereka/PRP/O/O\n'
#  'sejak/IN/O/O\n'
#  'Jumat/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '26/4/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '05.00/JJ/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Sebagian/CDI/O/O\n'
#  'warga/NN/O/O\n'
#  'mulai/MD/O/O\n'
#  'meninggalkan/VBT/O/O\n'
#  'rumah/NN/O/O\n'
#  'pada/IN/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '06.00/JJ/I-ARG/Time-Arg\n'
#  'WIB/NN/I-ARG/Time-Arg\n'
#  'setelah/SC/O/O\n'
#  'sempat/MD/O/O\n'
#  'memindahkan/VBT/O/O\n'
#  'perabotan/NN/O/O\n'
#  'ke/IN/O/O\n'
#  'lantai/NN/O/O\n'
#  'dua/CDP/O/O\n'
#  '\n'
#  'Beberapa/CDI/O/O\n'
#  'dari/IN/O/O\n'
#  'mereka/PRP/O/O\n'
#  'baru/MD/O/O\n'
#  'naik/VB/O/O\n'
#  'pukul/NN/O/O\n'
#  '08.00/JJ/O/O\n'
#  'WIB/NNP/O/O\n'
#  ',/,/O/O\n'
#  'setelah/SC/O/O\n'
#  'dijemput/VBT/O/O\n'
#  'tim/NN/O/O\n'
#  'SAR/NNP/O/O\n'
#  'dengan/IN/O/O\n'
#  'perahu/NN/O/O\n'
#  'karet/NN/O/O\n'
#  '\n'
#  'Mia/NNP/O/O\n'
#  ',/,/O/O\n'
#  'warga/NN/O/O\n'
#  'setempat/NN/O/O\n'
#  'mengatakan/VB/O/O\n'
#  'air/NN/O/O\n'
#  'setinggi/VBT/B-ARG/Height-Arg\n'
#  'pinggang/NN/I-ARG/Height-Arg\n'
#  'orang/NN/I-ARG/Height-Arg\n'
#  'dewasa/JJ/I-ARG/Height-Arg\n'
#  'memasuki/VBT/O/O\n'
#  'rumahnya/NN/O/O\n'
#  'pada/IN/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '05.00/JJ/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Tiga/CDP/O/O\n'
#  'jam/NN/O/O\n'
#  'kemudian/CC/O/O\n'
#  ',/,/O/O\n'
#  'air/NN/O/O\n'
#  'sudah/MD/O/O\n'
#  'naik/VB/O/O\n'
#  'hingga/IN/O/O\n'
#  'nyaris/PRP/O/O\n'
#  'menyentuh/VB/O/O\n'
#  'lantai/NN/O/O\n'
#  'dua/CDP/O/O\n'
#  '\n'
#  'Mia/NNP/O/O\n'
#  'dan/CC/O/O\n'
#  'tiga/CDP/O/O\n'
#  'orang/NN/O/O\n'
#  'anaknya/NN/O/O\n'
#  'pun/RP/O/O\n'
#  'dievakuasi/VBT/O/O\n'
#  'oleh/IN/O/O\n'
#  'tim/NN/O/O\n'
#  'SAR/NNP/O/O\n'
#  'pada/IN/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '08.00/JJ/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  'dan/CC/O/O\n'
#  'mengungsi/VBI/B-EVE/EVACUATE-EVENT\n'
#  'di/IN/O/O\n'
#  'pinggir/NN/O/O\n'
#  'jalan/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Ini/PR/O/O\n'
#  'yang/SC/O/O\n'
#  'terparah/JJ/O/O\n'
#  'di/IN/O/O\n'
#  '2019/CD/O/O\n'
#  '\n'
#  'Dulu/RB/O/O\n'
#  'pernah/MD/O/O\n'
#  'kaya/JJ/O/O\n'
#  'gini/NN/O/O\n'
#  'tahun/NN/O/O\n'
#  'lalu/JJ/O/O\n'
#  ',/,/O/O\n'
#  'beberapa/CDI/O/O\n'
#  'bulan/NN/O/O\n'
#  '(/OP/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  ')/CP/O/O\n'
#  'tidak/NEG/O/O\n'
#  'setinggi/VBT/O/O\n'
#  'ini/DT/O/O\n'
#  '\n'
#  'Semoga/NN/O/O\n'
#  'cepat/JJ/O/O\n'
#  'surut/JJ/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'Mia/NN/O/O\n'
#  'seperti/IN/O/O\n'
#  'mengutip/VBT/O/O\n'
#  'Antara/NN/O/O\n'
#  '\n'
#  'Ia/PRP/O/O\n'
#  'berharap/VBT/O/O\n'
#  'pemerintah/NN/O/O\n'
#  'segera/RB/O/O\n'
#  'menyediakan/VB/O/O\n'
#  'lahan/NN/O/O\n'
#  'kosong/JJ/O/O\n'
#  'untuk/IN/O/O\n'
#  'pengungsian/NN/O/O\n'
#  'agar/SC/O/O\n'
#  'korban/NN/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'tidak/NEG/O/O\n'
#  'berkerumun/VBI/O/O\n'
#  'di/IN/O/O\n'
#  'pinggir/NN/O/O\n'
#  'jalan/NN/O/O\n'
#  'sehingga/SC/O/O\n'
#  'menyebabkan/VB/O/O\n'
#  'kemacetan/NN/B-EVE/JAM-EVENT\n'
#  'sepanjang/IN/B-ARG/Length-Arg\n'
#  'satu/CD/I-ARG/Length-Arg\n'
#  'kilometer/NND/I-ARG/Length-Arg\n'
#  'di/IN/O/O\n'
#  'Jalan/NN/B-ARG/Place-Arg\n'
#  'Cililitan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4\n'
#  '-/NNP/O/O\n'
#  'Condet/NNP/B-PLOC/Place-Arg/(-6.2823949,106.8530383)/4\n'
#  '\n'
#  'Banjir/NN/B-EVE/FLOOD-EVENT\n'
#  'merendam/VBT/I-EVE/FLOOD-EVENT\n'
#  'sebagian/CDI/O/O\n'
#  'wilayah/NN/O/O\n'
#  'Jakarta/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  'pada/IN/O/O\n'
#  'Jumat/NN/O/O\n'
#  'dini/JJ/O/O\n'
#  'hari/NN/O/O\n'
#  'karena/IN/O/O\n'
#  'air/NN/O/O\n'
#  'Sungai/NN/B-ARG/Cause-Arg\n'
#  'Ciliwung/NNP/I-ARG/Cause-Arg\n'
#  'meluap/VBT/B-EVE/FLOOD-EVENT\n'
#  'sejak/IN/O/O\n'
#  'Kamis/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '25/4/DD/B-ARG/Time-Arg\n'
#  ')/CP/O/O\n'
#  'malam/NN/O/O\n'
#  '\n'
#  'Kepala/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'UPT/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Pusat/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Data/NN/I-ORG/OfficerOfficial-Arg\n'
#  'dan/CC/O/O\n'
#  'Informasi/NN/O/O\n'
#  'Badan/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Penanggulangan/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Bencana/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Daerah/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  'Jakarta/NNP/I-PLOC/Place-Arg\n'
#  'M/NNP/O/O\n'
#  'Ridwan/NNP/O/O\n'
#  'mengatakan/VB/O/O\n'
#  'luapan/NN/B-EVE/FLOOD-EVENT\n'
#  'air/NN/O/O\n'
#  'Sungai/NN/B-ARG/Cause-Arg\n'
#  'Ciliwung/NNP/I-ARG/Cause-Arg\n'
#  'akan/MD/O/O\n'
#  'melewati/VBT/O/O\n'
#  '13/CDP/O/O\n'
#  'wilayah/NN/O/O\n'
#  ',/,/O/O\n'
#  'di/IN/O/O\n'
#  'antaranya/NNG/O/O\n'
#  'Srengseng/NNP/B-LOC/Place-Arg/(-6.34840066885497, 106.8245009553336)/4\n'
#  'Sawah/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Rawajati/NNP/B-LOC/Place-Arg/(-6.258078344036345, 106.85465172512482)/4\n'
#  ',/,/O/O\n'
#  'Pengadegan/NNP/B-LOC/Place-Arg/(-6.95388742431344, 108.36410039280217)/4\n'
#  ',/,/O/O\n'
#  'Cikoko/NNP/B-LOC/Place-Arg/(-6.245041099532579, 106.85435715914397)/4\n'
#  ',/,/O/O\n'
#  'Pejaten/NNP/B-LOC/Place-Arg/(-6.279918869543594, 106.84835324241898)/4\n'
#  'Timur/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kebon/NNP/B-LOC/Place-Arg/(-0.5742377787510939, 101.9915417000183)/4\n'
#  'Baru/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Bukit/NNP/B-LOC/Place-Arg/(-6.221337778341242, 106.85811906630207)/4\n'
#  'Duri/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Balekambang/NNP/B-LOC/Place-Arg/(-6.281549654594483, 106.85272309431423)/4\n'
#  ',/,/O/O\n'
#  'Cililitan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4\n'
#  ',/,/O/O\n'
#  'Bidara/NNP/B-LOC/Place-Arg/(-6.217169337559462, 106.8611143840193)/4\n'
#  'Cina/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kampung/NNP/B-LOC/Place-Arg/(-3.220507894108893, 107.64114141584496)/4\n'
#  'Melayu/NNP/I-LOC/Place-Arg\n'
#  'dan/CC/O/O\n'
#  'Manggarai/NNP/B-LOC/Place-Arg/(-6.213525657107193, 106.85105464595664)/4\n'
#  '\n'
#  'Badan/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Penanggulangan/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Bencana/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Daerah/NNP/I-ORG/OfficerOfficial-Arg\n'
#  '(/OP/O/O\n'
#  'BPBD/NNP/B-ORG/OfficerOfficial-Arg\n'
#  ')/CP/O/O\n'
#  'DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  'Jakarta/NNP/I-PLOC/Place-Arg\n'
#  'meminta/VBT/O/O\n'
#  'para/DT/O/O\n'
#  'pengguna/NN/O/O\n'
#  'jalan/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'akan/MD/O/O\n'
#  'menuju/VB/O/O\n'
#  'Kalibata/NNP/B-PLOC/Place-Arg/(-6.263338194185572, 106.83763416323916)/4\n'
#  'untuk/IN/O/O\n'
#  'menghindari/VBT/O/O\n'
#  'Jalan/NN/B-ARG/Place-Arg\n'
#  'Dewi/NNP/I-ARG/Place-Arg\n'
#  'Sartika/NNP/I-ARG/Place-Arg\n'
#  'dikarenakan/VB/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  '\n'
#  '"/"/O/O\n'
#  'Dihimbau/NNP/O/O\n'
#  'untuk/IN/O/O\n'
#  'para/DT/O/O\n'
#  'pengguna/NN/O/O\n'
#  'jalan/NN/O/O\n'
#  'yg/NNP/O/O\n'
#  'ingin/RB/O/O\n'
#  'menuju/VB/O/O\n'
#  'ke/IN/O/O\n'
#  'Kalibata/SC/O/O\n'
#  'raya/JJ/O/O\n'
#  ',/,/O/O\n'
#  'hindari/IN/O/O\n'
#  'jalan/NN/B-ARG/Place-Arg\n'
#  'dewi/JJ/I-ARG/Place-Arg\n'
#  'sartika/NN/I-ARG/Place-Arg\n'
#  'karena/IN/O/O\n'
#  'saat/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'kondisi/NN/O/O\n'
#  'macet/NN/O/O\n'
#  'dikarenakan/VB/O/O\n'
#  'terdampak/IN/O/O\n'
#  'banjir/NN/B-EVE/FLOOD-EVENT\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kicau/NN/O/O\n'
#  'BPBD/NN/B-ORG\n'
#  'DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1\n'
#  'Jakarta/NNP/I-PLOC\n'
#  '\n'
#  '===\n'
#  'Bus/NN/O/O\n'
#  'Angkut/NN/O/O\n'
#  'Rombongan/NN/O/O\n'
#  'Guru/NN/O/O\n'
#  'TK/NNP/B-ORG/O\n'
#  'Terguling/NNP/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'Blitar/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  ',/,/O/O\n'
#  '5/CD/B-ARG/DeathVictim-Arg\n'
#  'Orang/NN/I-ARG/DeathVictim-Arg\n'
#  'Tewas/JJ/I-ARG/DeathVictim-Arg\n'
#  'KOMPAS/NNP/B-ORG/DeathVictim-Arg\n'
#  'com/FW/O/O\n'
#  '-/-/O/O\n'
#  'Sebuah/NND/O/O\n'
#  'bus/NN/O/O\n'
#  'pariwisata/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'mengangkut/VBT/O/O\n'
#  'rombongan/NN/O/O\n'
#  'guru/NN/O/O\n'
#  'pengawas/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'kepala/NN/B-ORG/O\n'
#  'sekolah/NN/I-ORG/O\n'
#  'taman/NN/I-ORG/O\n'
#  'kanak/NNP/I-ORG/O\n'
#  '-/-/I-ORG/O\n'
#  'kanak/NN/I-ORG/O\n'
#  'asal/NN/O/O\n'
#  'Kabupaten/NNP/B-PLOC/Place-Arg/(-8.100725299843663, 111.89695787221875)/2\n'
#  'Tulungagung/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Jawa/NNP/B-PLOC/Place-Arg/(-7.593465864949647, 112.53030664912593)/1\n'
#  'Timur/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'terguling/VBT/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'jembatan/NN/O/O\n'
#  ',/,/O/O\n'
#  'Kecamatan/NNP/B-LOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3\n'
#  'Kesamben/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  'Blitar/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Sabtu/NNP/B-ARG/Time-Arg\n'
#  '(/OP/O/O\n'
#  '7/12/2019/DD/B-ARG/Time-Arg\n'
#  ')./CP/O/O\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT\n'
#  'mengakibatkan/VBT/O/O\n'
#  'lima/CDP/B-ARG/DeathVictim-Arg\n'
#  'penumpang/NN/I-ARG/DeathVictim-Arg\n'
#  'dunia/VBI/I-ARG/DeathVictim-Arg\n'
#  '\n'
#  'Sementara/CC/O/O\n'
#  'penumpang/NN/O/O\n'
#  'lainnya/NNG/O/O\n'
#  'luka/NN/B-ARG\n'
#  '-/-/O/O\n'
#  'luka/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Total/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'dibawa/VB/O/O\n'
#  'ke/IN/O/O\n'
#  'RS/NN/B-ORG/Hospital-Arg\n'
#  'di/IN/O/O\n'
#  'Wlingi/NNP/B-LOC/Place-Arg/(-8.051630070562203, 112.35484978736103)/3\n'
#  '(/OP/O/O\n'
#  'RSUD/NN/B-ORG/Hospital-Arg\n'
#  'Ngudi/NN/I-ORG/Hospital-Arg\n'
#  'Waluyo/NN/I-ORG/Hospital-Arg\n'
#  'Blitar/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  ')/CP/O/O\n'
#  'ada/VBI/O/O\n'
#  '29/CD/B-ARG/WoundVictim-Arg\n'
#  'penumpang/NN/I-ARG/WoundVictim-Arg\n'
#  ',/,/O/O\n'
#  'sedangkan/CC/O/O\n'
#  'yang/SC/O/O\n'
#  'dunia/VBI/O/O\n'
#  'ada/VBI/O/O\n'
#  'lima/CDP/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'Direktur/NNP/O/O\n'
#  'RSUD/NNP/B-ORG/Hospital-Arg\n'
#  'Ngudi/NNP/I-ORG/Hospital-Arg\n'
#  'Waluyo/NNP/I-ORG/Hospital-Arg\n'
#  'Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  'Blitar/NNP/I-PLOC/Place-Arg\n'
#  'Endah/NNP/O/O\n'
#  'Woro/NNP/O/O\n'
#  'saat/SC/O/O\n'
#  'dikonfirmasi/VB/O/O\n'
#  ',/,/O/O\n'
#  'Sabtu/NNP/B-ARG/Time-Arg\n'
#  '\n'
#  'Dari/IN/O/O\n'
#  'lima/CDP/B-ARG/DeathVictim-Arg\n'
#  'orang/NN/I-ARG/DeathVictim-Arg\n'
#  'yang/SC/O/O\n'
#  'dunia/VBI/O/O\n'
#  'itu/DT/O/O\n'
#  ',/,/O/O\n'
#  'empat/CDP/O/O\n'
#  'di/IN/O/O\n'
#  'antaranya/NNG/O/O\n'
#  'warga/NN/O/O\n'
#  'Tulungagung/NNP/B-PLOC/Place-Arg/(-8.100725299843663, 111.89695787221875)/2\n'
#  ',/,/O/O\n'
#  'yakni/SC/O/O\n'
#  'Siti/NNP/O/O\n'
#  'Fatimah/NNP/O/O\n'
#  '(/OP/O/O\n'
#  '50/CDP/O/O\n'
#  ')/CP/O/O\n'
#  'warga/NN/O/O\n'
#  'Kecamatan/NNP/B-LOC/Place-Arg/(-7.6816479869417575, 111.95147258443662)/3\n'
#  'Gondang/NNP/I-PLOC\n'
#  ',/,/O/O\n'
#  'Anita/NNP/O/O\n'
#  '(/OP/O/O\n'
#  '46/CDP/O/O\n'
#  ')/CP/O/O\n'
#  'dan/NNP/O/O\n'
#  'Naksabandi/NNP/O/O\n'
#  '(/OP/O/O\n'
#  '58/CDP/O/O\n'
#  ')/CP/O/O\n'
#  'warga/NN/O/O\n'
#  'Desa/NN/B-LOC/Place-Arg/(-7.599752631403001, 111.22406242485857)/4\n'
#  'Balerejo/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kecamatan/NNP/B-PLOC/Place-Arg/(-7.956801805592932, 111.6170370314397)/3\n'
#  'Kauman/NNP/I-PLOC\n'
#  ',/,/O/O\n'
#  'lalu/VB/O/O\n'
#  'Kasihatin/NN/O/O\n'
#  'kepala/NN/B-ORG/DeathVictim-Arg\n'
#  'sekolah/NN/I-ORG/DeathVictim-Arg\n'
#  'TK/NNP/I-ORG/DeathVictim-Arg\n'
#  'Perwari/NNP/I-ORG/DeathVictim-Arg\n'
#  '\n'
#  'Seorang/NND/O/O\n'
#  'korban/NN/O/O\n'
#  'lagi/RB/O/O\n'
#  'adalah/VBT/O/O\n'
#  'Ridwan/NN/O/O\n'
#  '(/OP/O/O\n'
#  '75/CD/O/O\n'
#  ')/CP/O/O\n'
#  'warga/NN/O/O\n'
#  'Dusun/NN/O/O\n'
#  'Sembung/NNP/O/O\n'
#  ',/,/O/O\n'
#  'Desa/NN/B-LOC/Place-Arg/(-7.367510587106552, 110.1416622395258)/4\n'
#  'Pagergunung/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kecamatan/NNP/B-PLOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3\n'
#  'Kesamben/NNP/I-PLOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  'Blitar/NNP/I-PLOC/Place-Arg\n'
#  '\n'
#  'Kepala/NN/B-ORG/OfficerOfficial-Arg\n'
#  'Unit/NN/I-ORG/OfficerOfficial-Arg\n'
#  'Laka/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Lantas/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Polres/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Blitar/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  'Ipda/NNP/B-ORG/OfficerOfficial-Arg\n'
#  'Didik/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'Sugianto/NNP/I-ORG/OfficerOfficial-Arg\n'
#  'mengatakan/VB/O/O\n'
#  ',/,/O/O\n'
#  'seluruh/CDI/O/O\n'
#  'korban/NN/O/O\n'
#  'telah/MD/O/O\n'
#  'dievakuasi/VBT/O/O\n'
#  'ke/IN/O/O\n'
#  'rumah/NN/O/O\n'
#  'sakit/NN/O/O\n'
#  '\n'
#  '"/"/O/O\n'
#  'Saat/NN/O/O\n'
#  'ini/PR/O/O\n'
#  'para/DT/O/O\n'
#  'korban/NN/O/O\n'
#  'kami/PRP/O/O\n'
#  'evakuasi/NN/O/O\n'
#  ',/,/O/O\n'
#  'dibawa/VB/O/O\n'
#  'ke/IN/O/O\n'
#  'rumah/NN/O/O\n'
#  'sakit/NN/O/O\n'
#  '\n'
#  'Kendaraan/NN/O/O\n'
#  'juga/RB/O/O\n'
#  'masih/MD/O/O\n'
#  'proses/NN/O/O\n'
#  'evakuasi/NN/O/O\n'
#  'berlanjut/VBI/O/O\n'
#  ',/,/O/O\n'
#  '"/"/O/O\n'
#  'kata/VB/O/O\n'
#  'Didik/NNP/O/O\n'
#  'Sugianto/NNP/O/O\n'
#  '\n'
#  'Rombongan/NN/O/O\n'
#  'bus/NN/O/O\n'
#  'pariwisata/NN/O/O\n'
#  'yang/SC/O/O\n'
#  'mengangkut/VBT/O/O\n'
#  'guru/NN/O/O\n'
#  'pengawas/NN/O/O\n'
#  'dan/CC/O/O\n'
#  'kepala/NN/B-ORG/OfficerOfficial-Arg\n'
#  'sekolah/NN/I-ORG/OfficerOfficial-Arg\n'
#  'TK/NN/I-ORG/OfficerOfficial-Arg\n'
#  'asal/NN/O/O\n'
#  'Kabupaten/NNP/B-PLOC/Place-Arg/(-8.100725299843663, 111.89695787221875)/2\n'
#  'Tulungagung/NNP/I-PLOC\n'
#  'itu/DT/O/O\n'
#  'rencananya/NNG/O/O\n'
#  'akan/MD/O/O\n'
#  'menghabiskan/VBT/O/O\n'
#  'akhir/NN/O/O\n'
#  'pekan/NN/O/O\n'
#  'ke/IN/O/O\n'
#  'Pasuruan/NNP/B-PLOC/Place-Arg/(-7.648002139031701, 112.90464400847651)/2\n'
#  '\n'
#  'Bus/NN/O/O\n'
#  'terguling/VBI/B-EVE/ACCIDENT-EVENT\n'
#  'di/IN/O/O\n'
#  'jalan/NN/B-ARG/Place-Arg\n'
#  'raya/JJ/I-ARG/Place-Arg\n'
#  'Kesamben/NNP/B-LOC/Place-Arg/(-7.740079910506011, 112.3505905988675)/3\n'
#  ',/,/O/O\n'
#  'tepatnya/RB/O/O\n'
#  'sebelah/NN/O/O\n'
#  'timur/NN/O/O\n'
#  'SPBU/NNP/B-ORG/Place-Arg\n'
#  'Kesamben/NNP/B-LOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3\n'
#  ',/,/O/O\n'
#  'sekitar/CDI/O/O\n'
#  'pukul/NN/B-ARG/Time-Arg\n'
#  '06.30/JJ/I-ARG/Time-Arg\n'
#  'WIB/NNP/I-ARG/Time-Arg\n'
#  '\n'
#  'Lokasi/NN/O/O\n'
#  'kecelakaan/NN/B-EVE/ACCIDENT-EVENT/ACCIDENT-EVENT\n'
#  'juga/RB/O/O\n'
#  'dekat/JJ/O/O\n'
#  'jembatan/NN/O/O\n'
#  'di/IN/O/O\n'
#  'Kecamatan/NNP/B-LOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3\n'
#  'Kesamben/NNP/I-LOC/Place-Arg\n'
#  ',/,/O/O\n'
#  'Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2\n'
#  'Blitar/NNP/I-PLOC/Place-Arg\n'
#  '\n'
#  '===')

# %% [markdown]
# Replace "PLOC" with "LOC" because "PLOC" indicates pseudo-location for the data owner's methodology.
# Pseudo location is used to mark location which is not the actual location.

# %%
replaced_ploc = file_contents.replace("PLOC", "LOC")

# %%
type(file_contents)
# Out:
# str

# %% [markdown]
# Each document is splitted by "===" in the text file, so in order to get the documents in an array we need to split them.

# %%
documents = file_contents.split("===")
type(documents)
# Out:
# list

# %%
documents
# Out:
# ['Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\nJerry/NNP/O/O\nWong/NNP/O/O\nPengemudi/NNP/O/O\nMini/NNP/B-ARG/Vehicle-Arg\nCooper/NNP/I-ARG/Vehicle-Arg\ndi/IN/O/O\nRSCM/NN/B-ORG/Hospital-Arg\n-/-/O/O\n-/NNP/O/O\nJakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1\n-/-/O/O\nJenazah/NNP/O/O\nJerry/NNP/O/O\nWong/NNP/O/O\n,/,/O/O\npengemudi/NN/O/O\nMini/NNP/B-ARG/Vehicle-Arg\nCooper/NNP/I-ARG/Vehicle-Arg\nyang/SC/O/O\nmenabrak/VBT/B-EVE/ACCIDENT-EVENT\nbagian/O/O\nbelakang/NN/O/O\ntruk/NN/B-ARG/Vehicle-Arg\n,/,/O/O\nkini/RB/O/O\nberada/VBI/O/O\ndi/IN/O/O\n
# 2  \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3  \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4  \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
#
#   Fire_Event Flood_Event Earthquake_Event
# 0
# 1
# 2
# 3
# 4

# %%
def check_event_types(row):
    accident_key = "ACCIDENT-EVENT"
    fire_key = "FIRE-EVENT"
    flood_key = "FLOOD-EVENT"
    earthquake_key = "QUAKE-EVENT"
    document = row['Document']
    if accident_key in document:
        row['Accident_Event'] = True
    if fire_key in document:
        row['Fire_Event'] = True
    if flood_key in document:
        row['Flood_Event'] = True
    if earthquake_key in document:
        row['Earthquake_Event'] = True
    return row

# %%
df.apply(check_event_types, axis=1)
# Out:
#                                              Document Accident_Event  \
# 0   Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...           True
# 1   \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2   \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3   \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4   \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...           True
# ..                                                ...            ...
# 79  \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80  \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81  \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82  \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...           True
# 83
#
#    Fire_Event Flood_Event Earthquake_Event
# 0
# 1        True
# 2                                     True
# 3                                     True
# 4
# ..        ...         ...              ...
# 79                                    True
# 80                   True
# 81                   True
# 82
# 83
#
# [84 rows x 5 columns]

# %%
df = df.fillna(False)
df
# Out:
#                                              Document Accident_Event  \
# 0   Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...
# 1   \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2   \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3   \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4   \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
# ..                                                ...            ...
# 79  \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80  \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81  \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82  \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...
# 83
#
#    Fire_Event Flood_Event Earthquake_Event
# 0
# 1
# 2
# 3
# 4
# ..        ...         ...              ...
# 79
# 80
# 81
# 82
# 83
#
# [84 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Document          84 non-null     object
#  1   Accident_Event    84 non-null     object
#  2   Fire_Event        84 non-null     object
#  3   Flood_Event       84 non-null     object
#  4   Earthquake_Event  84 non-null     object
# dtypes: object(5)
# memory usage: 3.4+ KB

# %%
true_counts = df.apply(lambda x: x.astype(bool).sum())
print(true_counts)
# Out:
# Document            83
# Accident_Event       0
# Fire_Event           0
# Flood_Event          0
# Earthquake_Event     0
# dtype: int64

# %% [markdown]
# # Embedding

# %%
# NLTK
from nltk.tokenize import sent_tokenize, word_tokenize

# Warnings
import warnings
warnings.filterwarnings(action='ignore')

# Word2Vec
import gensim
from gensim.models import Word2Vec

# JSON
import json

# OS
import os

# %%
# Function to get text data from JSON
def extract_text_from_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
        content = data['content']
        # Pre-process data 
    return content

# Function to traverse `newspapers` folder & extract each JSON files
def extract_text_from_json_files(root_dir):
    text_data = []
    for subdir, dirs, files in os.walk(root_dir):
        for file in files:
            file_path = os.path.join(subdir, file)
            if file_path.endswith('.json'):
                text_data.append(extract_text_from_json(file_path))
    return text_data

# %%
# Indonesian News Dataset 2018 as Corpus 
# https://huggingface.co/datasets/indonesian-nlp/id_newspapers_2018/tree/main

root_directory = '/Users/azurast/Downloads/newspapers/json'
text_data = extract_text_from_json_files(root_directory)

# %%
text_data
# Out:
# []

# %%
# Tokenize the text data
tokenized_data = [gensim.utils.simple_preprocess(text) for text in text_data]

# %%
# Train the Word2Vec model
# model = Word2Vec(tokenized_data, vector_size=100, window=5, min_count=5, workers=4)

# %%
# Save the trained model
#model.save('indonesian_newspapers_word2vec.model')

# %%
# 1. Let's see the word embedding for "kebakaran" by accessing the "wv" attribute and passing in "kebakaran" as the key.
model = Word2Vec.load('my_model_indonesian_newspapers_word2vec.model')
print("Embedding for kebakaran:", model.wv["kebakaran"])
# Out:
# Embedding for kebakaran: [-0.11402367  0.37845838 -0.10772562 -0.13374746  0.04284624 -0.4803884
#   0.24623325  0.70485073 -0.15914932 -0.22895694 -0.02735815 -0.49519628
#  -0.17123197  0.0778406   0.12902541 -0.1309303   0.14402567 -0.3005387
#  -0.10067452 -0.6012565   0.07891174  0.18998279  0.39396274 -0.00951392
#  -0.16941355  0.05007969 -0.3464864  -0.15260598 -0.3600642   0.0784976
#   0.477373    0.03955512  0.24122703 -0.2837372  -0.3004585   0.42481065
#   0.12425724 -0.12694457 -0.07098845 -0.41624826 -0.03917486 -0.20446767
#  -0.11558851  0.10804968  0.451089    0.02398587 -0.33546603 -0.07152762
#   0.13858435  0.21837054  0.14388753 -0.27416983 -0.13308528 -0.27555966
#  -0.3208372   0.02202458  0.20332256 -0.05704811 -0.36412022  0.10308675
#   0.02870579  0.10630788  0.06790478 -0.1164986  -0.56474173  0.1377047
#   0.16009648  0.2849244  -0.5242075   0.25276956 -0.24397208  0.09804486
#   0.20336673 -0.14771955  0.271215    0.11228774 -0.00281903 -0.10425534
#  -0.3532008   0.09768607 -0.18656392 -0.16863212 -0.15894063  0.5201981
#  -0.07710415  0.19205374  0.08557902  0.50150126  0.4815885  -0.06829674
#   0.48339584  0.269162    0.1070343   0.06969362  0.5252481   0.41484514
#   0.08031651 -0.35870773  0.09153578 -0.07104719]

# %%
# 2. Inspect the model vocabulary by accessing keys of the "wv.index_to_key" attribute. We'll print the first 20 words.
print("Vocabulary length:", len(model.wv))
print("Check first 20 vocab:", model.wv.index_to_key[:20])
# Out:
# Vocabulary length: 578
# Check first 20 vocab: [',', 'di', '-', 'yang', '"', 'dan', '(', ')', 'Jakarta', 'ini', 'dari', 'rumah', 'ke', 'ada', 'itu', 'terjadi', 'air', 'warga', 'banjir', 'korban']

# %% [markdown]
# ## Train Test Split

# %%
df
# Out:
#                                              Document Accident_Event  \
# 0   Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...
# 1   \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2   \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3   \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4   \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
# ..                                                ...            ...
# 79  \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80  \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81  \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82  \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...
# 83
#
#    Fire_Event Flood_Event Earthquake_Event
# 0
# 1
# 2
# 3
# 4
# ..        ...         ...              ...
# 79
# 80
# 81
# 82
# 83
#
# [84 rows x 5 columns]

# %%
df['Event_Type'] = ''
df
# Out:
#                                              Document Accident_Event  \
# 0   Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...
# 1   \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2   \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3   \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4   \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
# ..                                                ...            ...
# 79  \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80  \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81  \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82  \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...
# 83
#
#    Fire_Event Flood_Event Earthquake_Event EventType Event_Type
# 0
# 1
# 2
# 3
# 4
# ..        ...         ...              ...       ...        ...
# 79
# 80
# 81
# 82
# 83
#
# [84 rows x 7 columns]

# %%
def fill_event_type(row):
    if row['Accident_Event'] == True:
        row['Event_Type'] = "Accident"
    if row['Fire_Event'] == True:
        row['Event_Type'] = "Fire"
    if row['Flood_Event'] == True:
        row['Event_Type'] = "Flood"
    if row['Earthquake_Event'] == True:
        row['Event_Type'] = "Earthquake"
    return row

# %%
df = df.apply(fill_event_type, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Document          84 non-null     object
#  1   Accident_Event    84 non-null     object
#  2   Fire_Event        84 non-null     object
#  3   Flood_Event       84 non-null     object
#  4   Earthquake_Event  84 non-null     object
#  5   EventType         84 non-null     object
#  6   Event_Type        84 non-null     object
# dtypes: object(7)
# memory usage: 4.7+ KB

# %%
df[df['Event_Type'].isna()]
# Out:
# Empty DataFrame
# Columns: [Document, Accident_Event, Fire_Event, Flood_Event, Earthquake_Event, EventType, Event_Type]
# Index: []

# %%
df = df.fillna("")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Document          84 non-null     object
#  1   Accident_Event    84 non-null     object
#  2   Fire_Event        84 non-null     object
#  3   Flood_Event       84 non-null     object
#  4   Earthquake_Event  84 non-null     object
#  5   EventType         84 non-null     object
#  6   Event_Type        84 non-null     object
# dtypes: object(7)
# memory usage: 4.7+ KB

# %%
pos_document_list = df['Document'].tolist()
tokenized_data = []
tokenized_documents = []

for document in pos_document_list:
    lines = document.split('\n')
    document_tokens = []
    for line in lines:
        print("line", line)
        # Skip empty line
        if line.strip() == '':
            continue
        # Split each line by the delimiter    
        parts = line.strip().split("/")
        word = parts[0]
        document_tokens.append(word)
    tokenized_data.append(document_tokens)

print(tokenized_data)
# Out:
# line Kerabat/NNP/O/O
# line Layat/NNP/O/O
# line Jasad/NNP/O/O
# line Jerry/NNP/O/O
# line Wong/NNP/O/O
# line Pengemudi/NNP/O/O
# line Mini/NNP/B-ARG/Vehicle-Arg
# line Cooper/NNP/I-ARG/Vehicle-Arg
# line di/IN/O/O
# line RSCM/NN/B-ORG/Hospital-Arg
# line -/-/O/O
# line -/NNP/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Jenazah/NNP/O/O
# line Jerry/NNP/O/O
# line Wong/NNP/O/O
# line ,/,/O/O
# line pengemudi/NN/O/O
# line Mini/NNP/B-ARG/Vehicle-Arg
# line Cooper/NNP/I-ARG/Vehicle-Arg
# line yang/SC/O/O
# line menabrak/VBT/B-EVE/ACCIDENT-EVENT
# line bagian/O/O
# line belakang/NN/O/O
# line truk/NN/B-ARG/Vehicle-Arg
# line ,/,/O/O
# line kini/RB/O/O
# line berada/VBI/O/O
# line di/IN/O/O
# line RSCM/NNP/B-ORG/Hospital-Arg
# line
# line Sekitar/CDI/O/O
# line 15/CDP/O/O
# line kerabat/NN/O/O
# line dan/CC/O/O
# line teman/NN/O/O
# line datang/VBI/O/O
# line melayat/VBT/O/O
# line
# line Pantauan/IN/O/O
# line detikcom/NN/B-ORG/Reporter-Arg
# line di/IN/O/O
# line kamar/NN/O/O
# line jenazah/NN/O/O
# line RSCM/NNP/B-ORG/Hospital-Arg
# line ,/,/O/O
# line Jalan/NN/B-ARG/Street-Arg
# line Salemba/NNP/I-ARG/Street-Arg
# line ,/,/O/O
# line Jakarta/NNP/B-PLOC/Place-Arg/(-6.1780125136691195, 106.83773321392438)/2
# line Pusat/NNP/I-PLOC/Place-Arg
# line ,/,/O/O
# line Jumat/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 16/5/2014/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line ,/,/O/O
# line jasad/NN/O/O
# line Jerry/NNP/O/O
# line ditutup/VB/O/O
# line kain/NN/O/O
# line jarik/NN/O/O
# line cokelat/JJ/O/O
# line ,/,/O/O
# line dikelilingi/VBT/O/O
# line kerabatnya/NN/O/O
# line
# line Ada/VB/O/O
# line seorang/NN/O/O
# line kerabat/NN/O/O
# line Jerry/NNP/O/O
# line ,/,/O/O
# line Dodi/NN/O/O
# line yang/SC/O/O
# line mengenang/VBT/O/O
# line Jerry/NN/O/O
# line sebagai/IN/O/O
# line orang/NN/O/O
# line yang/SC/O/O
# line baik/JJ/O/O
# line dan/CC/O/O
# line banyak/CD/O/O
# line teman/NN/O/O
# line
# line "/"/O/O
# line Jerry/NN/O/O
# line tadi/NN/O/O
# line perjalanan/NN/O/O
# line dari/IN/O/O
# line rumah/NN/O/O
# line temannya/NNG/O/O
# line ,/,/O/O
# line mau/MD/O/O
# line pulang/VBI/O/O
# line ke/IN/O/O
# line rumahnya/NN/O/O
# line di/IN/O/O
# line daerah/NN/O/O
# line Pluit/NNP/B-PLOC/To-Arg/(-6.113297962451269, 106.78672611344551)/4
# line
# line Jerry/NN/O/O
# line ini/DT/O/O
# line orangnya/NN/O/O
# line baik/JJ/O/O
# line ,/,/O/O
# line temannya/NNG/O/O
# line banyak/JJ/O/O
# line ,/,/O/O
# line kebetulan/NN/O/O
# line saya/PRP/O/O
# line teman/NN/O/O
# line main/NN/O/O
# line futsal/JJ/O/O
# line di/IN/O/O
# line Kuningan/NN/B-PLOC/Place-Arg/(-6.235976199075322, 106.82213128724581)/4
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line dia/PRP/O/O
# line
# line Sedang/NN/O/O
# line kerabatnya/NN/O/O
# line lainnya/NNG/O/O
# line enggan/RB/O/O
# line memberikan/VB/O/O
# line keterangan/NN/O/O
# line
# line "/"/O/O
# line Saya/PRP/O/O
# line nggak/NN/O/O
# line tahu/VBI/O/O
# line apa/WP/O/O
# line -/-/O/O
# line apa/WP/O/O
# line ,/,/O/O
# line kami/PRP/O/O
# line sedang/RB/O/O
# line berduka/VB/O/O
# line ,/,/O/O
# line "/"/O/O
# line begitu/RB/O/O
# line pinta/NN/O/O
# line seorang/NN/O/O
# line kerabat/NN/O/O
# line
# line Mini/NN/B-ARG/Vehicle-Arg
# line Cooper/NNP/I-ARG/Vehicle-Arg
# line bernopol/VB/O/O
# line B/SYM/B-ARG/Plate-Arg
# line 226/CD/I-ARG/Plate-Arg
# line NUK/NN/I-ARG/Plate-Arg
# line yang/SC/O/O
# line dikemudikan/VBT/O/O
# line Jerry/NNP/O/O
# line Wong/NNP/O/O
# line menghantam/VBT/B-EVE/ACCIDENT-EVENT
# line keras/JJ/O/O
# line bagian/O/O
# line belakang/NN/O/O
# line truk/NN/B-ARG/Vehicle-Arg
# line wing/FW/O/O
# line box/MD/O/O
# line bernopol/VB/O/O
# line B/SYM/B-ARG/Plate-Arg
# line 9667/CDP/I-ARG/Plate-Arg
# line ZX/NN/I-ARG/Plate-Arg
# line di/IN/O/O
# line Km/NN/B-ARG/Point-Arg
# line 24+800/NN/I-ARG/Point-Arg
# line dari/IN/O/O
# line Pluit/NN/B-LOC/From-Arg/(-6.113297962451269, 106.78672611344551)/4
# line arah/NN/O/O
# line Bandara/NNP/B-ORG/To-Arg
# line Soekarno/NNP/I-ORG/To-Arg
# line -/NNP/I-ORG/To-Arg
# line Hatta/NNP/I-ORG/To-Arg
# line
# line Saking/NN/O/O
# line kerasnya/NN/O/O
# line hantaman/NN/B-EVE/ACCIDENT-EVENT
# line itu/PR/O/O
# line ,/,/O/O
# line bagian/O/O
# line depan/NN/O/O
# line Mini/NNP/B-ARG/Vehicle-Arg
# line Cooper/NNP/I-ARG/Vehicle-Arg
# line tersangkut/VBI/O/O
# line ke/IN/O/O
# line bemper/NN/O/O
# line truk/NN/B-ARG/Vehicle-Arg
# line itu/PR/O/O
# line
# line
# line
# line 1/CDP/B-ARG/DeathVictim-Arg
# line Orang/NN/I-ARG/DeathVictim-Arg
# line Tewas/JJ/I-ARG/DeathVictim-Arg
# line ,/,/O/O
# line 125/CD/B-ARG/Evacuee-Arg
# line Ribu/CD/I-ARG/Evacuee-Arg
# line Warga/NN/I-ARG/Evacuee-Arg
# line California/NNP/B-PLOC/Place-Arg/(37.84576308242729, -120.72746695681695)/1
# line Mengungsi/VBI/B-EVE/EVACUATE-EVENT
# line akibat/IN/O/O
# line Kebakaran/NN/B-EVE/FIRE-EVENT
# line -/-/O/O
# line -/NNP/O/O
# line California/NNP/B-PLOC/Published-Arg/(37.84576308242729, -120.72746695681695)/1
# line -/-/O/O
# line Kebakaran/NN/B-EVE/FIRE-EVENT
# line hutan/NN/I-EVE/FIRE-EVENT
# line yang/SC/O/O
# line menerjang/VBT/O/O
# line wilayah/NN/O/O
# line California/NNP/B-PLOC/Place-Arg/(37.84576308242729, -120.72746695681695)/1
# line ,/,/O/O
# line Amerika/NNP/B-PLOC/Place-Arg/(38.4572641110912, -92.2110028043666)/0
# line Serikat/NNP/I-PLOC/Place-Arg
# line memaksa/VBT/O/O
# line 125/CDP/B-ARG/Evacuee-Arg
# line ribu/CDP/I-ARG/Evacuee-Arg
# line warga/NN/O/O
# line untuk/SC/O/O
# line mengungsi/VBI/B-EVE/EVACUATE-EVENT
# line
# line Dilaporkan/VBT/O/O
# line sedikitnya/NNG/O/O
# line satu/CDP/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line akibat/IN/O/O
# line kebakaran/NN/B-EVE/FIRE-EVENT
# line ini/PR/O/O
# line
# line Ada/NN/O/O
# line sembilan/CDP/B-ARG/Point-Arg
# line titik/NN/I-ARG/Point-Arg
# line api/NN/B-EVE/FIRE-EVENT
# line yang/SC/O/O
# line terus/RB/O/O
# line bergerak/VBI/O/O
# line di/IN/O/O
# line wilayah/NN/O/O
# line Southern/NNP/B-PLOC/Place-Arg/(37.84576308242729, -120.72746695681695)/5
# line California/NNP/I-PLOC/Place-Arg
# line dan/CC/O/O
# line mengancam/VBT/O/O
# line pemukiman/NN/B-ARG/Facility-Arg
# line warga/NN/I-ARG/Facility-Arg
# line yang/SC/O/O
# line ada/VBI/O/O
# line di/IN/O/O
# line San/NNP/B-LOC/Place-Arg/(33.135, -117.1743)/5
# line Marcos/NNP/I-LOC/Place-Arg
# line dan/CC/O/O
# line Escondido/NNP/B-LOC/Place-Arg/(33.1347, -117.0723)/5
# line ,/,/O/O
# line distrik/NN/O/O
# line San/NNP/B-PLOC/Place-Arg/(32.8312, -117.1225)/5
# line Diego/NNP/I-PLOC/Place-Arg
# line
# line Sebuah/NN/O/O
# line rumah/NN/O/O
# line yang/SC/O/O
# line cukup/RB/O/O
# line besar/JJ/O/O
# line milik/NN/O/O
# line warga/NN/O/O
# line setempat/NN/O/O
# line di/IN/O/O
# line pinggiran/NN/O/O
# line San/NNP/B-LOC/Place-Arg/(33.135, -117.1743)/5
# line Marcos/NNP/I-LOC/Place-Arg
# line habis/RB/O/O
# line dilalap/VBT/B-EVE/FIRE-EVENT
# line api/NN/I-EVE/FIRE-EVENT
# line
# line Tayangan/NN/O/O
# line televisi/NN/O/O
# line setempat/NN/O/O
# line menunjukkan/VB/O/O
# line bagaiman/IN/O/O
# line kobaran/NN/B-EVE/FIRE-EVENT
# line api/NN/I-EVE/FIRE-EVENT
# line bergerak/VBI/O/O
# line cepat/JJ/O/O
# line mendekati/VB/O/O
# line rumah/NN/O/O
# line warga/NN/O/O
# line ,/,/O/O
# line sementara/CC/O/O
# line warga/NN/O/O
# line bergegas/VBI/O/O
# line mengevakuasi/VBT/B-EVE/EVACUATE-EVENT
# line barang/NN/O/O
# line -/-/O/O
# line barangnya/NN/O/O
# line dan/CC/O/O
# line mengungsi/VBI/B-EVE/EVACUATE-EVENT
# line dari/IN/O/O
# line lokasi/NN/O/O
# line
# line Demikian/PR/O/O
# line seperti/IN/O/O
# line dilansir/VBT/O/O
# line Reuters/NN/B-ORG/Reporter-Arg
# line ,/,/O/O
# line Jumat/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 16/5/2014/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line
# line
# line Analisis/NNP/O/O
# line BMKG/NNP/B-ORG/Reporter-Arg
# line soal/IN/O/O
# line Gempa/NNP/B-EVE/QUAKE-EVENT
# line Lebak/NNP/B-LOC/Place-Arg/(-6.585671253448132, 106.20907658148096)/2
# line 5,1/CD/B-ARG/Strength-Arg
# line SR/NN/B-ARG/Strength-Arg
# line -/-/O/O
# line -/NNP/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line berkekuatan/VBI/B-ARG/Strength-Arg
# line 5,1/CD/I-ARG/Strength-Arg
# line Skala/NN/I-ARG/Strength-Arg
# line Richter/NNP/I-ARG/Strength-Arg
# line (/OP/O/O
# line SR/NNP/O/O
# line )/CP/O/O
# line mengguncang/VBT/B-EVE/QUAKE-EVENT
# line kawasan/NN/O/O
# line Lebak/NNP/B-LOC/Place-Arg/(-6.585671253448132, 106.20907658148096)/2
# line ,/,/O/O
# line Banten/NNP/B-LOC/Place-Arg/(-6.321098712338462, 106.23469405402261)/1
# line
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line dirasakan/VB/O/O
# line hingga/IN/O/O
# line Bandung/NNP/B-LOC/Place-Arg/(-7.043296715749431, 107.65469419110545)/2
# line Dampak/NN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/O/O
# line yang/SC/O/O
# line digambarkan/VB/O/O
# line oleh/IN/O/O
# line peta/NN/O/O
# line tingkat/NN/O/O
# line guncangan/NN/B-EVE/QUAKE-EVENT
# line (/OP/O/O
# line shakemap/NN/O/O
# line )/CP/O/O
# line BMKG/NNP/B-ORG/Reporter-Arg
# line dan/CC/O/O
# line laporan/NN/O/O
# line masyarakat/NN/O/O
# line menunjukkan/VB/O/O
# line bahwa/SC/O/O
# line dampak/NN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line berupa/VBT/O/O
# line guncangan/NN/B-EVE/QUAKE-EVENT
# line dirasakan/VB/O/O
# line di/IN/O/O
# line daerah/NN/O/O
# line Bayah/NN/B-LOC/Place-Arg/(-6.908602082571137, 106.28554321427342)/3
# line dan/CC/O/O
# line Cikotok/NNP/B-LOC/Place-Arg/(-6.853926442579436, 106.29481931990914)/4
# line dalam/IN/O/O
# line skala/NN/O/O
# line intensitas/NN/O/O
# line II/OD/B-ARG/Strength-Arg
# line SIG/NNP/I-ARG/Strength-Arg
# line -/-/O/O
# line BMKG/NNP/B-ORG/OfficerOfficial-Arg
# line (/OP/O/O
# line III/OD/B-ARG/Strength-Arg
# line -/-/O/O
# line IV/OD/B-ARG/Strength-Arg
# line MMI/NNP/I-ARG/Strength-Arg
# line )/CP/O/O
# line ,/,/O/O
# line Sukabumi/NNP/B-LOC/Place-Arg/(-6.936256164208697, 106.92618260828208)/2
# line dan/CC/O/O
# line Bandung/NNP/B-LOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2
# line dengan/IN/O/O
# line intensitas/NN/O/O
# line II/OD/B-ARG/Strength-Arg
# line SIG/NNP/I-ARG/Strength-Arg
# line -/-/O/O
# line BMKG/NNP/B-ORG/OfficerOfficial-Arg
# line (/OP/O/O
# line II/NNP/B-ARG/Strength-Arg
# line -/-/O/O
# line III/OD/B-ARG/Strength-Arg
# line MMI/NNP/I-ARG/Strength-Arg
# line )/CP/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line Kepala/NNP/B-ORG/OfficerOfficial-Arg
# line Pusat/NNP/I-ORG/OfficerOfficial-Arg
# line Gempa/NNP/I-ORG/OfficerOfficial-Arg
# line Bumi/NNP/I-ORG/OfficerOfficial-Arg
# line dan/CC/O/O
# line Tsunami/NN/O/O
# line BMKG/NNP/B-ORG/OfficerOfficial-Arg
# line Mochammad/NNP/O/O
# line Riyad/NNP/O/O
# line dalam/IN/O/O
# line keterangan/NN/O/O
# line tertulis/VBI/O/O
# line ,/,/O/O
# line Jumat/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 16/2/2018/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line Baca/VBI/O/O
# line juga/RB/O/O
# line :/:/O/O
# line Gempa/NNP/B-EVE/QUAKE-EVENT
# line 5,1/CD/B-ARG/Strength-Arg
# line SR/NN/I-ARG/Strength-Arg
# line Guncang/NNP/B-EVE/QUAKE-EVENT
# line Lebak/NNP/B-LOC/Place-Arg/(-6.585671253448132, 106.20907658148096)/2
# line Banten/NNP/B-LOC/Place-Arg/(-6.321098712338462, 106.23469405402261)/1
# line Berdasarkan/NNP/O/O
# line hasil/NN/O/O
# line analisis/NN/O/O
# line BMKG/NNP/B-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line itu/PR/O/O
# line merupakan/VB/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line tektonik/NN/O/O
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line itu/PR/O/O
# line terjadi/VB/O/O
# line akibat/IN/O/O
# line aktivitas/NN/O/O
# line subduksi/NN/O/O
# line lempeng/JJ/O/O
# line Indo/NNP/O/O
# line -/-/O/O
# line Australia/NNP/B-PLOC/Place-Arg/(-31.667307305686077, 138.4606196920466)/0
# line ke/IN/O/O
# line bawah/NN/O/O
# line Lempeng/NN/O/O
# line Eurasia/NNP/O/O
# line
# line
# line
# line 3/CDP/B-ARG/DeathVictim-Arg
# line Tewas/JJ/I-ARG/DeathVictim-Arg
# line Akibat/IN/O/O
# line Gempa/NNP/B-EVE/QUAKE-EVENT
# line di/IN/O/O
# line Meksiko/NNP/B-PLOC/Place-Arg/(20.893694415571684, -99.32179436716993)/0
# line dan/CC/O/O
# line Guatemala/NNP/B-PLOC/Place-Arg/(14.898340481702862, -90.81834384088687)/0
# line ,/,/O/O
# line Termasuk/VBT/O/O
# line Bayi/NN/O/O
# line Baru/NNP/O/O
# line Lahir/VBI/O/O
# line -/-/O/O
# line -/NNP/O/O
# line Mexico/NNP/B-PLOC/Published-Arg/(19.302903257396633, -99.10508326400131)/1
# line City/NNP/I-PLOC/Published-Arg
# line -/-/O/O
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line berkekuatan/VBI/B-ARG/Strength-Arg
# line 6,9/CD/I-ARG/Strength-Arg
# line Skala/NN/I-ARG/Strength-Arg
# line Richter/NNP/I-ARG/Strength-Arg
# line mengguncang/VB/B-EVE/QUAKE-EVENT/QUAKE-EVENT
# line wilayah/NN/O/O
# line Meksiko/NNP/B-LOC/Place-Arg/(20.893694415571684, -99.32179436716993)/0
# line dan/CC/O/O
# line Guatemala/NN/B-LOC/Place-Arg/(14.898340481702862, -90.81834384088687)/0
# line
# line Nahas/NNP/O/O
# line ,/,/O/O
# line sedikitnya/NNG/O/O
# line 3/CDP/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line dalam/IN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line termasuk/VB/O/O
# line salah/JJ/O/O
# line satunya/PRN/O/O
# line seorang/NN/O/O
# line bayi/NN/O/O
# line yang/SC/O/O
# line baru/JJ/O/O
# line lahir/VB/O/O
# line
# line Survei/NN/B-ORG/OfficerOfficial-Arg
# line Geologi/NNP/I-ORG/OfficerOfficial-Arg
# line AS/NNP/B-PLOC/Place-Arg/(38.4572641110912, -92.2110028043666)/0
# line (/OP/O/O
# line USGS/NNP/B-ORG/OfficerOfficial-Arg
# line )/CP/O/O
# line ,/,/O/O
# line seperti/IN/O/O
# line dilansir/VBT/O/O
# line AFP/NNP/B-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line Selasa/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 8/7/2014/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line ,/,/O/O
# line mencatat/VB/O/O
# line bahwa/SC/O/O
# line pusat/NN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line ini/DT/O/O
# line berada/VBI/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line yang/SC/O/O
# line hanya/RB/O/O
# line berjarak/VBI/O/O
# line 2/CDP/B-ARG/Central-Arg
# line kilometer/NN/I-ARG/Central-Arg
# line dari/IN/O/O
# line kota/NN/O/O
# line Puerto/NNP/B-LOC/Place-Arg/(-34.6135871,-58.3697784)/2
# line Madero/NNP/I-LOC/Place-Arg
# line dan/CC/O/O
# line berjarak/VBI/O/O
# line 200/CDP/B-ARG/Central-Arg
# line kilometer/NN/I-ARG/Central-Arg
# line dari/IN/O/O
# line Guatemala/NNP/B-LOC/Place-Arg/(14.629566162184377, -90.50339335214694)/2
# line City/NNP/I-LOC/Place-Arg
# line
# line Menurut/NNP/O/O
# line USGS/NNP/B-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line pusat/NN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line ini/DT/O/O
# line berada/VBI/O/O
# line pada/IN/O/O
# line kedalaman/NN/B-ARG/Depth-Arg
# line 60/CD/I-ARG/Depth-Arg
# line kilometer/NND/I-ARG/Depth-Arg
# line di/IN/O/O
# line bawah/NN/O/O
# line permukaan/NN/O/O
# line laut/NN/O/O
# line
# line Sekitar/CDI/O/O
# line 10/CDP/B-ARG/Repeat-Arg
# line kali/NN/I-ARG/Repeat-Arg
# line gempa/NN/B-EVE/QUAKE-EVENT
# line susulan/NN/I-EVE/QUAKE-EVENT
# line dilaporkan/VB/O/O
# line terjadi/VB/O/O
# line pasca/SC/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line 6,9/CD/B-ARG/Strength-Arg
# line SR/NN/I-ARG/Strength-Arg
# line tersebut/PR/O/O
# line melanda/VB/O/O
# line
# line Hal/NN/O/O
# line ini/PR/O/O
# line sempat/MD/O/O
# line memicu/VBT/O/O
# line kepanikan/NN/O/O
# line warga/NN/O/O
# line dan/CC/O/O
# line sayangnya/PRP/O/O
# line menyebabkan/VBT/O/O
# line tanah/NN/B-EVE/LANDSLIDE-EVENT
# line longsor/JJ/I-EVE/LANDSLIDE-EVENT
# line di/IN/O/O
# line beberapa/CDI/O/O
# line wilayah/NN/O/O
# line
# line
# line
# line Tabrak/NN/B-EVE/ACCIDENT-EVENT
# line Pembatas/NN/O/O
# line Jalan/NN/O/O
# line Km/NN/B-ARG/Point-Arg
# line 27/CD/I-ARG/Point-Arg
# line Tol/NNP/B-ARG/Street-Arg
# line Bandara/NNP/I-ARG/Street-Arg
# line ,/,/O/O
# line BMW/NN/B-ARG/Vehicle-Arg
# line Ringsek/NN/O/O
# line Berat/NN/O/O
# line -/-/O/O
# line -/NNP/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Sebuah/NND/O/O
# line mobil/NN/O/O
# line BMW/NNP/B-ARG/Vehicle-Arg
# line dengan/IN/O/O
# line nopol/NN/O/O
# line B/SYM/B-ARG/Plate-Arg
# line 54/CD/I-ARG/Plate-Arg
# line LN/NN/I-ARG/Plate-Arg
# line menabrak/VBT/B-EVE/ACCIDENT-EVENT
# line pembatas/NN/O/O
# line jalan/NN/O/O
# line Tol/NNP/B-ARG/Street-Arg
# line Bandara/NNP/I-ARG/Street-Arg
# line arah/NN/O/O
# line Jakarta/NNP/B-PLOC/To-Arg/(-6.197602429787846, 106.83139222722116)/1
# line tengah/O/O
# line malam/NN/O/O
# line ini/PR/O/O
# line
# line Kondisi/NN/O/O
# line mobil/NN/O/O
# line itu/PR/O/O
# line ringsek/JJ/O/O
# line berat/JJ/O/O
# line di/IN/O/O
# line bagian/NN/O/O
# line depan/JJ/O/O
# line
# line Informasi/NN/O/O
# line itu/PR/O/O
# line disampaikan/VB/O/O
# line TMC/NNP/O/O
# line Polda/NNP/B-ORG/OfficerOfficial-Arg
# line Metro/NN/I-ORG/OfficerOfficial-Arg
# line Jaya/NNP/I-ORG/OfficerOfficial-Arg
# line
# line BMW/NNP/B-ARG/Vehicle-Arg
# line bernomor/VBT/O/O
# line pelat/NN/O/O
# line B/SYM/B-ARG/Plate-Arg
# line 54/CD/I-ARG/Plate-Arg
# line LN/NN/I-ARG/Plate-Arg
# line itu/DT/O/O
# line menabrak/VBT/B-EVE/ACCIDENT-EVENT
# line pembatas/NN/O/O
# line jalan/NN/O/O
# line Tol/NNP/B-ARG/Street-Arg
# line Bandara/NNP/I-ARG/Street-Arg
# line di/IN/O/O
# line Km/NN/B-ARG/Point-Arg
# line 27/CD/I-ARG/Point-Arg
# line ,/,/O/O
# line tepatnya/RB/O/O
# line di/IN/O/O
# line Kamal/NNP/B-LOC/Place-Arg/(-6.101459525319878, 106.69969913010671)/4
# line mengarah/VBI/O/O
# line ke/IN/O/O
# line Pluit/NN/B-PLOC/To-Arg/(-6.113297962451269, 106.78672611344551)/4
# line pukul/NN/B-ARG/Time-Arg
# line 23.30/JJ/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line
# line Dari/IN/O/O
# line foto/NN/O/O
# line yang/SC/O/O
# line diunggah/VB/O/O
# line TMC/NNP/O/O
# line Polda/NNP/B-ORG/OfficerOfficial-Arg
# line Metro/NN/I-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line mobil/NN/O/O
# line itu/DT/O/O
# line diduga/VBT/O/O
# line berkecepatan/VBT/O/O
# line tinggi/JJ/O/O
# line saat/SC/O/O
# line menabrak/VBT/O/O
# line hingga/IN/O/O
# line mobil/NN/B-ARG/Vehicle-Arg
# line berbalik/VBI/O/O
# line ke/IN/O/O
# line arah/NN/O/O
# line berlawanan/VBI/O/O
# line
# line Bagian/NN/O/O
# line depannya/NN/O/O
# line tampak/VB/O/O
# line ringsek/JJ/O/O
# line berat/JJ/O/O
# line
# line Ban/NN/O/O
# line mobil/NN/B-ARG/Vehicle-Arg
# line depan/NN/O/O
# line sebelah/NN/O/O
# line kiri/NN/O/O
# line juga/RB/O/O
# line terlihat/VB/O/O
# line lepas/JJ/O/O
# line
# line
# line
# line Kebakaran/NN/B-EVE/FIRE-EVENT
# line Hanguskan/NNP/O/O
# line Kantor/NNP/B-ORG/Facility-Arg
# line Redaksi/NNP/I-ORG/Facility-Arg
# line Pikiran/NNP/I-ORG/Facility-Arg
# line Rakyat/NNP/I-ORG/Facility-Arg
# line -/NNP/O/O
# line -/-/O/O
# line Bandung/NNP/B-PLOC/Published-Arg/(-6.920669331867579, 107.62893793140472)/2
# line ,/,/O/O
# line -/-/O/O
# line Kebakaran/NN/B-EVE/FIRE-EVENT
# line melanda/VB/O/O
# line kantor/NN/B-ORG/Facility-Arg
# line redaksi/NN/I-ORG/Facility-Arg
# line koran/NN/I-ORG/Facility-Arg
# line Pikiran/NNP/I-ORG/Facility-Arg
# line Rakyat/NNP/I-ORG/Facility-Arg
# line di/IN/O/O
# line Jalan/NN/B-ARG/Street-Arg
# line Soekarno/NNP/I-ARG/Street-Arg
# line Hatta/NNP/I-ARG/Street-Arg
# line ,/,/O/O
# line Bandung/NNP/B-LOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2
# line
# line Belum/NEG/O/O
# line diketahui/VBT/O/O
# line penyebab/NN/O/O
# line insiden/NN/O/O
# line tersebut/PR/O/O
# line
# line Petugas/NN/B-ORG/OfficerOfficial-Arg
# line pemadam/NN/I-ORG/OfficerOfficial-Arg
# line sudah/MD/O/O
# line berada/VBI/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line kejadian/NN/O/O
# line
# line Kapolrestabes/NN/B-ORG/OfficerOfficial-Arg
# line Bandung/NNP/B-PLOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2
# line Kombes/NNP/B-ORG/OfficerOfficial-Arg
# line Pol/NNP/I-ORG/OfficerOfficial-Arg
# line Mashudi/NNP/I-ORG/OfficerOfficial-Arg
# line mengatakan/VB/O/O
# line peristiwa/NN/O/O
# line kebakaran/NN/B-EVE/FIRE-EVENT
# line berlangsung/VBI/O/O
# line sekitar/CDI/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 06.00/JJ/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line ,/,/O/O
# line Sabtu/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 4/10/2014/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line "/"/O/O
# line Api/NN/B-EVE/FIRE-EVENT
# line diduga/VBT/O/O
# line mulai/MD/O/O
# line muncul/VB/O/O
# line di/IN/O/O
# line lantai/NN/O/O
# line dua/CDP/O/O
# line ,/,/O/O
# line "/"/O/O
# line ucap/VB/O/O
# line Mashudi/NN/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line kejadian/NN/O/O
# line
# line Pantauan/NN/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line pada/IN/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 08.25/CD/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line ,/,/O/O
# line kondisi/NN/O/O
# line api/NN/B-EVE/FIRE-EVENT
# line sudah/MD/O/O
# line padam/IN/O/O
# line
# line Petugas/NN/B-ORG/OfficerOfficial-Arg
# line Dinas/NN/I-ORG/OfficerOfficial-Arg
# line Pencegahan/NN/I-ORG/OfficerOfficial-Arg
# line Kebakaran/NN/I-ORG/OfficerOfficial-Arg
# line (/OP/O/O
# line Diskar/NNP/B-ORG/OfficerOfficial-Arg
# line )/CP/O/O
# line Kota/NNP/B-PLOC/Place-Arg/(-6.920669331867579, 107.62893793140472)/2
# line Bandung/NNP/I-PLOC/Place-Arg
# line melakukan/VB/O/O
# line pendinginan/NN/O/O
# line di/IN/O/O
# line area/NN/O/O
# line bangunan/NN/B-ORG/Facility-Arg
# line redaksi/NN/B-ORG/Facility-Arg
# line Pikiran/NNP/B-ORG/Facility-Arg
# line Rakyat/NNP/B-ORG/Facility-Arg
# line
# line
# line
# line Truk/NN/B-ARG/Vehicle-Arg
# line Gandeng/NNP/O/O
# line Nyemplung/NNP/O/O
# line ke/IN/O/O
# line Sungai/NN/O/O
# line di/IN/O
# line Demak/NNP/B-PLOC/Place-Arg/(-6.914199432985346, 110.6401210778076)/2
# line -/NNP/O/O
# line -/-/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Sebuah/NND/O/O
# line truk/NN/B-ARG/Vehicle-Arg
# line gandeng/NN/O/O
# line mengalami/VB/O/O
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line Jalan/NN/B-ARG/Street-Arg
# line Raya/NNP/I-ARG/Street-Arg
# line Demak/NN/B-LOC/Place-Arg/(-6.914199432985346, 110.6401210778076)/2
# line arah/NN/O/O
# line Kudus/NN/B-PLOC/To-Arg/(-6.800818096681704, 110.85433802259463)/2
# line tepatnya/RB/O/O
# line di/IN/O/O
# line depan/NN/O/O
# line Pasar/NNP/B-ORG/Place-Arg
# line Gajah/NNP/I-ORG/Place-Arg
# line ,/,/O/O
# line Jawa/NNP/B-PLOC/Place-Arg/(-7.272336146806256, 110.1979583965181)
# line Tengah/NN/I-PLOC/Place-Arg
# line
# line Truk/NN/B-ARG/Vehicle-Arg
# line tersebut/DT/O/O
# line terguling/VBI/B-EVE/ACCIDENT-EVENT
# line hingga/IN/O/O
# line masuk/VBT/O/O
# line ke/IN/O/O
# line dalam/IN/O/O
# line sungai/NN/O/O
# line
# line Menurut/IN/O/O
# line saksi/NN/O/O
# line mata/NN/O/O
# line ,/,/O/O
# line Ali/NNP/O/O
# line Musyadad/NNP/O/O
# line kejadia/NN/O/O
# line terjadi/VB/O/O
# line ,/,/O/O
# line Minggu/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 18/1/2015/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 06.00/CDP/I-ARG/Time-Arg
# line WIB/NN/I-ARG/Time-Arg
# line tadi/NN/O/O
# line
# line Kondisi/NN/O/O
# line truk/NN/B-ARG/Vehicle-Arg
# line yang/SC/O/O
# line bernopol/VBT/O/O
# line berawalan/VBT/O/O
# line B/NNP/O/O
# line itu/PR/O/O
# line terlihat/VB/O/O
# line hancur/NN/O/O
# line dan/CC/O/O
# line terbalik/VBI/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line dalam/IN/O/O
# line sungai/NN/O/O
# line yang/SC/O/O
# line tidak/NEG/O/O
# line terlalu/RB/O/O
# line dalam/JJ/O/O
# line
# line Ali/NN/O/O
# line juga/RB/O/O
# line mengatakan/VBI/O/O
# line ,/,/O/O
# line ada/VBI/O/O
# line tiga/CDP/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line menjadi/VB/I-ARG/DeathVictim-Arg
# line korban/NN/I-ARG/DeathVictim-Arg
# line dalam/IN/O/O
# line kejadian/NN/O/O
# line ini/PR/O/O
# line
# line Ketiganya/NN/O/O
# line diketahui/VBT/O/O
# line sudah/MD/O/O
# line tidak/NEG/O/O
# line bernyawa/VBI/O/O
# line
# line
# line
# line Field/NNP/B-ORG/Facility-Arg
# line Hospital/NNP/I-ORG/Facility-Arg
# line Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0
# line di/IN/O/O
# line Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line Tangani/NNP/O/O
# line 9/CD/B-ARG/DeathVictim-Arg
# line Korban/NN/I-ARG/DeathVictim-Arg
# line dan/CC/O/O
# line Tampung/NNP/O/O
# line 346/CDP/B-ARG/Evacuee-Arg
# line Pengungsi/NN/I-ARG/Evacuee-Arg
# line -/-/O/O
# line -/NNP/O/O
# line Kathmandu/NNP/B-PLOC/Published-Arg/(27.72347337087862, 85.3308207184338)/3
# line -/-/O/O
# line Tim/NN/O/O
# line Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0
# line Peduli/JJ/O/O
# line Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line tengah/MD/O/O
# line membongkar/VBT/O/O
# line ruangan/NN/O/O
# line operasi/NN/O/O
# line ortopedi/NN/O/O
# line dan/CC/O/O
# line anestesi/NN/O/O
# line sebelum/SC/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line 7,4/CD/B-ARG/Strength-Arg
# line SR/NNP/B-ARG/Strength-Arg
# line mengguncang/VB/B-EVE/QUAKE-EVENT
# line wilayah/NN/O/O
# line utara/NN/O/O
# line Nepal/NN/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line tadi/NN/O/O
# line siang/NN/O/O
# line
# line Setelah/SC/O/O
# line ruang/NN/O/O
# line operasi/NN/O/O
# line dalam/IN/O/O
# line bentuk/NN/O/O
# line infleatable/NN/O/O
# line tent/NN/O/O
# line itu/PR/O/O
# line dibongkar/VB/O/O
# line ,/,/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line terjadi/VB/O/O
# line sehingga/SC/O/O
# line tim/NN/O/O
# line membangun/VB/O/O
# line tenda/NN/O/O
# line tambahan/NN/O/O
# line Ada/NN/O/O
# line 9/CD/O/O
# line warga/NN/O/O
# line yang/SC/O/O
# line dirawat/VBT/O/O
# line ,/,/O/O
# line luka/NN/O/O
# line -/-/O/O
# line luka/NN/O/O
# line dan/NNP/O/O
# line kepanikan/IN/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line Direktur/NN/B-ORG/OfficerOfficial-Arg
# line Tanggap/NN/I-ORG/OfficerOfficial-Arg
# line Darurat/JJ/I-ORG/OfficerOfficial-Arg
# line BNPB/NNP/I-ORG/OfficerOfficial-Arg
# line Junjungan/NNP/I-ORG/OfficerOfficial-Arg
# line Tambunan/NNP/I-ORG/OfficerOfficial-Arg
# line di/IN/O/O
# line Kathmandu/NNP/B-PLOC/Place-Arg/(27.72347337087862, 85.3308207184338)/3
# line ,/,/O/O
# line Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line ,/,/O/O
# line Selasa/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 12/5/2015/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line malam/NN/O/O
# line
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line berkekuatan/VBI/B-ARG/Strength-Arg
# line 7,4/CD/I-ARG/Strength-Arg
# line SR/NN/I-ARG/Strength-Arg
# line kembali/RB/O/O
# line mengguncang/VB/B-EVE/QUAKE-EVENT/QUAKE-EVENT
# line Nepal/NN/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line hari/NN/O/O
# line ini/PR/O/O
# line pada/IN/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 12.49/CD/I-ARG/Time-Arg
# line waktu/NN/O/O
# line setempat/NN/O/O
# line dan/CC/O/O
# line berlangsung/VB/O/O
# line kurang/RB/O/O
# line lebih/RB/O/O
# line selama/IN/O/O
# line 2/CDP/B-ARG/Duration-Arg
# line menit/NN/I-ARG/Duration-Arg
# line
# line Guncangan/NN/B-EVE/QUAKE-EVENT
# line terasa/VBI/O/O
# line kuat/JJ/O/O
# line di/IN/O/O
# line distrik/NN/O/O
# line field/NN/O/O
# line hospital/NNP/O/O
# line Indonesia/NNP/B-PLOC/Place-Arg/(-3.364424190355106, 111.68905197529755)/0
# line berdiri/VB/O/O
# line ,/,/O/O
# line yakni/SC/O/O
# line Satungal/NNP/B-LOC/Place-Arg/(27.68195348230143, 85.25200908474135)
# line
# line
# line
# line Nepal/NNP/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line Kembali/RB/O/O
# line Diguncang/VBT/B-EVE/QUAKE-EVENT
# line Gempa/NN/I-EVE/QUAKE-EVENT
# line 7,1/CD/B-ARG/Strength-Arg
# line SR/NNP/I-ARG/Strength-Arg
# line -/NNP/O/O
# line -/-/O/O
# line Kathmandu/NNP/B-PLOC/Published-Arg/(27.72347337087862, 85.3308207184338)/3
# line ,/,/O/O
# line -/-/O/O
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line bumi/NN/I-EVE/QUAKE-EVENT
# line kembali/RB/O/O
# line melanda/VB/O/O
# line Nepal/NN/B-PLOC/Place-Arg/(27.769976632749092, 84.50501489436837)/0
# line hari/NN/O/O
# line ini/PR/O/O
# line
# line Gempa/NNP/B-EVE/QUAKE-EVENT
# line berkekuatan/VBI/B-ARG/Strength-Arg
# line 7,1/CD/I-ARG/Strength-Arg
# line Skala/NN/I-ARG/Strength-Arg
# line Richter/NNP/I-ARG/Strength-Arg
# line (/OP/O/O
# line SR/NNP/O/O
# line )/CP/O/O
# line ini/DT/O/O
# line menyebabkan/VBT/O/O
# line ribuan/CDC/O/O
# line orang/NN/O/O
# line di/IN/O/O
# line ibukota/NN/O/O
# line Kathmandu/NN/B-LOC/Place-Arg/(27.72347337087862, 85.3308207184338)/3
# line berlarian/VBI/O/O
# line ke/IN/O/O
# line jalan/NN/O/O
# line -/-/O/O
# line jalan/NN/O/O
# line
# line Badan/NN/B-ORG/OfficerOfficial-Arg
# line Survei/NN/I-ORG/OfficerOfficial-Arg
# line Geologi/NNP/I-ORG/OfficerOfficial-Arg
# line Amerika/NNP/B-PLOC/Place-Arg/(38.4572641110912, -92.2110028043666)/0
# line Serikat/NNP/I-PLOC/Place-Arg
# line ,/,/O/O
# line USGS/NNP/B-ORG/OfficerOfficial-Arg
# line menyatakan/VB/O/O
# line seperti/IN/O/O
# line dilansir/VBT/O/O
# line kantor/NN/O/O
# line berita/NN/O/O
# line Reuters/NNP/B-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line Selasa/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 12/5/2015/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line ,/,/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line terjadi/VB/O/O
# line di/IN/O/O
# line wilayah/NN/O/O
# line sekitar/RB/O/O
# line 68/CD/B-ARG/Central-Arg
# line kilometer/NND/I-ARG/Central-Arg
# line sebelah/NN/I-ARG/Central-Arg
# line barat/NN/I-ARG/Central-Arg
# line kota/NN/B-LOC/Place-Arg/(27.928189880910356, 86.61208289377247)/4
# line Namche/NNP/I-LOC/Place-Arg
# line Bazar/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line dekat/JJ/O/O
# line dengan/IN/O/O
# line gunung/NN/O/O
# line Mount/NNP/B-ARG/Place-Arg
# line Everest/NN/I-ARG/Place-Arg
# line
# line Guncangan/NNP/B-EVE/QUAKE-EVENT
# line gempa/NN/I-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line dilaporkan/VB/O/O
# line dirasakan/VB/O/O
# line hingga/IN/O/O
# line ke/IN/O/O
# line New/NNP/B-LOC/Place-Arg/(28.646518974169425, 77.1089795345416)/2
# line Delhi/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line India/NNP/B-PLOC/Place-Arg/(21.57293880816482, 78.53025185596609)/0
# line
# line Sejauh/NN/O/O
# line ini/PR/O/O
# line ,/,/O/O
# line belum/NEG/O/O
# line ada/VBI/O/O
# line laporan/NN/O/O
# line korban/NN/O/O
# line maupun/CC/O/O
# line kerusakan/NN/O/O
# line akibat/IN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line
# line
# line
# line 41/CD/B-ARG/DeathVictim-Arg
# line Orang/NN/I-ARG/DeathVictim-Arg
# line Tewas/JJ/I-ARG/DeathVictim-Arg
# line Akibat/IN/O/O
# line Banjir/NN/B-EVE/FLOOD-EVENT
# line di/IN/O/O
# line India/NNP/B-PLOC/Place-Arg/(21.57293880816482, 78.53025185596609)/0
# line -/NNP/O/O
# line -/-/O/O
# line New/NNP/B-PLOC/Published-Arg/(28.646518974169425, 77.1089795345416)/2
# line Delhi/NNP/I-PLOC/Published-Arg
# line -/-/O/O
# line Wilayah/NN/O/O
# line Gujarat/NNP/B-LOC/Place-Arg/(22.292066083838034, 71.90914465940999)/1
# line ,/,/O/O
# line India/NNP/B-PLOC/Place-Arg/(21.57293880816482, 78.53025185596609)/0
# line tengah/MD/O/O
# line dilanda/VBT/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line bandang/JJ/I-EVE/FLOOD-EVENT
# line yang/SC/O/O
# line dipicu/VB/O/O
# line oleh/IN/O/O
# line hujan/NN/B-EVE/RAIN-EVENT
# line deras/NN/I-EVE/RAIN-EVENT
# line tiada/NN/O/O
# line henti/NN/O/O
# line selama/IN/O/O
# line 24/CDP/B-ARG/Duration-Arg
# line jam/NN/I-ARG/Duration-Arg
# line
# line Sedikitnya/NNG/O/O
# line 41/CD/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line akibat/IN/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line ini/PR/O/O
# line
# line Otoritas/NN/B-ORG/OfficerOfficial-Arg
# line setempat/NN/O/O
# line telah/MD/O/O
# line mengevakuasi/VBT/B-EVE/EVACUATE-EVENT
# line lebih/RB/O/O
# line dari/IN/O/O
# line 10/CDP/B-ARG/Evacuee-Arg
# line ribu/CDP/I-ARG/Evacuee-Arg
# line warga/NN/I-ARG/Evacuee-Arg
# line ,/,/O/O
# line terutama/JJ/O/O
# line dari/IN/O/O
# line wilayah/NN/O/O
# line Gujarat/NN/B-LOC/Place-Arg/(22.292066083838034, 71.90914465940999)/1
# line yang/SC/O/O
# line terletak/VBI/O/O
# line di/IN/O/O
# line dekat/JJ/O/O
# line pantai/NN/O/O
# line
# line Distrik/NNP/B-LOC/Place-Arg/(21.326558941241277, 71.29974959140496)/2
# line Amreli/NNP/I-LOC/Place-Arg
# line merupakan/VB/O/O
# line area/NN/O/O
# line terdampak/IN/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line paling/RB/O/O
# line parah/JJ/O/O
# line ,/,/O/O
# line dengan/IN/O/O
# line mayoritas/NN/O/O
# line korban/NN/O/O
# line tewas/JJ/O/O
# line berasal/VBI/O/O
# line dari/IN/O/O
# line distrik/NN/O/O
# line ini/PR/O/O
# line
# line "/"/O/O
# line Terdapat/NN/O/O
# line 41/CD/B-ARG/DeathVictim-Arg
# line korban/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line di/IN/O/O
# line sejumlah/CDI/O/O
# line wilayah/NN/O/O
# line ,/,/O/O
# line dengan/IN/O/O
# line 36/CDP/B-ARG/DeathVictim-Arg
# line korban/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line berasal/VBI/O/O
# line dari/IN/O/O
# line Amreli/NNP/B-LOC/Place-Arg/(21.326558941241277, 71.29974959140496)/2
# line ,/,/O/O
# line kemudian/CC/O/O
# line tiga/CDP/B-ARG/DeathVictim-Arg
# line korban/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line berasal/VBI/O/O
# line dari/IN/O/O
# line Bhavnagar/NNP/B-LOC/Place-Arg/(21.746013932118366, 72.04927349639709)/2
# line dan/CC/O/O
# line dua/CDP/B-ARG/DeathVictim-Arg
# line korban/NN/I-ARG/DeathVictim-Arg
# line tewas/JJ/I-ARG/DeathVictim-Arg
# line lainnya/NNG/O/O
# line dari/IN/O/O
# line disrik/VBT/O/O
# line Rajkot/NNP/B-LOC/Place-Arg/(22.011645000050645, 70.72023172903025)/2
# line ,/,/O/O
# line "/"/O/O
# line terang/JJ/O/O
# line seorang/NN/O/O
# line pejabat/NN/O/O
# line pada/IN/O/O
# line ruang/NN/O/O
# line kontrol/NN/O/O
# line badan/NN/O/O
# line penanggulangan/NN/O/O
# line bencana/NN/O/O
# line setempat/NN/O/O
# line ,/,/O/O
# line seperti/IN/O/O
# line dilansir/VBT/O/O
# line AFP/NNP/B-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line Kamis/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 25/6/2015/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line
# line
# line Pikap/NNP/B-ARG/Vehicle-Arg
# line Terguling/NNP/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line Tol/NNP/B-ARG/Street-Arg
# line JORR/NNP/I-ARG/Street-Arg
# line ,/,/O/O
# line Pondok/NNP/B-PLOC/Place-Arg/(-6.2649756,106.7818375)/3
# line Indah/NNP/I-PLOC
# line ke/IN/O/O
# line Cilincing/NNP/B-PLOC/Place-Arg/(-6.123697810179591, 106.93802723918002)/3
# line Macet/NNP/B-EVE/ACCIDENT-EVENT
# line 2/CDP/I-ARG/Length-Arg
# line Kilometer/NND/I-ARG/Length-Arg
# line -/-/O/O
# line -/NNP/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Mobil/NN/O/O
# line pikap/NN/B-ARG/Vehicle-Arg
# line terguling/VBI/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line KM/NN/B-ARG/Point-Arg
# line 52/CDP/I-ARG/Point-Arg
# line Tol/NNP/B-ARG/Place-Arg
# line JORR/NNP/I-ARG/Place-Arg
# line Pondok/NNP/B-LOC/Place-Arg/(-6.2649756,106.7818375)/3
# line Indah/NNP/I-LOC/Place-Arg
# line arah/NN/O/O
# line Cilincing/NNP/B-PLOC/To-Arg/(-6.123697810179591, 106.93802723918002)/3
# line pukul/NN/B-ARG/Time-Arg
# line 07.32/CD/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line
# line Kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line mengakibatkan/VBT/O/O
# line kepadatan/NN/O/O
# line kendaraan/NN/O/O
# line hingga/IN/O/O
# line 2/CDP/B-ARG/Length-Arg
# line kilometer/NND/I-ARG/Length-Arg
# line
# line Petugas/NN/B-ORG/OfficerOfficial-Arg
# line Jasa/NNP/I-ORG/OfficerOfficial-Arg
# line Marga/NN/I-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line Ani/NN/O/O
# line saat/SC/O/O
# line dikonfirmasi/VB/O/O
# line mengatakan/VB/O/O
# line ,/,/O/O
# line petugas/NN/O/O
# line sudah/MD/O/O
# line berada/VBI/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line kejadian/NN/O/O
# line
# line Belum/NEG/O/O
# line diketahui/VBT/O/O
# line ada/VBI/O/O
# line tidaknya/NEG/O/O
# line korban/NN/O/O
# line akibat/IN/O/O
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line
# line "/"/O/O
# line Kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line tepatnya/RB/O/O
# line di/IN/O/O
# line KM/NN/B-ARG/Point-Arg
# line 52+800/NN/I-ARG/Point-Arg
# line yaitu/SC/O/O
# line mobil/NN/B-ARG/Vehicle-Arg
# line muatan/NN/O/O
# line cat/NN/O/O
# line dan/CC/O/O
# line tiner/NN/O/O
# line
# line Akibatnya/NN/O/O
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line macet/NN/B-EVE/JAM-EVENT
# line 2/CDP/B-ARG/Length-Arg
# line KM/NN/I-ARG/Length-Arg
# line dari/IN/O/O
# line Pondok/NNP/B-LOC/From-Arg/(-6.2649756,106.7818375)/3
# line Indah/NNP/I-LOC/From-Arg
# line ke/IN/O/O
# line Cilincing/NNP/B-LOC/To-Arg/(-6.123697810179591, 106.93802723918002)/3
# line "/"/O/O
# line ujar/VB/O/O
# line Ani/NN/O/O
# line pada/IN/O/O
# line detikcom/NNP/B-ORG/Reporter-Arg
# line ,/,/O/O
# line Rabu/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 30/9/2015/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line
# line
# line Korban/NN/B-ARG/DeathVictim-Arg
# line Tewas/JJ/I-ARG/DeathVictim-Arg
# line di/IN/O/O
# line Plaza/NNP/B-ARG/Facility-Arg
# line UOB/NNP/I-ARG/Facility-Arg
# line Ditemukan/VBT/O/O
# line di/IN/O/O
# line Bawah/NN/O/O
# line Mobil/NN/O/O
# line di/IN/O/O
# line Basement/NNP/O/O
# line 1/CD/O/O
# line -/-/O/O
# line -/NNP/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Petugas/NN/B-ORG/OfficerOfficial-Arg
# line tim/NN/O/O
# line evakuasi/NN/O/O
# line kembali/RB/O/O
# line menemukan/VBT/O/O
# line korban/NN/B-ARG/Facility-Arg
# line tewas/JJ/I-ARG/Facility-Arg
# line di/IN/O/O
# line Plaza/NNP/B-ARG/Facility-Arg
# line UOB/NNP/I-ARG/Facility-Arg
# line ,/,/O/O
# line Thamrin/NNP/B-ARG/Place-Arg
# line
# line Korban/NN/O/O
# line diketahui/VBT/O/O
# line bernama/VB/O/O
# line Herdian/NNP/O/O
# line Eko/NNP/O/O
# line (/OP/O/O
# line 27/CD/O/O
# line )/CP/O/O
# line
# line Korban/NN/O/O
# line merupakan/VB/O/O
# line cleaning/FW/O/O
# line service/NN/O/O
# line di/IN/O/O
# line gedung/NN/O/O
# line itu/PR/O/O
# line
# line "Korban/DT/O/O
# line meninggal/VBI/O/O
# line ditemukan/VBT/O/O
# line di/IN/O/O
# line bawah/NN/O/O
# line mobil/NN/O/O
# line
# line Kondisi/NN/O/O
# line tubuh/NN/O/O
# line korban/NN/O/O
# line sudah/RB/O/O
# line bengkak/JJ/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line Kadis/NNP/B-ORG/OfficerOfficial-Arg
# line Damkar/NNP/I-ORG/OfficerOfficial-Arg
# line DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1
# line Paimin/NNP/O/O
# line Napitupulu/NNP/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line ,/,/O/O
# line Sabtu/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 19/1/2013/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line Korban/NNP/O/O
# line ditemukan/VBT/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 15.05/CD/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line
# line Jasad/NN/O/O
# line korban/NN/O/O
# line langsung/RB/O/O
# line dimasukkan/VB/O/O
# line ke/IN/O/O
# line kantung/NN/O/O
# line mayat/NN/O/O
# line dan/CC/O/O
# line dibawa/VB/O/O
# line ke/IN/O/O
# line RSCM/NNP/B-ORG/Hospital-Arg
# line
# line "/"/O/O
# line Korban/NN/O/O
# line ditemukan/VBT/O/O
# line di/IN/O/O
# line basement/NN/O/O
# line 1,/CDP/O/O
# line "/"/O/O
# line jelasnya/NN/O/O
# line
# line Kondisi/JJ/O/O
# line di/IN/O/O
# line lokasi/NN/O/O
# line ,/,/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line di/IN/O/O
# line basement/NN/O/O
# line 1/CD/O/O
# line sudah/MD/O/O
# line surut/JJ/O/O
# line ,/,/O/O
# line tetapi/CC/O/O
# line di/IN/O/O
# line basement/NN/O/O
# line 2/CD/O/O
# line masih/MD/O/O
# line tergenang/VBI/O/O
# line
# line Evakuasi/NNP/B-EVE/
# line terus/RB/O/O
# line dilakukan/VB/O/O
# line
# line
# line
# line Wali/NNP/B-ORG/OfficerOfficial-Arg
# line Kota/NNP/I-ORG/OfficerOfficial-Arg
# line :/:/O/O
# line Korban/NN/B-ARG/DeathVictim-Arg
# line Jiwa/NN/I-ARG/DeathVictim-Arg
# line Bisa/MD/O/O
# line Lebih/RB/O/O
# line dari/IN/O/O
# line 100/CDP/B-ARG/DeathVictim-Arg
# line Orang/NN/I-ARG/DeathVictim-Arg
# line -/-/O/O
# line -/-/O/O
# line Foto/NN/O/O
# line :/NNP/O/O
# line PoolTaipei/NNP/O/O
# line ,/,/O/O
# line -/-/O/O
# line Korban/NN/B-ARG/DeathVictim-Arg
# line jiwa/NN/I-ARG/DeathVictim-Arg
# line akibat/IN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line 6,4/CD/B-ARG/Strength-Arg
# line Skala/NN/I-ARG/Strength-Arg
# line Richter/NNP/I-ARG/Strength-Arg
# line (/OP/O/O
# line SR/NNP/O/O
# line )/CP/O/O
# line di/IN/O/O
# line kota/NN/B-LOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2
# line Tainan/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Taiwan/NNP/B-PLOC/Place-Arg/(24.119811469350566, 120.75584580341844)/0
# line selatan/NNP/O/O
# line terus/RB/O/O
# line bertambah/VBI/O/O
# line
# line Sejauh/NN/O/O
# line ini/PR/O/O
# line ,/,/O/O
# line sudah/MD/O/O
# line 38/CDP/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line yang/SC/I-ARG/DeathVictim-Arg
# line ditemukan/VBT/O/O
# line tewas/JJ/B-ARG/DeathVictim-Arg
# line usai/IN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line yang/SC/O/O
# line terjadi/VBI/O/O
# line dua/CDP/O/O
# line hari/NN/O/O
# line lalu/JJ/O/O
# line
# line Namun/CC/O/O
# line wali/NNP/B-ORG/OfficerOfficial-Arg
# line kota/NNP/I-ORG/OfficerOfficial-Arg
# line Tainan/NNP/B-PLOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2
# line mengingatkan/VB/O/O
# line ,/,/O/O
# line jumlah/NN/O/O
# line korban/NN/B-ARG/DeathVictim-Arg
# line jiwa/NN/I-ARG/DeathVictim-Arg
# line bisa/MD/O/O
# line mencapai/VB/O/O
# line lebih/RB/O/O
# line dari/IN/O/O
# line 100/CDP/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line
# line Upaya/NN/O/O
# line pencarian/NN/O/O
# line korban/NN/O/O
# line terus/RB/O/O
# line dilakukan/VB/O/O
# line dan/CC/O/O
# line difokuskan/VBT/O/O
# line di/IN/O/O
# line area/NN/O/O
# line reruntuhan/NN/O/O
# line gedung/NN/B-ARG/Facility-Arg
# line Wei/NNP/I-ARG/Facility-Arg
# line -/-/O/O
# line guan/NN/O/O
# line Golden/NNP/B-ARG/Facility-Arg
# line Dragon/NNP/I-ARG/Facility-Arg
# line Building/NNP/I-ARG/Facility-Arg
# line di/IN/O/O
# line kota/NN/B-LOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2
# line Tainan/NNP/I-LOC/Place-Arg
# line
# line Gedung/NNP/O/O
# line berlantai/VBT/O/O
# line 17/CDP/O/O
# line tersebut/DT/O/O
# line ambruk/NN/O/O
# line akibat/IN/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line yang/SC/O/O
# line terjadi/VB/O/O
# line pada/IN/O/O
# line Sabtu/NNP/B-ARG/Time-Arg
# line ,/,/O/O
# line 6/CD/O/O
# line Februari/NNP/O/O
# line lalu/VB/O/O
# line
# line Di/IN/O/O
# line gedung/NN/O/O
# line tersebut/PR/O/O
# line ,/,/O/O
# line 117/CD/B-ARG/MissingPerson-Arg
# line orang/NN/I-ARG/MissingPerson-Arg
# line tercatat/VB/I-ARG/MissingPerson-Arg
# line masih/MD/I-ARG/MissingPerson-Arg
# line hilang/VBI/I-ARG/MissingPerson-Arg
# line dan/CC/O/O
# line diperkirakan/VBT/O/O
# line tertimpa/VBI/O/O
# line puing/NN/O/O
# line -/-/O/O
# line puing/NN/O/O
# line
# line Wali/NN/B-ORG/OfficerOfficial-Arg
# line kota/NN/I-ORG/OfficerOfficial-Arg
# line Tainan/NNP/B-LOC/Place-Arg/(23.14866450719771, 120.33236160219855)/2
# line ,/,/O/O
# line William/NNP/O/O
# line Lai/NNP/O/O
# line mengatakan/VB/O/O
# line ,/,/O/O
# line upaya/NN/O/O
# line penyelamatan/NN/O/O
# line kini/RB/O/O
# line telah/MD/O/O
# line memasuki/VBT/O/O
# line apa/WP/O/O
# line yang/SC/O/O
# line disebutnya/VB/O/O
# line sebagai/IN/O/O
# line "/"/O/O
# line tahap/NN/O/O
# line ketiga/CDO/O/O
# line "/"/O/O
# line
# line
# line
# line 4/CD/B-ARG/Affectedvehicle-Arg
# line Kendaraan/NN/I-ARG/Affectedvehicle-Arg
# line Kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line Beruntun/NN/I-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line KM/NN/B-ARG/Point-Arg
# line 33/NNP/I-ARG/Point-Arg
# line Tol/NNP/B-ARG/Street-Arg
# line Jagorawi/NNP/I-ARG/Street-Arg
# line Arah/NN/O/O
# line Jakarta/NNP/B-PLOC/To-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/NNP/O/O
# line -/-/O/O
# line Foto/NN/O/O
# line :/NNP/O/O
# line -/-/O/O
# line Empat/CDP/B-ARG/Affectedvehicle-Arg
# line kendaraan/NN/I-ARG/Affectedvehicle-Arg
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line beruntun/VBI/I-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line KM/NN/B-ARG/Point-Arg
# line 33+800/NN/I-ARG/Point-Arg
# line Tol/NNP/B-ARG/Street-Arg
# line Jagorawi/NNP/I-ARG/Street-Arg
# line yang/SC/O/O
# line mengarah/VBI/O/O
# line ke/IN/O/O
# line Jakarta/NNP/B-PLOC/To-Arg/(-6.197602429787846, 106.83139222722116)/1
# line
# line Petugas/NN/B-ORG/OfficerOfficial-Arg
# line masih/MD/O/O
# line melakukan/VB/O/O
# line evakuasi/NN/O/O
# line kendaraan/NN/O/O
# line tersebut/PR/O/O
# line "/"/O/O
# line Kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line terjadi/VB/O/O
# line di/IN/O/O
# line lajur/NN/O/O
# line 2/CD/O/O
# line dan/CC/O/O
# line 3/CDP/O/O
# line
# line Untuk/IN/O/O
# line data/NN/O/O
# line -/-/O/O
# line data/NN/O/O
# line kendaraannya/NN/O/O
# line kami/PRP/O/O
# line belum/NEG/O/O
# line menerima/VBT/O/O
# line informasi/NN/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line petugas/NN/B-ORG/OfficerOfficial-Arg
# line operator/NN/I-ORG/OfficerOfficial-Arg
# line PT/NNP/I-ORG/OfficerOfficial-Arg
# line Jasamarga/NNP/I-ORG/OfficerOfficial-Arg
# line ,/,/O/O
# line Rafli/NN/O/O
# line saat/SC/O/O
# line dikonfirmasi/VB/O/O
# line ,/,/O/O
# line Kamis/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 28/4/2016/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line Peristiwa/NN/O/O
# line itu/PR/O/O
# line terjadi/VB/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 23.34/CD/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line
# line Lalu/VB/O/O
# line lintas/NN/O/O
# line pun/RP/O/O
# line padat/IN/O/O
# line menjelang/VBT/O/O
# line lokasi/NN/O/O
# line
# line
# line
# line Kasus/NN/O/O
# line Vellfire/NN/O/O
# line Anak/NN/O/O
# line Eks/NNP/O/O
# line Menteri/NNP/O/O
# line Sugiharto/NNP/O/O
# line Tabrak/NNP/B-EVE/ACCIDENT-EVENT
# line 4/CD/B-ARG/Affectedvehicle-Arg
# line Mobil/NN/I-ARG/Affectedvehicle-Arg
# line Masih/MD/O/O
# line Lanjut/VB/O/O
# line -/NNP/O/O
# line -/-/O/O
# line Jakarta/NNP/B-PLOC/Published-Arg/(-6.197602429787846, 106.83139222722116)/1
# line -/-/O/O
# line Kasus/NN/O/O
# line Vellfire/NNP/O/O
# line menabrak/VBT/B-EVE/ACCIDENT-EVENT
# line empat/CDP/B-ARG/Affectedvehicle-Arg
# line mobil/NN/I-ARG/Affectedvehicle-Arg
# line yang/SC/O/O
# line dikemudikan/VBT/O/O
# line Hadi/NNP/O/O
# line Prasetyo/NNP/O/O
# line (/OP/O/O
# line 16/CD/O/O
# line )/CP/O/O
# line anak/NN/O/O
# line eks/NN/O/O
# line Menteri/NN/O/O
# line BUMN/NN/O/O
# line Sugiharto/NNP/O/O
# line terus/RB/O/O
# line diseldiki/VBT/O/O
# line polisi/NN/O/O
# line
# line Saksi/NNP/O/O
# line -/-/O/O
# line saksi/NN/O/O
# line dalam/IN/O/O
# line kasus/NN/O/O
# line ini/PR/O/O
# line akan/MD/O/O
# line dipanggil/VB/O/O
# line
# line Polisi/NN/B-ORG/OfficerOfficial-Arg
# line juga/RB/O/O
# line memeriksa/VBT/O/O
# line kepemilikan/NN/O/O
# line SIM/NN/O/O
# line milik/NN/O/O
# line Hadi/NNP/O/O
# line yang/SC/O/O
# line baru/MD/O/O
# line berusia/VB/O/O
# line 16/CD/O/O
# line tahun/NN/O/O
# line
# line "/"/O/O
# line Memang/NN/O/O
# line tetap/JJ/O/O
# line kita/PRP/O/O
# line lanjutkan/VB/O/O
# line ,/,/O/O
# line kita/PRP/O/O
# line proses/NN/O/O
# line hukum/NN/O/O
# line kita/PRP/O/O
# line lanjutkan/VB/O/O
# line pendalaman/NN/O/O
# line
# line Kesulitan/VB/O/O
# line kita/PRP/O/O
# line kan/RP/O/O
# line pihak/NN/O/O
# line korban/NN/O/O
# line tidak/NEG/O/O
# line buat/NN/O/O
# line laporan/NN/O/O
# line ,/,/O/O
# line sudah/RB/O/O
# line diundang/VBT/O/O
# line tidak/NEG/O/O
# line datang/VBI/O/O
# line memang/RB/O/O
# line mereka/PRP/O/O
# line sudah/MD/O/O
# line ada/VB/O/O
# line penyelesaian/NN/O/O
# line kekeluargaan/NN/O/O
# line ,/,/O/O
# line tetapi/CC/O/O
# line proses/NN/O/O
# line hukum/NN/O/O
# line tetap/RB/O/O
# line berjalan/VB/O/O
# line
# line Karena/SC/O/O
# line ini/PR/O/O
# line kan/RP/O/O
# line bukan/NEG/O/O
# line delik/NN/O/O
# line aduan/FW/O/O
# line ,/,/O/O
# line ada/VB/O/O
# line prosedur/NN/O/O
# line penanganannya/NN/O/O
# line ,/,/O/O
# line "/"/O/O
# line jelas/VB/O/O
# line Kasatlantas/NNP/B-ORG/OfficerOfficial-Arg
# line Polres/NNP/I-ORG/OfficerOfficial-Arg
# line Jaksel/NNP/B-PLOC/Place-Arg/(-6.256679776683385, 106.81568629190677)/2
# line Kompol/NNP/B-ORG/OfficerOfficial-Arg
# line Dody/NNP/O/O
# line ,/,/O/O
# line Rabu/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 27/4/2016/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line Peristiwa/NN/O/O
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line ini/PR/O/O
# line terjadi/VB/O/O
# line pada/IN/O/O
# line Kamis/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 21/4/4/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line sore/NN/O/O
# line
# line Selain/IN/O/O
# line empat/CDP/B-ARG/Affectedvehicle-Arg
# line mobil/NN/I-ARG/Affectedvehicle-Arg
# line ada/VBI/O/O
# line satu/CDP/B-ARG/Affectedvehicle-Arg
# line motor/NN/I-ARG/Affectedvehicle-Arg
# line yang/SC/O/O
# line ditabrak/VBT/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line Jl/NNP/B-ARG/Street-Arg
# line Ciniru/NNP/I-ARG/Street-Arg
# line ,/,/O/O
# line Kebayoran/NNP/B-LOC/Place-Arg/(-6.24397614020749, 106.80236966063316)/3
# line Baru/NNP/I-LOC/Place-Arg
# line
# line Hadi/NN/O/O
# line saat/NN/O/O
# line ini/DT/O/O
# line mengejar/VBT/O/O
# line kakak/NN/O/O
# line tirinya/NNP/O/O
# line Stephen/NNP/O/O
# line
# line Kasus/NN/O/O
# line ini/PR/O/O
# line memang/RB/O/O
# line dilandasi/VBT/O/O
# line pertengkaran/NN/O/O
# line kakak/NN/O/O
# line dan/CC/O/O
# line adik/NNP/O/O
# line
# line
# line
# line BMKG/NNP/B-ORG/OfficerOfficial-Arg
# line :/:/O/O
# line Gempa/NNP/B-EVE/QUAKE-EVENT
# line 6,5/CD/B-ARG/Strength-Arg
# line SR/NN/I-ARG/Strength-Arg
# line di/IN/O/O
# line Sumbar/NNP/B-LOC/Place-Arg/(-0.7011133317649648, 100.54048425582306)/1
# line Cukup/RB/O/O
# line Kuat/JJ/O/O
# line Tapi/CC/O/O
# line Tak/NEG/O/O
# line Timbulkan/NN/O/O
# line Kerusakan/NN/O/O
# line -/-/O/O
# line -/-/O/O
# line Foto/NN/O/O
# line :/:/O/O
# line Zainal/NNP/O/O
# line AbidinJakarta/NNP/O/O
# line -/NNP/O/O
# line Gempa/NNP/B-EVE/QUAKE-EVENT
# line berkekuatan/VBI/B-ARG/Strength-Arg
# line 6,5/CD/I-ARG/Strength-Arg
# line SR/NNP/I-ARG/Strength-Arg
# line mengguncang/NNP/B-EVE/QUAKE-EVENT
# line Sumatera/NNP/B-LOC/Place-Arg/(-0.7011133317649648, 100.54048425582306)/1
# line Barat/NNP/I-LOC/Place-Arg
# line
# line Gempa/NN/B-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line cukup/RB/O/O
# line kuat/JJ/O/O
# line namun/CC/O/O
# line tidak/NEG/O/O
# line mengakibatkan/VBT/O/O
# line kerusakan/NN/O/O
# line
# line "/"/O/O
# line Mengacu/VB/O/O
# line parameter/NN/O/O
# line ini/PR/O/O
# line tampak/VB/O/O
# line bahwa/SC/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line tersebut/PR/O/O
# line merupakan/VB/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line menengah/JJ/O/O
# line terjadi/VBI/O/O
# line akibat/IN/O/O
# line aktivitas/NN/O/O
# line subduksi/NN/O/O
# line lempeng/JJ/O/O
# line di/IN/O/O
# line zona/NN/O/O
# line ,/,/O/O
# line "/"/O/O
# line ujar/VB/O/O
# line Kepala/NNP/B-ORG/OfficerOfficial-Arg
# line Bidang/NNP/I-ORG/OfficerOfficial-Arg
# line Mitigasi/NNP/I-ORG/OfficerOfficial-Arg
# line Gempa/NNP/I-ORG/OfficerOfficial-Arg
# line bumi/NN/I-ORG/OfficerOfficial-Arg
# line dan/CC/I-ORG/OfficerOfficial-Arg
# line Tsunami/NN/I-ORG/OfficerOfficial-Arg
# line BMKG/NNP/B-ORG/OfficerOfficial-Arg
# line Daryono/NNP/O/O
# line saat/SC/O/O
# line dihubungi/VBT/O/O
# line detikcom/NN/B-ORG/Reporter-Arg
# line ,/,/O/O
# line Kamis/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 2/6/2016/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line
# line Menurut/IN/O/O
# line Daryono/NNP/O/O
# line ,/,/O/O
# line gempa/NN/B-EVE/QUAKE-EVENT
# line ini/PR/O/O
# line memiliki/VB/O/O
# line efek/NN/O/O
# ...
# line banjir/NN/B-EVE/FLOOD-EVENT
# line )/CP/O/O
# line tidak/NEG/O/O
# line setinggi/VBT/O/O
# line ini/DT/O/O
# line
# line Semoga/NN/O/O
# line cepat/JJ/O/O
# line surut/JJ/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line Mia/NN/O/O
# line seperti/IN/O/O
# line mengutip/VBT/O/O
# line Antara/NN/O/O
# line
# line Ia/PRP/O/O
# line berharap/VBT/O/O
# line pemerintah/NN/O/O
# line segera/RB/O/O
# line menyediakan/VB/O/O
# line lahan/NN/O/O
# line kosong/JJ/O/O
# line untuk/IN/O/O
# line pengungsian/NN/O/O
# line agar/SC/O/O
# line korban/NN/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line tidak/NEG/O/O
# line berkerumun/VBI/O/O
# line di/IN/O/O
# line pinggir/NN/O/O
# line jalan/NN/O/O
# line sehingga/SC/O/O
# line menyebabkan/VB/O/O
# line kemacetan/NN/B-EVE/JAM-EVENT
# line sepanjang/IN/B-ARG/Length-Arg
# line satu/CD/I-ARG/Length-Arg
# line kilometer/NND/I-ARG/Length-Arg
# line di/IN/O/O
# line Jalan/NN/B-ARG/Place-Arg
# line Cililitan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4
# line -/NNP/O/O
# line Condet/NNP/B-PLOC/Place-Arg/(-6.2823949,106.8530383)/4
# line
# line Banjir/NN/B-EVE/FLOOD-EVENT
# line merendam/VBT/I-EVE/FLOOD-EVENT
# line sebagian/CDI/O/O
# line wilayah/NN/O/O
# line Jakarta/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1
# line pada/IN/O/O
# line Jumat/NN/O/O
# line dini/JJ/O/O
# line hari/NN/O/O
# line karena/IN/O/O
# line air/NN/O/O
# line Sungai/NN/B-ARG/Cause-Arg
# line Ciliwung/NNP/I-ARG/Cause-Arg
# line meluap/VBT/B-EVE/FLOOD-EVENT
# line sejak/IN/O/O
# line Kamis/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 25/4/DD/B-ARG/Time-Arg
# line )/CP/O/O
# line malam/NN/O/O
# line
# line Kepala/NNP/B-ORG/OfficerOfficial-Arg
# line UPT/NNP/I-ORG/OfficerOfficial-Arg
# line Pusat/NNP/I-ORG/OfficerOfficial-Arg
# line Data/NN/I-ORG/OfficerOfficial-Arg
# line dan/CC/O/O
# line Informasi/NN/O/O
# line Badan/NN/B-ORG/OfficerOfficial-Arg
# line Penanggulangan/NN/I-ORG/OfficerOfficial-Arg
# line Bencana/NN/I-ORG/OfficerOfficial-Arg
# line Daerah/NNP/I-ORG/OfficerOfficial-Arg
# line DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1
# line Jakarta/NNP/I-PLOC/Place-Arg
# line M/NNP/O/O
# line Ridwan/NNP/O/O
# line mengatakan/VB/O/O
# line luapan/NN/B-EVE/FLOOD-EVENT
# line air/NN/O/O
# line Sungai/NN/B-ARG/Cause-Arg
# line Ciliwung/NNP/I-ARG/Cause-Arg
# line akan/MD/O/O
# line melewati/VBT/O/O
# line 13/CDP/O/O
# line wilayah/NN/O/O
# line ,/,/O/O
# line di/IN/O/O
# line antaranya/NNG/O/O
# line Srengseng/NNP/B-LOC/Place-Arg/(-6.34840066885497, 106.8245009553336)/4
# line Sawah/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Rawajati/NNP/B-LOC/Place-Arg/(-6.258078344036345, 106.85465172512482)/4
# line ,/,/O/O
# line Pengadegan/NNP/B-LOC/Place-Arg/(-6.95388742431344, 108.36410039280217)/4
# line ,/,/O/O
# line Cikoko/NNP/B-LOC/Place-Arg/(-6.245041099532579, 106.85435715914397)/4
# line ,/,/O/O
# line Pejaten/NNP/B-LOC/Place-Arg/(-6.279918869543594, 106.84835324241898)/4
# line Timur/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Kebon/NNP/B-LOC/Place-Arg/(-0.5742377787510939, 101.9915417000183)/4
# line Baru/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Bukit/NNP/B-LOC/Place-Arg/(-6.221337778341242, 106.85811906630207)/4
# line Duri/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Balekambang/NNP/B-LOC/Place-Arg/(-6.281549654594483, 106.85272309431423)/4
# line ,/,/O/O
# line Cililitan/NNP/B-LOC/Place-Arg/(-6.386314411858343, 106.42243148751925)/4
# line ,/,/O/O
# line Bidara/NNP/B-LOC/Place-Arg/(-6.217169337559462, 106.8611143840193)/4
# line Cina/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Kampung/NNP/B-LOC/Place-Arg/(-3.220507894108893, 107.64114141584496)/4
# line Melayu/NNP/I-LOC/Place-Arg
# line dan/CC/O/O
# line Manggarai/NNP/B-LOC/Place-Arg/(-6.213525657107193, 106.85105464595664)/4
# line
# line Badan/NN/B-ORG/OfficerOfficial-Arg
# line Penanggulangan/NN/I-ORG/OfficerOfficial-Arg
# line Bencana/NN/I-ORG/OfficerOfficial-Arg
# line Daerah/NNP/I-ORG/OfficerOfficial-Arg
# line (/OP/O/O
# line BPBD/NNP/B-ORG/OfficerOfficial-Arg
# line )/CP/O/O
# line DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1
# line Jakarta/NNP/I-PLOC/Place-Arg
# line meminta/VBT/O/O
# line para/DT/O/O
# line pengguna/NN/O/O
# line jalan/NN/O/O
# line yang/SC/O/O
# line akan/MD/O/O
# line menuju/VB/O/O
# line Kalibata/NNP/B-PLOC/Place-Arg/(-6.263338194185572, 106.83763416323916)/4
# line untuk/IN/O/O
# line menghindari/VBT/O/O
# line Jalan/NN/B-ARG/Place-Arg
# line Dewi/NNP/I-ARG/Place-Arg
# line Sartika/NNP/I-ARG/Place-Arg
# line dikarenakan/VB/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line
# line "/"/O/O
# line Dihimbau/NNP/O/O
# line untuk/IN/O/O
# line para/DT/O/O
# line pengguna/NN/O/O
# line jalan/NN/O/O
# line yg/NNP/O/O
# line ingin/RB/O/O
# line menuju/VB/O/O
# line ke/IN/O/O
# line Kalibata/SC/O/O
# line raya/JJ/O/O
# line ,/,/O/O
# line hindari/IN/O/O
# line jalan/NN/B-ARG/Place-Arg
# line dewi/JJ/I-ARG/Place-Arg
# line sartika/NN/I-ARG/Place-Arg
# line karena/IN/O/O
# line saat/NN/O/O
# line ini/PR/O/O
# line kondisi/NN/O/O
# line macet/NN/O/O
# line dikarenakan/VB/O/O
# line terdampak/IN/O/O
# line banjir/NN/B-EVE/FLOOD-EVENT
# line ,/,/O/O
# line "/"/O/O
# line kicau/NN/O/O
# line BPBD/NN/B-ORG
# line DKI/NNP/B-PLOC/Place-Arg/(-6.197602429787846, 106.83139222722116)/1
# line Jakarta/NNP/I-PLOC
# line
# line
# line
# line Bus/NN/O/O
# line Angkut/NN/O/O
# line Rombongan/NN/O/O
# line Guru/NN/O/O
# line TK/NNP/B-ORG/O
# line Terguling/NNP/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line Blitar/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line ,/,/O/O
# line 5/CD/B-ARG/DeathVictim-Arg
# line Orang/NN/I-ARG/DeathVictim-Arg
# line Tewas/JJ/I-ARG/DeathVictim-Arg
# line KOMPAS/NNP/B-ORG/DeathVictim-Arg
# line com/FW/O/O
# line -/-/O/O
# line Sebuah/NND/O/O
# line bus/NN/O/O
# line pariwisata/NN/O/O
# line yang/SC/O/O
# line mengangkut/VBT/O/O
# line rombongan/NN/O/O
# line guru/NN/O/O
# line pengawas/NN/O/O
# line dan/CC/O/O
# line kepala/NN/B-ORG/O
# line sekolah/NN/I-ORG/O
# line taman/NN/I-ORG/O
# line kanak/NNP/I-ORG/O
# line -/-/I-ORG/O
# line kanak/NN/I-ORG/O
# line asal/NN/O/O
# line Kabupaten/NNP/B-PLOC/Place-Arg/(-8.100725299843663, 111.89695787221875)/2
# line Tulungagung/NNP/I-PLOC/Place-Arg
# line ,/,/O/O
# line Jawa/NNP/B-PLOC/Place-Arg/(-7.593465864949647, 112.53030664912593)/1
# line Timur/NNP/I-PLOC/Place-Arg
# line ,/,/O/O
# line terguling/VBT/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line jembatan/NN/O/O
# line ,/,/O/O
# line Kecamatan/NNP/B-LOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3
# line Kesamben/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line Blitar/NNP/I-PLOC/Place-Arg
# line ,/,/O/O
# line Sabtu/NNP/B-ARG/Time-Arg
# line (/OP/O/O
# line 7/12/2019/DD/B-ARG/Time-Arg
# line )./CP/O/O
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT
# line mengakibatkan/VBT/O/O
# line lima/CDP/B-ARG/DeathVictim-Arg
# line penumpang/NN/I-ARG/DeathVictim-Arg
# line dunia/VBI/I-ARG/DeathVictim-Arg
# line
# line Sementara/CC/O/O
# line penumpang/NN/O/O
# line lainnya/NNG/O/O
# line luka/NN/B-ARG
# line -/-/O/O
# line luka/NN/O/O
# line
# line "/"/O/O
# line Total/NN/O/O
# line yang/SC/O/O
# line dibawa/VB/O/O
# line ke/IN/O/O
# line RS/NN/B-ORG/Hospital-Arg
# line di/IN/O/O
# line Wlingi/NNP/B-LOC/Place-Arg/(-8.051630070562203, 112.35484978736103)/3
# line (/OP/O/O
# line RSUD/NN/B-ORG/Hospital-Arg
# line Ngudi/NN/I-ORG/Hospital-Arg
# line Waluyo/NN/I-ORG/Hospital-Arg
# line Blitar/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line )/CP/O/O
# line ada/VBI/O/O
# line 29/CD/B-ARG/WoundVictim-Arg
# line penumpang/NN/I-ARG/WoundVictim-Arg
# line ,/,/O/O
# line sedangkan/CC/O/O
# line yang/SC/O/O
# line dunia/VBI/O/O
# line ada/VBI/O/O
# line lima/CDP/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line Direktur/NNP/O/O
# line RSUD/NNP/B-ORG/Hospital-Arg
# line Ngudi/NNP/I-ORG/Hospital-Arg
# line Waluyo/NNP/I-ORG/Hospital-Arg
# line Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line Blitar/NNP/I-PLOC/Place-Arg
# line Endah/NNP/O/O
# line Woro/NNP/O/O
# line saat/SC/O/O
# line dikonfirmasi/VB/O/O
# line ,/,/O/O
# line Sabtu/NNP/B-ARG/Time-Arg
# line
# line Dari/IN/O/O
# line lima/CDP/B-ARG/DeathVictim-Arg
# line orang/NN/I-ARG/DeathVictim-Arg
# line yang/SC/O/O
# line dunia/VBI/O/O
# line itu/DT/O/O
# line ,/,/O/O
# line empat/CDP/O/O
# line di/IN/O/O
# line antaranya/NNG/O/O
# line warga/NN/O/O
# line Tulungagung/NNP/B-PLOC/Place-Arg/(-8.100725299843663, 111.89695787221875)/2
# line ,/,/O/O
# line yakni/SC/O/O
# line Siti/NNP/O/O
# line Fatimah/NNP/O/O
# line (/OP/O/O
# line 50/CDP/O/O
# line )/CP/O/O
# line warga/NN/O/O
# line Kecamatan/NNP/B-LOC/Place-Arg/(-7.6816479869417575, 111.95147258443662)/3
# line Gondang/NNP/I-PLOC
# line ,/,/O/O
# line Anita/NNP/O/O
# line (/OP/O/O
# line 46/CDP/O/O
# line )/CP/O/O
# line dan/NNP/O/O
# line Naksabandi/NNP/O/O
# line (/OP/O/O
# line 58/CDP/O/O
# line )/CP/O/O
# line warga/NN/O/O
# line Desa/NN/B-LOC/Place-Arg/(-7.599752631403001, 111.22406242485857)/4
# line Balerejo/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Kecamatan/NNP/B-PLOC/Place-Arg/(-7.956801805592932, 111.6170370314397)/3
# line Kauman/NNP/I-PLOC
# line ,/,/O/O
# line lalu/VB/O/O
# line Kasihatin/NN/O/O
# line kepala/NN/B-ORG/DeathVictim-Arg
# line sekolah/NN/I-ORG/DeathVictim-Arg
# line TK/NNP/I-ORG/DeathVictim-Arg
# line Perwari/NNP/I-ORG/DeathVictim-Arg
# line
# line Seorang/NND/O/O
# line korban/NN/O/O
# line lagi/RB/O/O
# line adalah/VBT/O/O
# line Ridwan/NN/O/O
# line (/OP/O/O
# line 75/CD/O/O
# line )/CP/O/O
# line warga/NN/O/O
# line Dusun/NN/O/O
# line Sembung/NNP/O/O
# line ,/,/O/O
# line Desa/NN/B-LOC/Place-Arg/(-7.367510587106552, 110.1416622395258)/4
# line Pagergunung/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Kecamatan/NNP/B-PLOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3
# line Kesamben/NNP/I-PLOC/Place-Arg
# line ,/,/O/O
# line Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line Blitar/NNP/I-PLOC/Place-Arg
# line
# line Kepala/NN/B-ORG/OfficerOfficial-Arg
# line Unit/NN/I-ORG/OfficerOfficial-Arg
# line Laka/NNP/I-ORG/OfficerOfficial-Arg
# line Lantas/NNP/I-ORG/OfficerOfficial-Arg
# line Polres/NNP/I-ORG/OfficerOfficial-Arg
# line Blitar/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line Ipda/NNP/B-ORG/OfficerOfficial-Arg
# line Didik/NNP/I-ORG/OfficerOfficial-Arg
# line Sugianto/NNP/I-ORG/OfficerOfficial-Arg
# line mengatakan/VB/O/O
# line ,/,/O/O
# line seluruh/CDI/O/O
# line korban/NN/O/O
# line telah/MD/O/O
# line dievakuasi/VBT/O/O
# line ke/IN/O/O
# line rumah/NN/O/O
# line sakit/NN/O/O
# line
# line "/"/O/O
# line Saat/NN/O/O
# line ini/PR/O/O
# line para/DT/O/O
# line korban/NN/O/O
# line kami/PRP/O/O
# line evakuasi/NN/O/O
# line ,/,/O/O
# line dibawa/VB/O/O
# line ke/IN/O/O
# line rumah/NN/O/O
# line sakit/NN/O/O
# line
# line Kendaraan/NN/O/O
# line juga/RB/O/O
# line masih/MD/O/O
# line proses/NN/O/O
# line evakuasi/NN/O/O
# line berlanjut/VBI/O/O
# line ,/,/O/O
# line "/"/O/O
# line kata/VB/O/O
# line Didik/NNP/O/O
# line Sugianto/NNP/O/O
# line
# line Rombongan/NN/O/O
# line bus/NN/O/O
# line pariwisata/NN/O/O
# line yang/SC/O/O
# line mengangkut/VBT/O/O
# line guru/NN/O/O
# line pengawas/NN/O/O
# line dan/CC/O/O
# line kepala/NN/B-ORG/OfficerOfficial-Arg
# line sekolah/NN/I-ORG/OfficerOfficial-Arg
# line TK/NN/I-ORG/OfficerOfficial-Arg
# line asal/NN/O/O
# line Kabupaten/NNP/B-PLOC/Place-Arg/(-8.100725299843663, 111.89695787221875)/2
# line Tulungagung/NNP/I-PLOC
# line itu/DT/O/O
# line rencananya/NNG/O/O
# line akan/MD/O/O
# line menghabiskan/VBT/O/O
# line akhir/NN/O/O
# line pekan/NN/O/O
# line ke/IN/O/O
# line Pasuruan/NNP/B-PLOC/Place-Arg/(-7.648002139031701, 112.90464400847651)/2
# line
# line Bus/NN/O/O
# line terguling/VBI/B-EVE/ACCIDENT-EVENT
# line di/IN/O/O
# line jalan/NN/B-ARG/Place-Arg
# line raya/JJ/I-ARG/Place-Arg
# line Kesamben/NNP/B-LOC/Place-Arg/(-7.740079910506011, 112.3505905988675)/3
# line ,/,/O/O
# line tepatnya/RB/O/O
# line sebelah/NN/O/O
# line timur/NN/O/O
# line SPBU/NNP/B-ORG/Place-Arg
# line Kesamben/NNP/B-LOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3
# line ,/,/O/O
# line sekitar/CDI/O/O
# line pukul/NN/B-ARG/Time-Arg
# line 06.30/JJ/I-ARG/Time-Arg
# line WIB/NNP/I-ARG/Time-Arg
# line
# line Lokasi/NN/O/O
# line kecelakaan/NN/B-EVE/ACCIDENT-EVENT/ACCIDENT-EVENT
# line juga/RB/O/O
# line dekat/JJ/O/O
# line jembatan/NN/O/O
# line di/IN/O/O
# line Kecamatan/NNP/B-LOC/Place-Arg/(-8.120459667921391, 112.3846910222594)/3
# line Kesamben/NNP/I-LOC/Place-Arg
# line ,/,/O/O
# line Kabupaten/NNP/B-PLOC/Place-Arg/(-8.116787994159438, 112.21988109991273)/2
# line Blitar/NNP/I-PLOC/Place-Arg
# line
# line
# line
# [['Kerabat', 'Layat', 'Jasad', 'Jerry', 'Wong', 'Pengemudi', 'Mini', 'Cooper', 'di', 'RSCM', '-', '-', 'Jakarta', '-', 'Jenazah', 'Jerry', 'Wong', ',', 'pengemudi', 'Mini', 'Cooper', 'yang', 'menabrak', 'bagian', 'belakang', 'truk', ',', 'kini', 'berada', 'di', 'RSCM', 'Sekitar', '15', 'kerabat', 'dan', 'teman', 'datang', 'melayat', 'Pantauan', 'detikcom', 'di', 'kamar', 'jenazah', 'RSCM', ',', 'Jalan', 'Salemba', ',', 'Jakarta', 'Pusat', ',', 'Jumat', '(', '16', ')', ',', 'jasad', 'Jerry', 'ditutup', 'kain', 'jarik', 'cokelat', ',', 'dikelilingi', 'kerabatnya', 'Ada', 'seorang', 'kerabat', 'Jerry', ',', 'Dodi', 'yang', 'mengenang', 'Jerry', 'sebagai', 'orang', 'yang', 'baik', 'dan', 'banyak', 'teman', '"', 'Jerry', 'tadi', 'perjalanan', 'dari', 'rumah', 'temannya', ',', 'mau', 'pulang', 'ke', 'rumahnya', 'di', 'daerah', 'Pluit', 'Jerry', 'ini', 'orangnya', 'baik', ',', 'temannya', 'banyak', ',', 'kebetulan', 'saya', 'teman', 'main', 'futsal', 'di', 'Kuningan', ',', '"', 'kata', 'dia', 'Sedang', 'kerabatnya', 'lainnya', 'enggan', 'memberikan', 'keterangan', '"', 'Saya', 'nggak', 'tahu', 'apa', '-', 'apa', ',', 'kami', 'sedang', 'berduka', ',', '"', 'begitu', 'pinta', 'seorang', 'kerabat', 'Mini', 'Cooper', 'bernopol', 'B', '226', 'NUK', 'yang', 'dikemudikan', 'Jerry', 'Wong', 'menghantam', 'keras', 'bagian', 'belakang', 'truk', 'wing', 'box', 'bernopol', 'B', '9667', 'ZX', 'di', 'Km', '24+800', 'dari', 'Pluit', 'arah', 'Bandara', 'Soekarno', '-', 'Hatta', 'Saking', 'kerasnya', 'hantaman', 'itu', ',', 'bagian', 'depan', 'Mini', 'Cooper', 'tersangkut', 'ke', 'bemper', 'truk', 'itu'], ['1', 'Orang', 'Tewas', ',', '125', 'Ribu', 'Warga', 'California', 'Mengungsi', 'akibat', 'Kebakaran', '-', '-', 'California', '-', 'Kebakaran', 'hutan', 'yang', 'menerjang', 'wilayah', 'California', ',', 'Amerika', 'Serikat', 'memaksa', '125', 'ribu', 'warga', 'untuk', 'mengungsi', 'Dilaporkan', 'sedikitnya', 'satu', 'orang', 'tewas', 'akibat', 'kebakaran', 'ini', 'Ada', 'sembilan', 'titik', 'api', 'yang', 'terus', 'bergerak', 'di', 'wilayah', 'Southern', 'California', 'dan', 'mengancam', 'pemukiman', 'warga', 'yang', 'ada', 'di', 'San', 'Marcos', 'dan', 'Escondido', ',', 'distrik', 'San', 'Diego', 'Sebuah', 'rumah', 'yang', 'cukup', 'besar', 'milik', 'warga', 'setempat', 'di', 'pinggiran', 'San', 'Marcos', 'habis', 'dilalap', 'api', 'Tayangan', 'televisi', 'setempat', 'menunjukkan', 'bagaiman', 'kobaran', 'api', 'bergerak', 'cepat', 'mendekati', 'rumah', 'warga', ',', 'sementara', 'warga', 'bergegas', 'mengevakuasi', 'barang', '-', 'barangnya', 'dan', 'mengungsi', 'dari', 'lokasi', 'Demikian', 'seperti', 'dilansir', 'Reuters', ',', 'Jumat', '(', '16', ')'], ['Analisis', 'BMKG', 'soal', 'Gempa', 'Lebak', '5,1', 'SR', '-', '-', 'Jakarta', '-', 'Gempa', 'bumi', 'berkekuatan', '5,1', 'Skala', 'Richter', '(', 'SR', ')', 'mengguncang', 'kawasan', 'Lebak', ',', 'Banten', 'Gempa', 'ini', 'dirasakan', 'hingga', 'Bandung', 'Dampak', 'gempa', 'bumi', 'yang', 'digambarkan', 'oleh', 'peta', 'tingkat', 'guncangan', '(', 'shakemap', ')', 'BMKG', 'dan', 'laporan', 'masyarakat', 'menunjukkan', 'bahwa', 'dampak', 'gempa', 'bumi', 'berupa', 'guncangan', 'dirasakan', 'di', 'daerah', 'Bayah', 'dan', 'Cikotok', 'dalam', 'skala', 'intensitas', 'II', 'SIG', '-', 'BMKG', '(', 'III', '-', 'IV', 'MMI', ')', ',', 'Sukabumi', 'dan', 'Bandung', 'dengan', 'intensitas', 'II', 'SIG', '-', 'BMKG', '(', 'II', '-', 'III', 'MMI', ')', ',', '"', 'kata', 'Kepala', 'Pusat', 'Gempa', 'Bumi', 'dan', 'Tsunami', 'BMKG', 'Mochammad', 'Riyad', 'dalam', 'keterangan', 'tertulis', ',', 'Jumat', '(', '16', ')', 'Baca', 'juga', ':', 'Gempa', '5,1', 'SR', 'Guncang', 'Lebak', 'Banten', 'Berdasarkan', 'hasil', 'analisis', 'BMKG', ',', 'gempa', 'itu', 'merupakan', 'gempa', 'bumi', 'tektonik', 'Gempa', 'itu', 'terjadi', 'akibat', 'aktivitas', 'subduksi', 'lempeng', 'Indo', '-', 'Australia', 'ke', 'bawah', 'Lempeng', 'Eurasia'], ['3', 'Tewas', 'Akibat', 'Gempa', 'di', 'Meksiko', 'dan', 'Guatemala', ',', ...

# %%
# Train the Word2Vec model
my_model = Word2Vec(tokenized_data, vector_size=100, window=5, min_count=5, workers=4)

# %%
# Save the trained model
# my_model.save('my_model_indonesian_newspapers_word2vec.model')

# %%
document_vectors = []

for tokens in tokenized_data:
    # If the document has no tokens (e.g., after preprocessing), assign a default vector
    if not tokens:
        document_vectors.append(np.zeros(my_model.vector_size))
    else:
        # Calculate the document vector by averaging the word vectors
        document_vector = np.mean([my_model.wv[word] for word in tokens if word in my_model.wv.index_to_key], axis=0)
        document_vectors.append(document_vector)

# %%
y_vectors = []
for label in df['Event_Type']:
    label_vector = np.mean([my_model.wv[word] for word in label if word in my_model.wv.index_to_key], axis=0)
    y_vectors.append(label_vector)

# %%
document_vectors[0]
# Out:
# array([-0.12387558,  0.3450927 , -0.0721269 , -0.05232852,  0.01720145,
#        -0.4560713 ,  0.20645854,  0.60567826, -0.22441961, -0.17900987,
#        -0.02367817, -0.47163802, -0.11995075,  0.05255514,  0.14703786,
#        -0.15496871,  0.09423275, -0.24966626, -0.13772894, -0.49646738,
#         0.05740146,  0.163016  ,  0.3809803 , -0.05315839, -0.12483926,
#         0.0769779 , -0.34598184, -0.18044128, -0.3089661 ,  0.0409544 ,
#         0.40049723,  0.048063  ,  0.22175628, -0.18704057, -0.23429811,
#         0.43017083,  0.1358005 , -0.11894071, -0.14714123, -0.3522848 ,
#        -0.03139261, -0.2230216 , -0.12332384,  0.10893395,  0.37661967,
#        -0.04837448, -0.28859988, -0.11931238,  0.12882304,  0.16780868,
#         0.15381701, -0.26329908, -0.06231876, -0.25818405, -0.27213198,
#         0.06029445,  0.15896788, -0.11193493, -0.36640272,  0.09775911,
#         0.01228678,  0.07225887,  0.05842808, -0.10962836, -0.43739718,
#         0.14187858,  0.19295003,  0.26495758, -0.5382732 ,  0.24818033,
#        -0.18934925,  0.08102641,  0.15105496, -0.10803971,  0.2348748 ,
#         0.14985216, -0.00849288, -0.13970937, -0.30793646,  0.13996878,
#        -0.15228158, -0.14275572, -0.20425706,  0.4001337 , -0.11463138,
#         0.146667  ,  0.09543424,  0.41514137,  0.44634667, -0.03371008,
#         0.42322737,  0.22314796,  0.07572868,  0.05137225,  0.5225726 ,
#         0.3457038 ,  0.0269678 , -0.3170017 ,  0.07306492, -0.050536  ],
#       dtype=float32)

# %%
y_vectors[3]
# Out:
# nan

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import LabelEncoder

tfidf_vectorizer = TfidfVectorizer()

X_train,X_test,y_train,y_test = train_test_split(document_vectors, df['Event_Type'], train_size=0.8, random_state=42)

# %%
# Min max scaling
min_value = np.min(X_train, axis=0)
max_value = np.max(X_train, axis=0)
scaled_X_train = (X_train - min_value) / (max_value - min_value)
scaled_X_test = (X_test - min_value) / (max_value - min_value)

# %%
label_encoder = LabelEncoder()

y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.fit_transform(y_test)

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(scaled_X_train, y_train_encoded)
# Out:
# MultinomialNB()

# %%
y_pred = nb.predict(scaled_X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
confusion_matrix(y_test_encoded, y_pred)
# Out:
# array([[17]])

# %%
print(classification_report(y_pred, y_test_encoded))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17

# %% [markdown]
# # Joint Paradigm
# **Phase 1: Trigger & Argument Identification**
#
# **Phase 2: Trigger & Argument Classification**

# %%
df_copy = df

# %%
df_copy = df_copy.drop(['Accident_Event', 'Fire_Event',	'Flood_Event', 'Earthquake_Event'], axis=1, inplace=False)

# %%
df_copy = df_copy.drop(['EventType'], axis=1, inplace=False)

# %%
df_copy
# Out:
#                                              Document Event_Type
# 0   Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...
# 1   \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2   \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3   \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4   \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
# ..                                                ...        ...
# 79  \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80  \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81  \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82  \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...
# 83
#
# [84 rows x 2 columns]

# %%
df_copy['Document_ID'] = ''
df_copy
# Out:
#                                              Document Event_Type Document_ID
# 0   Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...
# 1   \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2   \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3   \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4   \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
# ..                                                ...        ...         ...
# 79  \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80  \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81  \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82  \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...
# 83
#
# [84 rows x 3 columns]

# %%
df_copy = df_copy[['Document_ID', 'Document', 'Event_Type']]

# %%
df_copy
# Out:
#    Document_ID                                           Document Event_Type
# 0               Kerabat/NNP/O/O\nLayat/NNP/O/O\nJasad/NNP/O/O\...
# 1               \n1/CDP/B-ARG/DeathVictim-Arg\nOrang/NN/I-ARG/...
# 2               \nAnalisis/NNP/O/O\nBMKG/NNP/B-ORG/Reporter-Ar...
# 3               \n3/CDP/B-ARG/DeathVictim-Arg\nTewas/JJ/I-ARG/...
# 4               \nTabrak/NN/B-EVE/ACCIDENT-EVENT\nPembatas/NN/...
# ..         ...                                                ...        ...
# 79              \nGempa/NNP/B-EVE/QUAKE-EVENT\nMagnitudo/NNP/B...
# 80              \nHujan/NN/O/O\nDeras/NNP/O/O\n,/,/O/O\nKawasa...
# 81              \nBanjir/NN/B-EVE/FLOOD-EVENT\n3/CDP/B-ARG/Hei...
# 82              \nBus/NN/O/O\nAngkut/NN/O/O\nRombongan/NN/O/O\...
# 83
#
# [84 rows x 3 columns]

# %%
class MyToken:
    def __init__(self, doc_id, word=None, pos_tag=None, event=None, argument=None, latlong=None, admin_level=None):
        self.doc_id = doc_id
        self.word = word if word is not None else ""
        self.pos_tag = pos_tag if pos_tag is not None else ""
        self.event = event if event is not None else ""
        self.argument = argument if argument is not None else ""
        self.latlong = latlong if latlong is not None else ""
        self.admin_level = admin_level if admin_level is not None else ""

# %%
import re

my_docs = df_copy['Document'].tolist()

my_docss = []

for index, document in enumerate(my_docs):
    lines = document.split('\n')
    document_tokens = []
    for line in lines:
        # Skip empty line
        if line.strip() == '':
            continue
        # Split each line by the delimiter    

        pattern1 = r"(\d{1,2}/\d{1,2}/\d{4})/(.*)"
        result1 = re.findall(pattern1, line)

        if result1: 
            first_part = result1[0][0]
            other_parts = result1[0][1].split('/')
            parts = [first_part] + other_parts
        else:
            parts = line.strip().split("/")
        
        # word = parts[0]
        # pos_tag = parts[1]
        # event = parts[2]
        # argument = parts[3]
        # latlong = parts[4]
        # admin_level = parts[5]
        if len(parts) == 6:
            token = MyToken(index, parts[0], parts[1], parts[2], parts[3], parts[4], parts[5])
        elif len(parts) == 5:
            token = MyToken(index, parts[0], parts[1], parts[2], parts[3], parts[4])
        elif len(parts) == 4:
            token = MyToken(index, parts[0], parts[1], parts[2], parts[3])
        elif len(parts) == 3:
            token = MyToken(index, parts[0], parts[1], parts[2])
        elif len(parts) == 2:
            token = MyToken(index, parts[0], parts[1])
        elif len(parts) == 1:
            token = MyToken(index, parts[0])
        else:
            token = MyToken(index)
        document_tokens.append(token)
    my_docss.append(document_tokens)

# %%
# ada yang salah nih harusnya 84 semua
print(len(my_docss))
# print(len(my_docss[0]))
# print(len(my_docss[1]))
# print(len(my_docss[2]))
# print(len(my_docss[3]))
# print(len(my_docss[4]))
# print(len(my_docss[5]))
# Out:
# 84

# %%
documentids = []
words = []
pos_tags = []
events = []
arguments = []
coordinates = []
admin_levels = []

for document in my_docss:
    for token in document:
        documentids.append(token.doc_id)
        words.append(token.word)
        pos_tags.append(token.pos_tag)
        events.append(token.event)
        arguments.append(token.argument)
        coordinates.append(token.latlong)
        admin_levels.append(token.admin_level)

# %%
print(len(documentids))
print(len(words))
print(len(pos_tags))
print(len(events))
print(len(arguments))
print(len(coordinates))
print(len(admin_levels))
# Out:
# 15438
# 15438
# 15438
# 15438
# 15438
# 15438
# 15438

# %%
new_df = pd.DataFrame({'doc_id': documentids, 'word': words, 'pos_tag': pos_tags, 'event': events, 'argument': arguments, 'coordinate': coordinates, 'admin_level': admin_levels})

# %%
from IPython.display import display

pd.set_option("display.max_rows", 20)
display(new_df)
# Out:
#        doc_id       word pos_tag   event   argument  \
# 0           0    Kerabat     NNP       O          O
# 1           0      Layat     NNP       O          O
# 2           0      Jasad     NNP       O          O
# 3           0      Jerry     NNP       O          O
# 4           0       Wong     NNP       O          O
# ...       ...        ...     ...     ...        ...
# 15433      82  Kecamatan     NNP   B-LOC  Place-Arg
# 15434      82   Kesamben     NNP   I-LOC  Place-Arg
# 15435      82          ,       ,       O          O
# 15436      82  Kabupaten     NNP  B-PLOC  Place-Arg
# 15437      82     Blitar     NNP  I-PLOC  Place-Arg
#
#                                      coordinate admin_level
# 0
# 1
# 2
# 3
# 4
# ...                                         ...         ...
# 15433   (-8.120459667921391, 112.3846910222594)           3
# 15434
# 15435
# 15436  (-8.116787994159438, 112.21988109991273)           2
# 15437
#
# [15438 rows x 7 columns]

# %%
new_df.to_csv('dataframe/transformed.csv')

# %%
def get_unique_values_overview(column):
    column_unique_count = column.nunique()
    column_unique_values = column.unique()
    column_unique_value_counts = column.value_counts()

    print("==================" + column.name + "=================\n")
    
    print("Number of unique values in column:")
    pp.pprint(column_unique_count)

    # print("Unique values in column:")
    # pp.pprint(column_unique_values)

    pd.set_option('display.max_rows', None)
    print("Each unnique values count:")
    pp.pprint(column_unique_value_counts)

    print("==========================================\n")

# %%
# Try creating train test split with still 80/20 split
# But, make sure the percentage of the event trigger & argument role is also proportional
# Count the number of -EVENT and Arguments

get_unique_values_overview(new_df['event'])
get_unique_values_overview(new_df['argument'])

# based on the values here masih ada salah parsing karena masih ada arguments location di arguments & argument roles di event
# Out:
# ==================event=================
#
# Number of unique values in column:
# 20
# Each unnique values count:
# event
# O         11073
# I-ARG      1048
# B-ARG       950
# B-EVE       596
# B-PLOC      446
# B-LOC       322
# B-ORG       288
# I-ORG       285
# I-PLOC      184
# I-LOC       129
# I-EVE       103
# DD            3
# 8             2
#               2
# 5             2
# 4             1
# 3             1
# 9             1
# 6             1
# 1             1
# Name: count, dtype: int64
# ==========================================
#
# ==================argument=================
#
# Number of unique values in column:
# 62
# Each unnique values count:
# argument
# O                             11046
# Place-Arg                      1043
# Time-Arg                        410
# OfficerOfficial-Arg             395
# FLOOD-EVENT                     195
# DeathVictim-Arg                 195
# FIRE-EVENT                      178
# Height-Arg                      172
# Street-Arg                      157
#                                 146
# ACCIDENT-EVENT                  129
# QUAKE-EVENT                     125
# Vehicle-Arg                     119
# Strength-Arg                     94
# Central-Arg                      89
# Facility-Arg                     81
# Published-Arg                    79
# Plate-Arg                        59
# Cause-Arg                        50
# Hospital-Arg                     47
# AffectedHouse-Arg                45
# DispatchedTrucks-Arg             44
# Point-Arg                        39
# Reporter-Arg                     39
# AffectedVillage-Arg              32
# To-Arg                           32
# Duration-Arg                     31
# Depth-Arg                        29
# AffectedDistrict-Arg             28
# Length-Arg                       25
# WoundVictim-Arg                  24
# Evacuee-Arg                      20
# LANDSLIDE-EVENT                  18
# AffectedFamily-Arg               16
# EVACUATE-EVENT                   16
# From-Arg                         16
# JAM-EVENT                        16
# RAIN-EVENT                       16
# AffectedPeople-Arg               15
# Affectedvehicle-Arg              14
# AffectedInfrastructure-Arg       14
# HouseBurnt-Arg                   10
# DD                                9
# Spot-Arg                          9
# AffectedField-Arg                 9
# AffectedFacility-Arg              8
# AffectedVehicle-Arg               7
# Delta-Arg                         6
# MissingPerson-Arg                 5
# AffectedRT-Arg                    4
# VehicleBurnt-Arg                  4
# MEETING-EVENT                     4
# AffectedFamily                    4
# AffectedHouse-House               3
# DeathVictim                       3
# Strength_Arg                      3
# MonetaryLoss-Arg                  3
# B-ARG                             3
# AffectedCities-Arg                2
# Repeat-Arg                        2
# PLate-Arg                         1
# B-EVE                             1
# Name: count, dtype: int64
# ==========================================

# %%
# load csv
mydf = pd.read_csv('dataframe/transformed.csv')

# %%
get_unique_values_overview(mydf['event'])
get_unique_values_overview(mydf['argument'])
# Out:
# ==================event=================
#
# Number of unique values in column:
# 11
# Each unnique values count:
# event
# O         11072
# I-ARG      1048
# B-ARG       962
# B-EVE       597
# B-PLOC      446
# B-LOC       322
# B-ORG       288
# I-ORG       285
# I-PLOC      184
# I-LOC       129
# I-EVE       103
# Name: count, dtype: int64
# ==========================================
#
# ==================argument=================
#
# Number of unique values in column:
# 58
# Each unnique values count:
# argument
# O                             11046
# Place-Arg                      1043
# Time-Arg                        422
# OfficerOfficial-Arg             395
# FLOOD-EVENT                     195
# DeathVictim-Arg                 195
# FIRE-EVENT                      178
# Height-Arg                      172
# Street-Arg                      157
# ACCIDENT-EVENT                  129
# QUAKE-EVENT                     125
# Vehicle-Arg                     119
# Strength-Arg                     94
# Central-Arg                      89
# Facility-Arg                     81
# Published-Arg                    79
# Plate-Arg                        59
# Cause-Arg                        50
# Hospital-Arg                     47
# AffectedHouse-Arg                45
# DispatchedTrucks-Arg             44
# Point-Arg                        39
# Reporter-Arg                     39
# AffectedVillage-Arg              32
# To-Arg                           32
# Duration-Arg                     31
# Depth-Arg                        29
# AffectedDistrict-Arg             28
# Length-Arg                       25
# WoundVictim-Arg                  24
# Evacuee-Arg                      20
# LANDSLIDE-EVENT                  18
# RAIN-EVENT                       17
# AffectedFamily-Arg               16
# JAM-EVENT                        16
# From-Arg                         16
# EVACUATE-EVENT                   16
# AffectedPeople-Arg               15
# Affectedvehicle-Arg              14
# AffectedInfrastructure-Arg       14
# HouseBurnt-Arg                   10
# Spot-Arg                          9
# AffectedField-Arg                 9
# AffectedFacility-Arg              8
# AffectedVehicle-Arg               7
# Delta-Arg                         6
# MissingPerson-Arg                 5
# VehicleBurnt-Arg                  4
# MEETING-EVENT                     4
# AffectedFamily                    4
# AffectedRT-Arg                    4
# MonetaryLoss-Arg                  3
# DeathVictim                       3
# Strength_Arg                      3
# AffectedHouse-House               3
# AffectedCities-Arg                2
# Repeat-Arg                        2
# PLate-Arg                         1
# Name: count, dtype: int64
# ==========================================
